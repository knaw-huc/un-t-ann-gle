# %% [markdown]
# Naar analogie met de exercitie voor 7 aaneensluitende zittingsdagen, hieronder een poging hetzelfde te doen voor een DBNL TEI document. Overeenkomst: leaf text elementen (in dit geval paragrafen, of wellicht tokens - begin met paragrafen) in sequentie, met daarop een hierarchische 'fysische' structuur.

# %%
import lxml
from lxml import etree

path = '../data/tei-samples/bosb002graa04_01.xml'

_last_page_begin_index = 0
_last_section_begin_index = -1
_last_chapter_begin_index = -1
_last_paragraph_begin_index = -1
_last_head_begin_index = -1

_last_page_end_index = -1
_last_section_end_index = -1
_last_chapter_end_index = -1
_last_paragraph_end_index = -1
_last_head_end_index = -1

_last_page_id = ""

all_textelements=[]
all_annotations=[]

# handle each of the elements in the hierarchy according to 'layer type'
def handle_element(action,e):  
    global _last_page_begin_index
    global _last_section_begin_index
    global _last_chapter_begin_index
    global _last_paragraph_begin_index
    global _last_head_begin_index

    global _last_page_end_index
    global _last_section_end_index
    global _last_chapter_end_index
    global _last_paragraph_end_index
    global _last_head_end_index
    
    global _last_page_id

    if action == 'start':
        # store last begin indexes
        if e.tag == 'p':
            _last_paragraph_begin_index = len(all_textelements)               
        elif e.tag == 'div' and e.get('type') == 'chapter':
            _last_chapter_begin_index = len(all_textelements)
        elif e.tag == 'div' and e.get('type') == 'section':
            _last_section_begin_index = len(all_textelements)
        elif e.tag == 'head':
            _last_head_begin_index = len(all_textelements)
    elif action == 'end':
        if e.tag == 'p': 
            # leaf text element, add to all_textelements, also include text after possible pb's
            for index, t in enumerate(e.itertext()):
                all_textelements.append(t.strip())
                if index > 0: # assume: caused by pb contained within p. Update page end.
                    _last_page_end_index = len(all_textelements)-1
                    
            _last_paragraph_end_index = len(all_textelements)-1
            all_annotations.append({'label':'paragraph','begin_index': _last_paragraph_begin_index,\
                            'end_index':_last_paragraph_end_index,'id': "generate_later"})
        elif e.tag == 'head':
            # leaf text element, add to all_textelements
            all_textelements.append(e.text)
            
            _last_head_end_index = len(all_textelements)-1
            all_annotations.append({'label':'head','begin_index': _last_head_begin_index,\
                            'end_index':_last_head_end_index,'id': "generate_later"}) 
        elif e.tag == 'div' and e.get('type') == 'chapter':
            _last_chapter_end_index = len(all_textelements)-1
            all_annotations.append({'label':'chapter','begin_index': _last_chapter_begin_index,\
                            'end_index':_last_chapter_end_index,'id':'generate_later'})            
        elif e.tag == 'div' and e.get('type') == 'section':
            _last_section_end_index = len(all_textelements)-1
            all_annotations.append({'label':'section','begin_index': _last_section_begin_index,\
                            'end_index':_last_section_end_index,'id':'generate_later'})               
        elif e.tag == 'pb':
            # first store the 'previous' page, then store begin and end of currently closed page
            all_annotations.append({'label':'page','begin_index': _last_page_begin_index,\
                            'end_index':_last_page_end_index,'id': _last_page_id}) 
            _last_page_begin_index = _last_page_end_index
            _last_page_end_index = len(all_textelements)-1 
            _last_page_id = f"page-{e.get('n')}"
            
    return        

# use iterparse to traverse the xml hierarchy, depth first, post order
context = etree.iterparse(path, events=('start','end'))
for action, elem in context:
    handle_element(action,elem)

# %%
all_textelements[200:215]
# Out:
# ['',
#  'wyatt',
#  '',
#  '207',
#  '',
#  '',
#  '',
#  'HOOFDSTUK XIV.',
#  '',
#  '',
#  '',
#  '',
#  'gevangenschap',
#  '',
#  '221']

# %%
len(all_textelements)
# Out:
# 3130

# %%
all_annotations
# Out:
# [{'label': 'paragraph',
#   'begin_index': 0,
#   'end_index': 0,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1,
#   'end_index': 1,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 2,
#   'end_index': 2,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 3,
#   'end_index': 3,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 4,
#   'end_index': 14,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 15,
#   'end_index': 15,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 16,
#   'end_index': 16,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 17,
#   'end_index': 17,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 18,
#   'end_index': 18,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 19,
#   'end_index': 21,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 22,
#   'end_index': 22,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 23,
#   'end_index': 23,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 24,
#   'end_index': 26,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 27,
#   'end_index': 28,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 29,
#   'end_index': 29,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 30,
#   'end_index': 30,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 31,
#   'end_index': 31,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 32,
#   'end_index': 32,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 33,
#   'end_index': 33,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 34,
#   'end_index': 34,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 35,
#   'end_index': 35,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 36,
#   'end_index': 36,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 37,
#   'end_index': 41,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 42,
#   'end_index': 43,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 44,
#   'end_index': 44,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 45,
#   'end_index': 47,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 48,
#   'end_index': 48,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 49,
#   'end_index': 49,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 50,
#   'end_index': 52,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 53,
#   'end_index': 53,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 54,
#   'end_index': 54,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 55,
#   'end_index': 178,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 179,
#   'end_index': 179,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 180,
#   'end_index': 182,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 183,
#   'end_index': 289,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 290,
#   'end_index': 290,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 291,
#   'end_index': 291,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 292,
#   'end_index': 292,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 293,
#   'end_index': 295,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 296,
#   'end_index': 296,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 297,
#   'end_index': 297,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 298,
#   'end_index': 297,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 298,
#   'end_index': 297,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 298,
#   'end_index': 297,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 298,
#   'end_index': 297,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 298,
#   'end_index': 297,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 298,
#   'end_index': 297,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 298,
#   'end_index': 297,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 298,
#   'end_index': 297,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 0, 'end_index': 295, 'id': ''},
#  {'label': 'paragraph',
#   'begin_index': 298,
#   'end_index': 297,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 295, 'end_index': 297, 'id': 'page-IV'},
#  {'label': 'head',
#   'begin_index': 298,
#   'end_index': 298,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 297, 'end_index': 297, 'id': 'page-1'},
#  {'label': 'head',
#   'begin_index': 299,
#   'end_index': 299,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 300,
#   'end_index': 300,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 297, 'end_index': 298, 'id': 'page-3'},
#  {'label': 'paragraph',
#   'begin_index': 301,
#   'end_index': 302,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 303,
#   'end_index': 303,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 304,
#   'end_index': 304,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 305,
#   'end_index': 305,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 306,
#   'end_index': 306,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 307,
#   'end_index': 307,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 298, 'end_index': 302, 'id': 'page-4'},
#  {'label': 'paragraph',
#   'begin_index': 308,
#   'end_index': 309,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 310,
#   'end_index': 310,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 311,
#   'end_index': 311,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 312,
#   'end_index': 312,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 313,
#   'end_index': 315,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 316,
#   'end_index': 316,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 317,
#   'end_index': 317,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 302, 'end_index': 315, 'id': 'page-5'},
#  {'label': 'paragraph',
#   'begin_index': 318,
#   'end_index': 319,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 320,
#   'end_index': 320,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 321,
#   'end_index': 321,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 322,
#   'end_index': 322,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 323,
#   'end_index': 323,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 315, 'end_index': 319, 'id': 'page-6'},
#  {'label': 'paragraph',
#   'begin_index': 324,
#   'end_index': 325,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 326,
#   'end_index': 326,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 327,
#   'end_index': 327,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 328,
#   'end_index': 328,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 329,
#   'end_index': 329,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 330,
#   'end_index': 330,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 331,
#   'end_index': 331,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 319, 'end_index': 325, 'id': 'page-7'},
#  {'label': 'paragraph',
#   'begin_index': 332,
#   'end_index': 332,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 325, 'end_index': 331, 'id': 'page-8'},
#  {'label': 'paragraph',
#   'begin_index': 333,
#   'end_index': 334,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 335,
#   'end_index': 335,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 336,
#   'end_index': 336,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 337,
#   'end_index': 337,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 338,
#   'end_index': 338,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 339,
#   'end_index': 339,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 340,
#   'end_index': 340,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 331, 'end_index': 334, 'id': 'page-9'},
#  {'label': 'paragraph',
#   'begin_index': 341,
#   'end_index': 344,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 345,
#   'end_index': 345,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 346,
#   'end_index': 346,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 334, 'end_index': 344, 'id': 'page-10'},
#  {'label': 'paragraph',
#   'begin_index': 347,
#   'end_index': 350,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 344, 'end_index': 350, 'id': 'page-11'},
#  {'label': 'page', 'begin_index': 350, 'end_index': 350, 'id': 'page-12'},
#  {'label': 'page', 'begin_index': 350, 'end_index': 350, 'id': 'page-13'},
#  {'label': 'paragraph',
#   'begin_index': 351,
#   'end_index': 356,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 350, 'end_index': 356, 'id': 'page-14'},
#  {'label': 'paragraph',
#   'begin_index': 357,
#   'end_index': 358,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 359,
#   'end_index': 359,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 360,
#   'end_index': 360,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 361,
#   'end_index': 361,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 362,
#   'end_index': 362,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 363,
#   'end_index': 363,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 364,
#   'end_index': 364,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 356, 'end_index': 358, 'id': 'page-15'},
#  {'label': 'paragraph',
#   'begin_index': 365,
#   'end_index': 366,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 358, 'end_index': 366, 'id': 'page-16'},
#  {'label': 'paragraph',
#   'begin_index': 367,
#   'end_index': 368,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 366, 'end_index': 368, 'id': 'page-17'},
#  {'label': 'paragraph',
#   'begin_index': 369,
#   'end_index': 372,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 373,
#   'end_index': 373,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 374,
#   'end_index': 374,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 375,
#   'end_index': 375,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 376,
#   'end_index': 376,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 368, 'end_index': 372, 'id': 'page-18'},
#  {'label': 'paragraph',
#   'begin_index': 377,
#   'end_index': 377,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 378,
#   'end_index': 378,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 379,
#   'end_index': 381,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 382,
#   'end_index': 383,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 372, 'end_index': 383, 'id': 'page-19'},
#  {'label': 'paragraph',
#   'begin_index': 384,
#   'end_index': 386,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 387,
#   'end_index': 387,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 388,
#   'end_index': 388,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 383, 'end_index': 386, 'id': 'page-20'},
#  {'label': 'paragraph',
#   'begin_index': 389,
#   'end_index': 394,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 395,
#   'end_index': 395,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 396,
#   'end_index': 396,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 397,
#   'end_index': 397,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 386, 'end_index': 394, 'id': 'page-21'},
#  {'label': 'paragraph',
#   'begin_index': 398,
#   'end_index': 399,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 400,
#   'end_index': 404,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 394, 'end_index': 404, 'id': 'page-22'},
#  {'label': 'paragraph',
#   'begin_index': 405,
#   'end_index': 406,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 407,
#   'end_index': 407,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 408,
#   'end_index': 408,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 409,
#   'end_index': 409,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 404, 'end_index': 406, 'id': 'page-23'},
#  {'label': 'paragraph',
#   'begin_index': 410,
#   'end_index': 410,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 411,
#   'end_index': 411,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 412,
#   'end_index': 412,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 406, 'end_index': 409, 'id': 'page-24'},
#  {'label': 'paragraph',
#   'begin_index': 413,
#   'end_index': 414,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 415,
#   'end_index': 415,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 416,
#   'end_index': 416,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 417,
#   'end_index': 417,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 418,
#   'end_index': 418,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 419,
#   'end_index': 419,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 420,
#   'end_index': 420,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 421,
#   'end_index': 421,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 422,
#   'end_index': 422,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 423,
#   'end_index': 423,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 424,
#   'end_index': 424,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 425,
#   'end_index': 425,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 426,
#   'end_index': 426,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 427,
#   'end_index': 427,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 409, 'end_index': 414, 'id': 'page-25'},
#  {'label': 'paragraph',
#   'begin_index': 428,
#   'end_index': 429,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 430,
#   'end_index': 430,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 431,
#   'end_index': 431,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 432,
#   'end_index': 432,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 433,
#   'end_index': 433,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 434,
#   'end_index': 434,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 435,
#   'end_index': 435,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 436,
#   'end_index': 436,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 437,
#   'end_index': 437,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 438,
#   'end_index': 438,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 439,
#   'end_index': 439,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 414, 'end_index': 429, 'id': 'page-26'},
#  {'label': 'paragraph',
#   'begin_index': 440,
#   'end_index': 440,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 441,
#   'end_index': 441,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 442,
#   'end_index': 442,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 443,
#   'end_index': 443,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 444,
#   'end_index': 444,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 445,
#   'end_index': 445,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 429, 'end_index': 439, 'id': 'page-27'},
#  {'label': 'paragraph',
#   'begin_index': 446,
#   'end_index': 446,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 447,
#   'end_index': 447,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 448,
#   'end_index': 448,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 449,
#   'end_index': 449,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 450,
#   'end_index': 450,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 451,
#   'end_index': 451,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 452,
#   'end_index': 452,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 453,
#   'end_index': 453,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 454,
#   'end_index': 454,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 455,
#   'end_index': 455,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 456,
#   'end_index': 456,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 439, 'end_index': 445, 'id': 'page-28'},
#  {'label': 'paragraph',
#   'begin_index': 457,
#   'end_index': 457,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 458,
#   'end_index': 458,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 459,
#   'end_index': 459,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 460,
#   'end_index': 460,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 461,
#   'end_index': 461,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 462,
#   'end_index': 462,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 463,
#   'end_index': 463,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 445, 'end_index': 456, 'id': 'page-29'},
#  {'label': 'paragraph',
#   'begin_index': 464,
#   'end_index': 464,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 465,
#   'end_index': 465,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 466,
#   'end_index': 466,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 467,
#   'end_index': 467,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 456, 'end_index': 463, 'id': 'page-30'},
#  {'label': 'paragraph',
#   'begin_index': 468,
#   'end_index': 469,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 470,
#   'end_index': 470,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 471,
#   'end_index': 471,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 472,
#   'end_index': 472,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 473,
#   'end_index': 473,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 474,
#   'end_index': 474,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 463, 'end_index': 469, 'id': 'page-31'},
#  {'label': 'paragraph',
#   'begin_index': 475,
#   'end_index': 476,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 477,
#   'end_index': 477,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 478,
#   'end_index': 478,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 479,
#   'end_index': 479,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 480,
#   'end_index': 480,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 481,
#   'end_index': 481,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 482,
#   'end_index': 482,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 483,
#   'end_index': 483,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 484,
#   'end_index': 484,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 469, 'end_index': 476, 'id': 'page-32'},
#  {'label': 'paragraph',
#   'begin_index': 485,
#   'end_index': 486,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 487,
#   'end_index': 487,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 488,
#   'end_index': 488,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 489,
#   'end_index': 489,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 490,
#   'end_index': 490,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 491,
#   'end_index': 491,
#   'id': 'generate_later'},
#  {'label': 'section',
#   'begin_index': 298,
#   'end_index': 491,
#   'id': 'generate_later'},
#  {'label': 'chapter',
#   'begin_index': 298,
#   'end_index': 491,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 476, 'end_index': 486, 'id': 'page-33'},
#  {'label': 'head',
#   'begin_index': 492,
#   'end_index': 492,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 486, 'end_index': 491, 'id': 'page-34'},
#  {'label': 'paragraph',
#   'begin_index': 493,
#   'end_index': 494,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 491, 'end_index': 494, 'id': 'page-35'},
#  {'label': 'paragraph',
#   'begin_index': 495,
#   'end_index': 496,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 497,
#   'end_index': 497,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 498,
#   'end_index': 500,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 501,
#   'end_index': 501,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 502,
#   'end_index': 502,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 503,
#   'end_index': 503,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 494, 'end_index': 500, 'id': 'page-36'},
#  {'label': 'paragraph',
#   'begin_index': 504,
#   'end_index': 507,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 508,
#   'end_index': 508,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 509,
#   'end_index': 509,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 510,
#   'end_index': 510,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 511,
#   'end_index': 511,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 512,
#   'end_index': 512,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 513,
#   'end_index': 513,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 514,
#   'end_index': 514,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 515,
#   'end_index': 515,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 516,
#   'end_index': 516,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 517,
#   'end_index': 517,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 500, 'end_index': 507, 'id': 'page-37'},
#  {'label': 'paragraph',
#   'begin_index': 518,
#   'end_index': 519,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 520,
#   'end_index': 520,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 521,
#   'end_index': 521,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 522,
#   'end_index': 522,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 523,
#   'end_index': 523,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 524,
#   'end_index': 524,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 525,
#   'end_index': 525,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 526,
#   'end_index': 526,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 507, 'end_index': 519, 'id': 'page-38'},
#  {'label': 'paragraph',
#   'begin_index': 527,
#   'end_index': 527,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 528,
#   'end_index': 528,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 519, 'end_index': 526, 'id': 'page-39'},
#  {'label': 'paragraph',
#   'begin_index': 529,
#   'end_index': 530,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 531,
#   'end_index': 531,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 532,
#   'end_index': 532,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 533,
#   'end_index': 533,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 534,
#   'end_index': 534,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 535,
#   'end_index': 535,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 536,
#   'end_index': 536,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 526, 'end_index': 530, 'id': 'page-40'},
#  {'label': 'paragraph',
#   'begin_index': 537,
#   'end_index': 538,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 539,
#   'end_index': 539,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 540,
#   'end_index': 540,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 541,
#   'end_index': 541,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 542,
#   'end_index': 542,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 543,
#   'end_index': 543,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 544,
#   'end_index': 544,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 545,
#   'end_index': 545,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 546,
#   'end_index': 546,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 547,
#   'end_index': 547,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 548,
#   'end_index': 548,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 549,
#   'end_index': 549,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 550,
#   'end_index': 550,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 530, 'end_index': 538, 'id': 'page-41'},
#  {'label': 'paragraph',
#   'begin_index': 551,
#   'end_index': 552,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 538, 'end_index': 552, 'id': 'page-42'},
#  {'label': 'paragraph',
#   'begin_index': 553,
#   'end_index': 554,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 555,
#   'end_index': 555,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 552, 'end_index': 554, 'id': 'page-43'},
#  {'label': 'paragraph',
#   'begin_index': 556,
#   'end_index': 557,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 558,
#   'end_index': 558,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 559,
#   'end_index': 559,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 560,
#   'end_index': 560,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 554, 'end_index': 557, 'id': 'page-44'},
#  {'label': 'paragraph',
#   'begin_index': 561,
#   'end_index': 562,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 563,
#   'end_index': 563,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 564,
#   'end_index': 564,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 565,
#   'end_index': 565,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 566,
#   'end_index': 566,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 567,
#   'end_index': 567,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 568,
#   'end_index': 568,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 569,
#   'end_index': 569,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 557, 'end_index': 562, 'id': 'page-45'},
#  {'label': 'paragraph',
#   'begin_index': 570,
#   'end_index': 571,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 572,
#   'end_index': 572,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 573,
#   'end_index': 573,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 574,
#   'end_index': 574,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 575,
#   'end_index': 575,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 576,
#   'end_index': 576,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 577,
#   'end_index': 579,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 562, 'end_index': 579, 'id': 'page-46'},
#  {'label': 'paragraph',
#   'begin_index': 580,
#   'end_index': 580,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 581,
#   'end_index': 583,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 584,
#   'end_index': 584,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 585,
#   'end_index': 585,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 586,
#   'end_index': 586,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 587,
#   'end_index': 587,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 588,
#   'end_index': 588,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 579, 'end_index': 583, 'id': 'page-47'},
#  {'label': 'paragraph',
#   'begin_index': 589,
#   'end_index': 590,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 591,
#   'end_index': 591,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 592,
#   'end_index': 592,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 583, 'end_index': 590, 'id': 'page-48'},
#  {'label': 'paragraph',
#   'begin_index': 593,
#   'end_index': 594,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 595,
#   'end_index': 595,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 596,
#   'end_index': 598,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 599,
#   'end_index': 599,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 590, 'end_index': 598, 'id': 'page-49'},
#  {'label': 'paragraph',
#   'begin_index': 600,
#   'end_index': 605,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 606,
#   'end_index': 610,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 611,
#   'end_index': 611,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 612,
#   'end_index': 612,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 598, 'end_index': 610, 'id': 'page-50'},
#  {'label': 'paragraph',
#   'begin_index': 613,
#   'end_index': 614,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 615,
#   'end_index': 615,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 616,
#   'end_index': 616,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 617,
#   'end_index': 617,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 610, 'end_index': 614, 'id': 'page-51'},
#  {'label': 'paragraph',
#   'begin_index': 618,
#   'end_index': 619,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 620,
#   'end_index': 620,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 621,
#   'end_index': 621,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 622,
#   'end_index': 622,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 623,
#   'end_index': 623,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 614, 'end_index': 619, 'id': 'page-52'},
#  {'label': 'paragraph',
#   'begin_index': 624,
#   'end_index': 627,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 628,
#   'end_index': 628,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 629,
#   'end_index': 629,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 630,
#   'end_index': 630,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 631,
#   'end_index': 631,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 632,
#   'end_index': 632,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 619, 'end_index': 627, 'id': 'page-53'},
#  {'label': 'page', 'begin_index': 627, 'end_index': 632, 'id': 'page-54'},
#  {'label': 'paragraph',
#   'begin_index': 633,
#   'end_index': 635,
#   'id': 'generate_later'},
#  {'label': 'chapter',
#   'begin_index': 492,
#   'end_index': 635,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 632, 'end_index': 635, 'id': 'page-55'},
#  {'label': 'head',
#   'begin_index': 636,
#   'end_index': 636,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 635, 'end_index': 635, 'id': 'page-56'},
#  {'label': 'paragraph',
#   'begin_index': 637,
#   'end_index': 638,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 639,
#   'end_index': 639,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 640,
#   'end_index': 640,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 641,
#   'end_index': 641,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 642,
#   'end_index': 642,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 643,
#   'end_index': 643,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 644,
#   'end_index': 644,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 635, 'end_index': 638, 'id': 'page-57'},
#  {'label': 'paragraph',
#   'begin_index': 645,
#   'end_index': 645,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 646,
#   'end_index': 646,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 647,
#   'end_index': 647,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 648,
#   'end_index': 648,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 649,
#   'end_index': 649,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 650,
#   'end_index': 650,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 651,
#   'end_index': 651,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 652,
#   'end_index': 652,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 653,
#   'end_index': 653,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 654,
#   'end_index': 654,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 655,
#   'end_index': 655,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 638, 'end_index': 644, 'id': 'page-58'},
#  {'label': 'paragraph',
#   'begin_index': 656,
#   'end_index': 659,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 660,
#   'end_index': 660,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 661,
#   'end_index': 661,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 662,
#   'end_index': 662,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 663,
#   'end_index': 663,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 664,
#   'end_index': 664,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 665,
#   'end_index': 665,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 666,
#   'end_index': 666,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 667,
#   'end_index': 667,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 668,
#   'end_index': 668,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 669,
#   'end_index': 669,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 644, 'end_index': 659, 'id': 'page-59'},
#  {'label': 'paragraph',
#   'begin_index': 670,
#   'end_index': 671,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 672,
#   'end_index': 672,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 673,
#   'end_index': 673,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 674,
#   'end_index': 674,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 675,
#   'end_index': 675,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 676,
#   'end_index': 676,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 677,
#   'end_index': 677,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 678,
#   'end_index': 678,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 679,
#   'end_index': 679,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 680,
#   'end_index': 680,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 681,
#   'end_index': 681,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 659, 'end_index': 671, 'id': 'page-60'},
#  {'label': 'paragraph',
#   'begin_index': 682,
#   'end_index': 683,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 684,
#   'end_index': 684,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 685,
#   'end_index': 685,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 686,
#   'end_index': 686,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 687,
#   'end_index': 687,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 688,
#   'end_index': 688,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 689,
#   'end_index': 689,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 690,
#   'end_index': 690,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 671, 'end_index': 683, 'id': 'page-61'},
#  {'label': 'paragraph',
#   'begin_index': 691,
#   'end_index': 692,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 693,
#   'end_index': 693,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 694,
#   'end_index': 694,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 695,
#   'end_index': 695,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 696,
#   'end_index': 696,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 697,
#   'end_index': 697,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 698,
#   'end_index': 698,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 699,
#   'end_index': 699,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 700,
#   'end_index': 700,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 701,
#   'end_index': 701,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 702,
#   'end_index': 702,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 703,
#   'end_index': 703,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 704,
#   'end_index': 704,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 705,
#   'end_index': 705,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 706,
#   'end_index': 706,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 683, 'end_index': 692, 'id': 'page-62'},
#  {'label': 'paragraph',
#   'begin_index': 707,
#   'end_index': 707,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 708,
#   'end_index': 708,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 709,
#   'end_index': 709,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 710,
#   'end_index': 710,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 711,
#   'end_index': 711,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 712,
#   'end_index': 712,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 713,
#   'end_index': 713,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 714,
#   'end_index': 714,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 715,
#   'end_index': 715,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 716,
#   'end_index': 716,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 692, 'end_index': 706, 'id': 'page-63'},
#  {'label': 'paragraph',
#   'begin_index': 717,
#   'end_index': 718,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 719,
#   'end_index': 719,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 720,
#   'end_index': 720,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 706, 'end_index': 718, 'id': 'page-64'},
#  {'label': 'paragraph',
#   'begin_index': 721,
#   'end_index': 724,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 725,
#   'end_index': 725,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 726,
#   'end_index': 726,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 727,
#   'end_index': 727,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 728,
#   'end_index': 728,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 729,
#   'end_index': 729,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 730,
#   'end_index': 730,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 731,
#   'end_index': 733,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 718, 'end_index': 733, 'id': 'page-65'},
#  {'label': 'paragraph',
#   'begin_index': 734,
#   'end_index': 734,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 735,
#   'end_index': 735,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 736,
#   'end_index': 736,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 737,
#   'end_index': 737,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 738,
#   'end_index': 738,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 739,
#   'end_index': 739,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 740,
#   'end_index': 740,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 733, 'end_index': 733, 'id': 'page-66'},
#  {'label': 'paragraph',
#   'begin_index': 741,
#   'end_index': 742,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 743,
#   'end_index': 743,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 744,
#   'end_index': 744,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 745,
#   'end_index': 745,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 746,
#   'end_index': 746,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 747,
#   'end_index': 747,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 748,
#   'end_index': 748,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 749,
#   'end_index': 749,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 750,
#   'end_index': 750,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 733, 'end_index': 742, 'id': 'page-67'},
#  {'label': 'paragraph',
#   'begin_index': 751,
#   'end_index': 752,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 753,
#   'end_index': 753,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 754,
#   'end_index': 754,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 755,
#   'end_index': 755,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 756,
#   'end_index': 756,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 757,
#   'end_index': 757,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 742, 'end_index': 752, 'id': 'page-68'},
#  {'label': 'page', 'begin_index': 752, 'end_index': 757, 'id': 'page-69'},
#  {'label': 'paragraph',
#   'begin_index': 758,
#   'end_index': 760,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 761,
#   'end_index': 761,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 762,
#   'end_index': 762,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 757, 'end_index': 760, 'id': 'page-70'},
#  {'label': 'paragraph',
#   'begin_index': 763,
#   'end_index': 763,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 764,
#   'end_index': 764,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 765,
#   'end_index': 765,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 766,
#   'end_index': 766,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 767,
#   'end_index': 767,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 760, 'end_index': 762, 'id': 'page-71'},
#  {'label': 'paragraph',
#   'begin_index': 768,
#   'end_index': 768,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 769,
#   'end_index': 769,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 770,
#   'end_index': 770,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 771,
#   'end_index': 771,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 772,
#   'end_index': 772,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 773,
#   'end_index': 773,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 774,
#   'end_index': 774,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 762, 'end_index': 767, 'id': 'page-72'},
#  {'label': 'paragraph',
#   'begin_index': 775,
#   'end_index': 775,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 776,
#   'end_index': 776,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 767, 'end_index': 774, 'id': 'page-73'},
#  {'label': 'paragraph',
#   'begin_index': 777,
#   'end_index': 778,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 779,
#   'end_index': 779,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 774, 'end_index': 778, 'id': 'page-74'},
#  {'label': 'paragraph',
#   'begin_index': 780,
#   'end_index': 781,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 778, 'end_index': 781, 'id': 'page-75'},
#  {'label': 'paragraph',
#   'begin_index': 782,
#   'end_index': 783,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 784,
#   'end_index': 784,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 785,
#   'end_index': 785,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 786,
#   'end_index': 786,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 787,
#   'end_index': 787,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 788,
#   'end_index': 788,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 789,
#   'end_index': 789,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 790,
#   'end_index': 790,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 791,
#   'end_index': 791,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 781, 'end_index': 783, 'id': 'page-76'},
#  {'label': 'paragraph',
#   'begin_index': 792,
#   'end_index': 792,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 793,
#   'end_index': 793,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 794,
#   'end_index': 794,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 795,
#   'end_index': 795,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 796,
#   'end_index': 796,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 797,
#   'end_index': 797,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 798,
#   'end_index': 798,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 799,
#   'end_index': 799,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 800,
#   'end_index': 800,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 801,
#   'end_index': 801,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 783, 'end_index': 791, 'id': 'page-77'},
#  {'label': 'paragraph',
#   'begin_index': 802,
#   'end_index': 803,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
# ...
#   'end_index': 1110,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1111,
#   'end_index': 1111,
#   'id': 'generate_later'},
#  {'label': 'chapter',
#   'begin_index': 1072,
#   'end_index': 1111,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1096, 'end_index': 1103, 'id': 'page-126'},
#  {'label': 'head',
#   'begin_index': 1112,
#   'end_index': 1112,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1113,
#   'end_index': 1113,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1114,
#   'end_index': 1114,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1115,
#   'end_index': 1115,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1103, 'end_index': 1111, 'id': 'page-127'},
#  {'label': 'paragraph',
#   'begin_index': 1116,
#   'end_index': 1119,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1120,
#   'end_index': 1122,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1111, 'end_index': 1122, 'id': 'page-128'},
#  {'label': 'paragraph',
#   'begin_index': 1123,
#   'end_index': 1126,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1122, 'end_index': 1126, 'id': 'page-129'},
#  {'label': 'page', 'begin_index': 1126, 'end_index': 1126, 'id': 'page-130'},
#  {'label': 'paragraph',
#   'begin_index': 1127,
#   'end_index': 1130,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1131,
#   'end_index': 1131,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1132,
#   'end_index': 1132,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1133,
#   'end_index': 1133,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1134,
#   'end_index': 1134,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1135,
#   'end_index': 1135,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1126, 'end_index': 1130, 'id': 'page-131'},
#  {'label': 'paragraph',
#   'begin_index': 1136,
#   'end_index': 1137,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1138,
#   'end_index': 1138,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1139,
#   'end_index': 1139,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1140,
#   'end_index': 1140,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1141,
#   'end_index': 1141,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1142,
#   'end_index': 1142,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1143,
#   'end_index': 1143,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1144,
#   'end_index': 1144,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1130, 'end_index': 1137, 'id': 'page-132'},
#  {'label': 'paragraph',
#   'begin_index': 1145,
#   'end_index': 1145,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1146,
#   'end_index': 1146,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1147,
#   'end_index': 1147,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1148,
#   'end_index': 1148,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1149,
#   'end_index': 1149,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1150,
#   'end_index': 1150,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1151,
#   'end_index': 1151,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1137, 'end_index': 1144, 'id': 'page-133'},
#  {'label': 'paragraph',
#   'begin_index': 1152,
#   'end_index': 1152,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1153,
#   'end_index': 1153,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1154,
#   'end_index': 1154,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1155,
#   'end_index': 1155,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1156,
#   'end_index': 1156,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1157,
#   'end_index': 1157,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1158,
#   'end_index': 1158,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1144, 'end_index': 1151, 'id': 'page-134'},
#  {'label': 'paragraph',
#   'begin_index': 1159,
#   'end_index': 1158,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1151, 'end_index': 1158, 'id': 'page-*1'},
#  {'label': 'paragraph',
#   'begin_index': 1159,
#   'end_index': 1164,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1165,
#   'end_index': 1165,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1166,
#   'end_index': 1166,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1167,
#   'end_index': 1167,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1168,
#   'end_index': 1168,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1169,
#   'end_index': 1169,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1170,
#   'end_index': 1170,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1171,
#   'end_index': 1171,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1172,
#   'end_index': 1172,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1173,
#   'end_index': 1173,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1174,
#   'end_index': 1174,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1175,
#   'end_index': 1175,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1176,
#   'end_index': 1176,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1177,
#   'end_index': 1177,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1178,
#   'end_index': 1178,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1179,
#   'end_index': 1179,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1180,
#   'end_index': 1180,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1158, 'end_index': 1164, 'id': 'page-135'},
#  {'label': 'paragraph',
#   'begin_index': 1181,
#   'end_index': 1181,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1182,
#   'end_index': 1182,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1183,
#   'end_index': 1183,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1184,
#   'end_index': 1184,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1185,
#   'end_index': 1185,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1186,
#   'end_index': 1186,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1187,
#   'end_index': 1187,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1188,
#   'end_index': 1188,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1189,
#   'end_index': 1189,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1190,
#   'end_index': 1190,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1191,
#   'end_index': 1191,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1192,
#   'end_index': 1192,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1164, 'end_index': 1180, 'id': 'page-136'},
#  {'label': 'paragraph',
#   'begin_index': 1193,
#   'end_index': 1194,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1195,
#   'end_index': 1195,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1196,
#   'end_index': 1196,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1197,
#   'end_index': 1197,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1180, 'end_index': 1194, 'id': 'page-137'},
#  {'label': 'paragraph',
#   'begin_index': 1198,
#   'end_index': 1198,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1199,
#   'end_index': 1199,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1200,
#   'end_index': 1200,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1201,
#   'end_index': 1201,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1202,
#   'end_index': 1202,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1203,
#   'end_index': 1203,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1194, 'end_index': 1197, 'id': 'page-138'},
#  {'label': 'paragraph',
#   'begin_index': 1204,
#   'end_index': 1205,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1206,
#   'end_index': 1206,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1207,
#   'end_index': 1207,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1197, 'end_index': 1205, 'id': 'page-139'},
#  {'label': 'paragraph',
#   'begin_index': 1208,
#   'end_index': 1209,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1210,
#   'end_index': 1212,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1213,
#   'end_index': 1213,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1214,
#   'end_index': 1214,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1215,
#   'end_index': 1215,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1216,
#   'end_index': 1216,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1217,
#   'end_index': 1217,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1205, 'end_index': 1212, 'id': 'page-140'},
#  {'label': 'paragraph',
#   'begin_index': 1218,
#   'end_index': 1219,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1220,
#   'end_index': 1220,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1221,
#   'end_index': 1221,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1222,
#   'end_index': 1222,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1223,
#   'end_index': 1223,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1224,
#   'end_index': 1224,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1225,
#   'end_index': 1225,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1226,
#   'end_index': 1226,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1227,
#   'end_index': 1227,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1228,
#   'end_index': 1228,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1229,
#   'end_index': 1229,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1230,
#   'end_index': 1230,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1212, 'end_index': 1219, 'id': 'page-141'},
#  {'label': 'paragraph',
#   'begin_index': 1231,
#   'end_index': 1231,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1232,
#   'end_index': 1232,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1233,
#   'end_index': 1233,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1234,
#   'end_index': 1234,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1235,
#   'end_index': 1235,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1236,
#   'end_index': 1240,
#   'id': 'generate_later'},
#  {'label': 'chapter',
#   'begin_index': 1112,
#   'end_index': 1240,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1219, 'end_index': 1240, 'id': 'page-142'},
#  {'label': 'head',
#   'begin_index': 1241,
#   'end_index': 1241,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1242,
#   'end_index': 1244,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1240, 'end_index': 1244, 'id': 'page-143'},
#  {'label': 'paragraph',
#   'begin_index': 1245,
#   'end_index': 1246,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1247,
#   'end_index': 1247,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1248,
#   'end_index': 1248,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1249,
#   'end_index': 1249,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1250,
#   'end_index': 1250,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1251,
#   'end_index': 1251,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1252,
#   'end_index': 1252,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1244, 'end_index': 1246, 'id': 'page-144'},
#  {'label': 'paragraph',
#   'begin_index': 1253,
#   'end_index': 1253,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1254,
#   'end_index': 1254,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1255,
#   'end_index': 1255,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1256,
#   'end_index': 1256,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1257,
#   'end_index': 1257,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1258,
#   'end_index': 1258,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1259,
#   'end_index': 1259,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1260,
#   'end_index': 1260,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1246, 'end_index': 1252, 'id': 'page-145'},
#  {'label': 'paragraph',
#   'begin_index': 1261,
#   'end_index': 1262,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1263,
#   'end_index': 1263,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1264,
#   'end_index': 1264,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1265,
#   'end_index': 1265,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1266,
#   'end_index': 1266,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1267,
#   'end_index': 1267,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1268,
#   'end_index': 1268,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1269,
#   'end_index': 1269,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1270,
#   'end_index': 1270,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1271,
#   'end_index': 1271,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1272,
#   'end_index': 1272,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1252, 'end_index': 1262, 'id': 'page-146'},
#  {'label': 'paragraph',
#   'begin_index': 1273,
#   'end_index': 1273,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1274,
#   'end_index': 1274,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1275,
#   'end_index': 1275,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1276,
#   'end_index': 1276,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1277,
#   'end_index': 1277,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1278,
#   'end_index': 1278,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1279,
#   'end_index': 1279,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1280,
#   'end_index': 1280,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1281,
#   'end_index': 1281,
#   'id': 'generate_later'},
#  {'label': 'page', 'begin_index': 1262, 'end_index': 1272, 'id': 'page-147'},
#  {'label': 'paragraph',
#   'begin_index': 1282,
#   'end_index': 1283,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1284,
#   'end_index': 1284,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1285,
#   'end_index': 1285,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1286,
#   'end_index': 1286,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1287,
#   'end_index': 1287,
#   'id': 'generate_later'},
#  {'label': 'paragraph',
#   'begin_index': 1288,
#   'end_index': 1290,
#   'id': 'generate_later'},
#  ...]

# %%
def get_annotations_overlapping_with(begin,end,annotations):
    return (a for a in annotations if (a['begin_index'] >= begin and a['begin_index'] < end) or\
           (a['end_index'] > begin and a['end_index'] <= end) or\
           (a['begin_index'] <= begin and a['end_index'] >= end))

# %%
# print all annotations for a chapter
for a in get_annotations_overlapping_with(636,832,all_annotations):
    print(a)
# Out:
# {'label': 'head', 'begin_index': 636, 'end_index': 636, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 637, 'end_index': 638, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 639, 'end_index': 639, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 640, 'end_index': 640, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 641, 'end_index': 641, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 642, 'end_index': 642, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 643, 'end_index': 643, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 644, 'end_index': 644, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 635, 'end_index': 638, 'id': 'page-57'}
# {'label': 'paragraph', 'begin_index': 645, 'end_index': 645, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 646, 'end_index': 646, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 647, 'end_index': 647, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 648, 'end_index': 648, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 649, 'end_index': 649, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 650, 'end_index': 650, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 651, 'end_index': 651, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 652, 'end_index': 652, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 653, 'end_index': 653, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 654, 'end_index': 654, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 655, 'end_index': 655, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 638, 'end_index': 644, 'id': 'page-58'}
# {'label': 'paragraph', 'begin_index': 656, 'end_index': 659, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 660, 'end_index': 660, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 661, 'end_index': 661, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 662, 'end_index': 662, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 663, 'end_index': 663, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 664, 'end_index': 664, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 665, 'end_index': 665, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 666, 'end_index': 666, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 667, 'end_index': 667, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 668, 'end_index': 668, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 669, 'end_index': 669, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 644, 'end_index': 659, 'id': 'page-59'}
# {'label': 'paragraph', 'begin_index': 670, 'end_index': 671, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 672, 'end_index': 672, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 673, 'end_index': 673, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 674, 'end_index': 674, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 675, 'end_index': 675, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 676, 'end_index': 676, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 677, 'end_index': 677, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 678, 'end_index': 678, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 679, 'end_index': 679, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 680, 'end_index': 680, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 681, 'end_index': 681, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 659, 'end_index': 671, 'id': 'page-60'}
# {'label': 'paragraph', 'begin_index': 682, 'end_index': 683, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 684, 'end_index': 684, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 685, 'end_index': 685, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 686, 'end_index': 686, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 687, 'end_index': 687, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 688, 'end_index': 688, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 689, 'end_index': 689, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 690, 'end_index': 690, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 671, 'end_index': 683, 'id': 'page-61'}
# {'label': 'paragraph', 'begin_index': 691, 'end_index': 692, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 693, 'end_index': 693, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 694, 'end_index': 694, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 695, 'end_index': 695, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 696, 'end_index': 696, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 697, 'end_index': 697, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 698, 'end_index': 698, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 699, 'end_index': 699, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 700, 'end_index': 700, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 701, 'end_index': 701, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 702, 'end_index': 702, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 703, 'end_index': 703, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 704, 'end_index': 704, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 705, 'end_index': 705, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 706, 'end_index': 706, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 683, 'end_index': 692, 'id': 'page-62'}
# {'label': 'paragraph', 'begin_index': 707, 'end_index': 707, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 708, 'end_index': 708, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 709, 'end_index': 709, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 710, 'end_index': 710, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 711, 'end_index': 711, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 712, 'end_index': 712, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 713, 'end_index': 713, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 714, 'end_index': 714, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 715, 'end_index': 715, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 716, 'end_index': 716, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 692, 'end_index': 706, 'id': 'page-63'}
# {'label': 'paragraph', 'begin_index': 717, 'end_index': 718, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 719, 'end_index': 719, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 720, 'end_index': 720, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 706, 'end_index': 718, 'id': 'page-64'}
# {'label': 'paragraph', 'begin_index': 721, 'end_index': 724, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 725, 'end_index': 725, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 726, 'end_index': 726, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 727, 'end_index': 727, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 728, 'end_index': 728, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 729, 'end_index': 729, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 730, 'end_index': 730, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 731, 'end_index': 733, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 718, 'end_index': 733, 'id': 'page-65'}
# {'label': 'paragraph', 'begin_index': 734, 'end_index': 734, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 735, 'end_index': 735, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 736, 'end_index': 736, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 737, 'end_index': 737, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 738, 'end_index': 738, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 739, 'end_index': 739, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 740, 'end_index': 740, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 733, 'end_index': 733, 'id': 'page-66'}
# {'label': 'paragraph', 'begin_index': 741, 'end_index': 742, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 743, 'end_index': 743, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 744, 'end_index': 744, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 745, 'end_index': 745, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 746, 'end_index': 746, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 747, 'end_index': 747, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 748, 'end_index': 748, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 749, 'end_index': 749, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 750, 'end_index': 750, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 733, 'end_index': 742, 'id': 'page-67'}
# {'label': 'paragraph', 'begin_index': 751, 'end_index': 752, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 753, 'end_index': 753, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 754, 'end_index': 754, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 755, 'end_index': 755, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 756, 'end_index': 756, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 757, 'end_index': 757, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 742, 'end_index': 752, 'id': 'page-68'}
# {'label': 'page', 'begin_index': 752, 'end_index': 757, 'id': 'page-69'}
# {'label': 'paragraph', 'begin_index': 758, 'end_index': 760, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 761, 'end_index': 761, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 762, 'end_index': 762, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 757, 'end_index': 760, 'id': 'page-70'}
# {'label': 'paragraph', 'begin_index': 763, 'end_index': 763, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 764, 'end_index': 764, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 765, 'end_index': 765, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 766, 'end_index': 766, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 767, 'end_index': 767, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 760, 'end_index': 762, 'id': 'page-71'}
# {'label': 'paragraph', 'begin_index': 768, 'end_index': 768, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 769, 'end_index': 769, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 770, 'end_index': 770, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 771, 'end_index': 771, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 772, 'end_index': 772, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 773, 'end_index': 773, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 774, 'end_index': 774, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 762, 'end_index': 767, 'id': 'page-72'}
# {'label': 'paragraph', 'begin_index': 775, 'end_index': 775, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 776, 'end_index': 776, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 767, 'end_index': 774, 'id': 'page-73'}
# {'label': 'paragraph', 'begin_index': 777, 'end_index': 778, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 779, 'end_index': 779, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 774, 'end_index': 778, 'id': 'page-74'}
# {'label': 'paragraph', 'begin_index': 780, 'end_index': 781, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 778, 'end_index': 781, 'id': 'page-75'}
# {'label': 'paragraph', 'begin_index': 782, 'end_index': 783, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 784, 'end_index': 784, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 785, 'end_index': 785, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 786, 'end_index': 786, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 787, 'end_index': 787, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 788, 'end_index': 788, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 789, 'end_index': 789, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 790, 'end_index': 790, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 791, 'end_index': 791, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 781, 'end_index': 783, 'id': 'page-76'}
# {'label': 'paragraph', 'begin_index': 792, 'end_index': 792, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 793, 'end_index': 793, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 794, 'end_index': 794, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 795, 'end_index': 795, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 796, 'end_index': 796, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 797, 'end_index': 797, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 798, 'end_index': 798, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 799, 'end_index': 799, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 800, 'end_index': 800, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 801, 'end_index': 801, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 783, 'end_index': 791, 'id': 'page-77'}
# {'label': 'paragraph', 'begin_index': 802, 'end_index': 803, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 804, 'end_index': 804, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 791, 'end_index': 803, 'id': 'page-78'}
# {'label': 'paragraph', 'begin_index': 805, 'end_index': 806, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 807, 'end_index': 807, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 808, 'end_index': 808, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 803, 'end_index': 806, 'id': 'page-79'}
# {'label': 'paragraph', 'begin_index': 809, 'end_index': 810, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 811, 'end_index': 811, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 812, 'end_index': 812, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 806, 'end_index': 810, 'id': 'page-80'}
# {'label': 'paragraph', 'begin_index': 813, 'end_index': 814, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 815, 'end_index': 815, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 816, 'end_index': 816, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 817, 'end_index': 817, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 818, 'end_index': 818, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 819, 'end_index': 819, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 820, 'end_index': 820, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 821, 'end_index': 821, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 810, 'end_index': 814, 'id': 'page-81'}
# {'label': 'paragraph', 'begin_index': 822, 'end_index': 823, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 824, 'end_index': 824, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 825, 'end_index': 825, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 826, 'end_index': 826, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 827, 'end_index': 827, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 828, 'end_index': 828, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 829, 'end_index': 829, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 830, 'end_index': 830, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 831, 'end_index': 831, 'id': 'generate_later'}
# {'label': 'paragraph', 'begin_index': 832, 'end_index': 832, 'id': 'generate_later'}
# {'label': 'chapter', 'begin_index': 636, 'end_index': 832, 'id': 'generate_later'}
# {'label': 'page', 'begin_index': 814, 'end_index': 823, 'id': 'page-82'}
# {'label': 'page', 'begin_index': 823, 'end_index': 836, 'id': 'page-83'}

# %%
# return generator for annotations with a specific label
def get_annotations_of_type(type,annotations):
    return (a for a in annotations if a['label'] == type)

# %%
# nested generators
def get_annotations_of_type_overlapping(type,begin,end,annotations):
    return get_annotations_of_type(type,(get_annotations_overlapping_with(begin,end,annotations)))

# %% [markdown]
# Variations of the above 3 functions, now for multiple types iso for just one type.

# %%
def get_annotations_of_types(types,annotations):
    return (a for a in annotations if a['label'] in types)

# %%
def get_annotations_of_types_overlapping(types,begin,end,annotations):
    return get_annotations_of_types(types,(get_annotations_overlapping_with(begin,end,annotations)))

# %%
def get_textlines_between(begin,end,annotations): 
    textlines = []
    types = ('paragraph', 'head')
    for line_annot in get_annotations_of_types_overlapping(types,begin,end,annotations):
        textlines.append((line_annot['begin_index'],line_annot['end_index'], \
                          all_textelements[line_annot['begin_index']:line_annot['end_index']]))
    return textlines

# %%
# get text for (text segment of) a chapter
for a in get_textlines_between(636,832,all_annotations):
    print(a)
# Out:
# (636, 636, [])
# (637, 638, ["Met eene snelheid als die van het licht had zich het gerucht door gansch Londen verspreid, dat de edele Graaf van Devonshire met uitstekende eer ten hove ontvangen, in zijne rechtmatige bezittingen hersteld geworden en met een aantal gunsten overladen was. Bij de verwardheid van zoodanige volksgeruchten ontbrak het ook niet aan de noodige ongerijmdheden en overdrijvingen. Doch hoe uiteenloopend de lezingen over zijn plechtig onthaal op Whitehall ook mochten zijn, daarin waren allen, protestanten zoowel als katholieken, burgers zoowel als krijgsknechten, van den Lord-Mayor en zijne aldermen tot de schamele bewoners der afgelegenste dwarsstegen, het eens, dat dezen edelman geene zoo hooge eer kon bewezen worden, die zij allen hem niet waardig keurden. Ook verdrong men zich op die plaatsen, waar men hem nog dien eigen dag meende te zullen zien. Eene samengeschoolde volksmenigte leverde toenmaals, behoudens eenige karakteristieke uitzonderingen van tijd en volksaard, hetzelfde schouwspel op, dat men nog heden in elke hoofdstad, waar de talrijke menschenmassa's der lagere volksklassen zich verzamelen, kan waarnemen. Het waren dezelfde opgeruide hartstochten, dezelfde schelle, ruwe, luidruchtige onbewimpelde taal. Het was dezelfde vermetele nieuwsgierigheid, om het voorwerp der algemeene aandacht van nabij te zien, en vechtpartijen om anderhalven voet gronds. Men vond er, evenals"])
# (639, 639, [])
# (640, 640, [])
# (641, 641, [])
# (642, 642, [])
# (643, 643, [])
# (644, 644, [])
# (645, 645, [])
# (646, 646, [])
# (647, 647, [])
# (648, 648, [])
# (649, 649, [])
# (650, 650, [])
# (651, 651, [])
# (652, 652, [])
# (653, 653, [])
# (654, 654, [])
# (655, 655, [])
# (656, 659, ['‘Hei, hei, Maggie Snowpust! oude leelijke tooverheks! meen je mij weg te dringen,', 'dam you!', 'Heb het hart daartoe! Het was je dan beter op een bezemsteel door de lucht te rijden,’ grauwde haar een man toe. Niet alle omstanders waren van'])
# (660, 660, [])
# (661, 661, [])
# (662, 662, [])
# (663, 663, [])
# (664, 664, [])
# (665, 665, [])
# (666, 666, [])
# (667, 667, [])
# (668, 668, [])
# (669, 669, [])
# (670, 671, ['‘Lang zal hij leven, de edele Graaf Courtenay! God zegene onzen Devonshire! Heil zij den zoon der Yorks! den dappersten edelman van Engeland, den edelmoedigste, den mildadigste! Mogen de heiligen al zijne wenschen vervullen! Hij worde onze Koning!’ schreeuwde de smid met uitbundige woestheid. ‘Ja, ja! zoo'])
# (672, 672, [])
# (673, 673, [])
# (674, 674, [])
# (675, 675, [])
# (676, 676, [])
# (677, 677, [])
# (678, 678, [])
# (679, 679, [])
# (680, 680, [])
# (681, 681, [])
# (682, 683, ['‘Zij leve! Leve Maria! leve Courtenay!’ galmde het op nieuw,'])
# (684, 684, [])
# (685, 685, [])
# (686, 686, [])
# (687, 687, [])
# (688, 688, [])
# (689, 689, [])
# (690, 690, [])
# (691, 692, ['Hier werd de Graaf door zijne zuster ontvangen met al de levendige blijdschap van haar vurig karakter. Driftig voerde zij hem naar haar bijzonder vertrek, een ongemeen zwierig boudoir uit dien tijd eene soort van vrouwelijk heiligdom, op welks beschrijving wij nader zullen terugkomen. Met een wenk riep'])
# (693, 693, [])
# (694, 694, [])
# (695, 695, [])
# (696, 696, [])
# (697, 697, [])
# (698, 698, [])
# (699, 699, [])
# (700, 700, [])
# (701, 701, [])
# (702, 702, [])
# (703, 703, [])
# (704, 704, [])
# (705, 705, [])
# (706, 706, [])
# (707, 707, [])
# (708, 708, [])
# (709, 709, [])
# (710, 710, [])
# (711, 711, [])
# (712, 712, [])
# (713, 713, [])
# (714, 714, [])
# (715, 715, [])
# (716, 716, [])
# (717, 718, ['‘Gij zoudt u vermaakt hebben, Mylady,’ hervatte Chandos, ‘als gij getuige waart geweest van de blijdschap des volks bij'])
# (719, 719, [])
# (720, 720, [])
# (721, 724, ["‘Dat vraag ik mij zelven dikwijls af. Eigenlijk is de voorkeur van het volk op mij gevallen, als de liefde van een onbedacht jongeling op een jong meisje, zonder dat beiden er zich rekenschap van weten te geven, en het is maar al te zeker, dat beiden hun afgod te meer vereeren, naarmate zij minder weten waarom. Het is waar, ik ben gemeenzaam jegens allen en zie niet op een vriendelijk woord en wat goud, zoo ik hen daarmede helpen kan.’ - Hier bleef de Lord eenige oogenblikken als in diep nadenken verzonken, en vervolgde toen met warme geestdrift terwijl zijn edel gelaat en zielvol oog eene roerende uitdrukking van goedheid en innige overtuiging aannamen: ‘O, men heeft zich nog niet verwaardigd, het groote, doch vaak miskende deel onzer natie, dat men het gemeen noemt, met opmerkzame menschenliefde en menschenkennis gade te slaan. En toch zijn zij het waardig, die massa's uit den lagen burgerstand. Zij alleen behouden het eigenaardige volkskarakter, waar de beschaving het bij ons effent en uitroeit. Zegt mij, is", 'hij', 'een Engelschman, de hoveling, die zich plooit naar elke luim van zijn gebieder; die voor vorstengunst vergeet dat hij een vaderland heeft, dat hij zelfstandig mensch is? Kan hij een eigen karakter toonen, hij, die als de kameleon de kleur aanneemt van hem op wien zijne eerzucht staart? Evenwel zoude diezelfde edelman zich verontwaardigen, als men hem zeide dat'])
# (725, 725, [])
# (726, 726, [])
# (727, 727, [])
# (728, 728, [])
# (729, 729, [])
# (730, 730, [])
# (731, 733, ['‘O, wat dat betreft, ik wenschte dat', 'ik'])
# (734, 734, [])
# (735, 735, [])
# (736, 736, [])
# (737, 737, [])
# (738, 738, [])
# (739, 739, [])
# (740, 740, [])
# (741, 742, ['‘Ja, gij behoeft een echtgenoot, een man die het recht heeft u te beschermen tegen den laster en de aantijgingen, waarmede men uwe levenswijze en karakter bevlekt. Ik weet het, ze zijn'])
# (743, 743, [])
# (744, 744, [])
# (745, 745, [])
# (746, 746, [])
# (747, 747, [])
# (748, 748, [])
# (749, 749, [])
# (750, 750, [])
# (751, 752, ['‘Vergeef mij, mevrouw, ik kwam slechts ten geleide van Mylord'])
# (753, 753, [])
# (754, 754, [])
# (755, 755, [])
# (756, 756, [])
# (757, 757, [])
# (758, 760, ['Lady Arabella Courtenay was eene vrouw van meer dan gewone schoonheid; zij bezat al de boeiende bekoorlijkheden en vele der deugden van hare sekse, maar ruim vermengd met eigenaardige zwakheden en gebreken. Zoo bezat zij een fijn opmerkenden geest en eene onuitputtelijke goedheid van hart. Doch de eerste werd veelal nutteloos gemaakt door eene verregaande loszinnigheid en zorgeloosheid, en de andere ontluisterd door overdreven behaagzucht. Zoo bezat zij oorspronkelijkheid en fijn gevoel voor het schoone, maar door zonderlingheid en toomelooze prachtliefde verdorven. Haar oordeel zoude haar een veilige gids zijn geweest, doch zij had zich gewend het onstuimig geroep der hartstochten eerder gehoor te gunnen dan den bedaarden, maar vasten toon der kalme beradenheid. En toch was zij in geheel bezondere omstandigheden geplaatst, die de leiding der koele rede zoo noodzakelijk maakten. Hare moeder was haar ontvallen op een leeftijd, waarin zij ieder ander dan moederlijk opzicht ontgroeid was. Haar vader, de oude Graaf Sterny, te veel in allerlei staatkundige betrekkingen gewikkeld om over zijne dochter te kunnen waken, verheugde zich, als hij haar nu en dan zag, slechts over de ontwikkeling', 'harer schoonheid, en toen er later over hare talenten en beschaving maar ééne stem opging, hield hij hare opvoeding voor voltooid en liet haar gerust aan haar zelve over, zich in het vervolg slechts verwonderende, dat zij uit zoovele edele, bevallige jongelingen, die naar hare hand dongen, geene keuze scheen te kunnen doen. Bij zijn toenemenden ouderdom bedroefde hij zich over deze eigenzinnigheid en hij zoude misschien tot vaderlijken dwang zijn overgegaan, indien de dood des Konings en de daarop volgende staatkundige beroerten, waarin hij en zijn zoon op zulk eene schrikkelijke wijze gewikkeld werden, niet verhinderd waren tusschen beide getreden. Arabella, hoewel vier jaren ouder dan haar broeder, had zich echter nooit met staatkundige of godsdienstige partijschap ingelaten. Zij had vrienden en aanbidders onder elke partij, van elke kleur, en zij had tusschen hen nooit eenig ander onderscheid gemaakt, dan luim of smaak haar ingaf. Zij had niet geaarzeld, zich aan de voeten van Northumberland te werpen, om het leven haars vaders en de vrijheid eens innig geliefden broeders af te smeeken, doch met geene andere uitkomst dan eenige persoonlijke voordeelen voor haar zelve, zooals het behoud van Sterny-House en van haar aanzienlijk moederlijk vermogen, dat eigenlijk aan onzen Graaf Courtenay behoorde, als eenige zoon zijner ouders; - daarom noemde zich Arabella ook altijd zijne rentmeesteresse en had hij enkele malen zonder omstandigheden uit hare beurs geput. Met ongemeene hartstochtelijkheid had zij haars vaders gewelddadigen dood betreurd, maar toen de tranen eenmaal waren afgewischt en het rouwgewaad weggeworpen, had zij haar huis in eene eeuwigdurende feestzaal herschapen; zij was als iemand, die zich bedwelmen wil in een langen roes van zinvermaak en zelfvergeten. Zij zag allen, die haar zien wilden, en daar zij eene uitstekend schoone vrouw was, in wier vernuft en levendigheid de meesten smaak vonden, zag zij rondom zich allen vereenigd, die op beschaving, geest en scherp oordeel aanspraak konden maken, of die zich door rang en vermogen tot haar omgang gerechtigd achtten. De diepe afzondering, waarin de geestrijke prinses Elisabeth leefde, werkte misschien daartoe mede. De meer degelijke kennis en diepzin-'])
# (761, 761, [])
# (762, 762, [])
# (763, 763, [])
# (764, 764, [])
# (765, 765, [])
# (766, 766, [])
# (767, 767, [])
# (768, 768, [])
# (769, 769, [])
# (770, 770, [])
# (771, 771, [])
# (772, 772, [])
# (773, 773, [])
# (774, 774, [])
# (775, 775, [])
# (776, 776, [])
# (777, 778, ['‘Jezus Maria! monster! Dat was satan zelf!’ gilde de ongelukkige, toen hij zich met snelle schreden verwijderde. Zij deed eene poging om van de noodlottige plaats weg te vluchten, dan, ze viel bewusteloos op de trappen van het altaar neder. Zóó werd zij gevonden door hare kamervrouw, die haar met onrust gezocht had; deze voerde haar, met behulp van andere lieden, in een draagstoel naar Sterny-House. De Lord was afwezend; zijn zoon nog een kind. Na eene hevige ziekte, die haar misschien voor krankzinnigheid bewaarde, kwam zij weder tot bezinning. Zij zoude alles voor een bangen droom of een schrikkelijk'])
# (779, 779, [])
# (780, 781, ['‘Ik had,’ dus schreef hij, ‘een geweldiger middel kunnen bezigen, doch uw dood was geene volstrekte noodzakelijkheid: ik gebruikte medelijden met uwe jeugd en levenslust. Ik had u lang bespied en eene zwakheid in u opgespoord; op deze werkte ik: uwe zucht tot het buitengewone leverde u in mijne handen en redde u tevens het leven; want ware mij de list mislukt, dan had ik gebruik gemaakt van het recht der sterkeren. Voor het overige hebt gij in mij, ik erken het, een somberen echtge-'])
# (782, 783, ['Van tijd tot tijd ontving zij zulke brieven vol bitter vernuft en in wrangen, snijdenden stijl. Een vreemde marskramer was er de zwijgende brenger van. Dat waren dan telkens scherpe prikkels der herinnering, zonder welke de loszinnige en jeugdige vrouw, na zoovele jaren, het gebeurde misschien zoude beschouwd hebben als ware het niet voorgevallen. Bevallig en bevallende, ontbrak het haar nimmer aan bewonderaars; te behaagziek om ze van zich te weren, hield zij zich echter op genoegzamen afstand om ernstige aanzoeken te voorkomen, of zij verschanste zich daartoe achter losse scherts en ijskoude onverschilligheid, die de meesten terugschrikten. Zoo was zij reeds haar dertigste jaar genaderd, toen zij voor Chandos eene wezenlijke liefde opvatte. Nu eerst besefte zij het onderscheid tusschen het wilde, zonderlinge vuur, dat haar eenmaal bij het aanschouwen van den onbekende doorgloeid had, en de kalme en zielverheffende aandoening, die haar bij het denken aan Chandos beving; het onderscheid tusschen hartstocht en liefde. Doch nu eerst bevatte zij, welk geluk zij voor altijd verloren had, en aan welk een martelrad van grenzenloos lijden zij zich zelve had laten vast-'])
# (784, 784, [])
# (785, 785, [])
# (786, 786, [])
# (787, 787, [])
# (788, 788, [])
# (789, 789, [])
# (790, 790, [])
# (791, 791, [])
# (792, 792, [])
# (793, 793, [])
# (794, 794, [])
# (795, 795, [])
# (796, 796, [])
# (797, 797, [])
# (798, 798, [])
# (799, 799, [])
# (800, 800, [])
# (801, 801, [])
# (802, 803, ['Deze boog zich zwijgend en ging. ‘Ons alleen!’ riep hij verachtelijk, toen hij zich buiten het vertrek bevond; ‘een bloedverwant zendt hij van zich als een loonknecht, om aan een'])
# (804, 804, [])
# (805, 806, ['‘Ja, Graaf! ik heb hem gesproken,’ dus nam Staunton het woord, toen Darley vertrokken was. ‘Hij was te voet en wan-'])
# (807, 807, [])
# (808, 808, [])
# (809, 810, ['‘Dat zoude zeker eene zeer gelukkige uitkomst zijn; maar'])
# (811, 811, [])
# (812, 812, [])
# (813, 814, ['‘Goede Yorick, ik weet hoe oprecht gij het met mij meent, hoe hartelijk gij aan mij gehecht zijt, doch gij doet mij lachen; het is alsof gij een ziener waart uit uwe Hooglanden, met uwe'])
# (815, 815, [])
# (816, 816, [])
# (817, 817, [])
# (818, 818, [])
# (819, 819, [])
# (820, 820, [])
# (821, 821, [])
# (822, 823, ['Een uur later zat de Graaf van Devonshire, in eene meer vrije huiskleeding, aan eene tafel van massief ebbenhout, met ingespannen aandacht te schrijven. Het waren oogenschijnlijk aangename gewaarwordingen die hem thans vervulden. Zijn edel voorhoofd was onbewolkt, een lichte blos van genoegen kleurde zijn innemend gelaat, een zacht vuur straalde uit zijne groote, zwaarmoedige oogen. Soms staarde hij met een glimlach op het geschrevene, dan weder liet hij het hoofd in dwepende mijme-'])
# (824, 824, [])
# (825, 825, [])
# (826, 826, [])
# (827, 827, [])
# (828, 828, [])
# (829, 829, [])
# (830, 830, [])
# (831, 831, [])
# (832, 832, [])

# %% [markdown]
# Gebruik bovenstaande voor het visualiseren van alle tekst voor een pagina, of alle heads (vanaf het midden van het boek)

# %%
for a in get_annotations_of_type('page', all_annotations):
    if a['id'] == 'page-116':
        print(a)
# Out:
# {'label': 'page', 'begin_index': 1036, 'end_index': 1042, 'id': 'page-116'}

# %%
for tl in get_textlines_between(1036,1042,all_annotations):
    print(tl)
# Out:
# (1037, 1037, [])
# (1038, 1038, [])
# (1039, 1039, [])
# (1040, 1040, [])
# (1041, 1042, ['Nog slechts ten deele hersteld van de verschillende aandoeningen, die zijn gemoed geschokt hadden, liep de Graaf van Devonshire eene der gewone hofzalen binnen. Men zegt hem dat de Koningin naar hem gevraagd heeft; men wijst hem het vertrek aan waar zij zich bevindt; hij begeeft zich daarheen; hij ziet er den Kanselier en Benefield bij haar. Eensklaps is het hem duidelijk, dat dit tot eene vreeselijke ontknooping leiden kan, dat beiden met elkander in betrekking kunnen staan en het eens tot zijn verderf. Als wij een belangrijk geheim met ons omgedragen, is het ons alsof elk onzer bewegingen dat'])

# %% [markdown]
# ISSUE: bovenstaande haalt alle overlappende paragrafen en heads op, maar zou moeten afbreken bij de page breaks die binnen paragrafen optreden. De kleinste basissegmenten zouden moeten worden opgehaald. Wat ontbreekt, is het equivalent van de lines, zoals in de republic casus.
#
# Wat wel moet gebeuren: voor een end of paragraph moeten niet alle textonderdelen worden gejoined, maar allemaal afzonderlijk worden toegevoegd aan all_textelements. Vervolgens moet een paragraph annotation worden aangemaakt over al deze onderdelen.

# %%
for t in all_textelements[1036:1042]:
    print(f"{t}\n")
# Out:
# dedigen. Het ware hem wellust geweest, slechts eens den zoeten naam der geliefde voor een vertrouwd oor te mogen uitspreken. En toch moest hij laaghartig en zelfzuchtig schijnen, en toch gevoelde hij dat de ander niet meer gelooven kon aan de goedheid van zijn hart, toen hij antwoordde, zooals zijn gegeven woord het eischte:
#
# ‘Neen, Arundel, neen! ik kan haar niet helpen; voor haar vermag ik niets; vooralsnog niets;... misschien in het vervolg;... wie weet.... geloof mij, mijn vriend, laat ons geduld hebben.’
#
# ‘Dus heeft de beklagenswaardige ook u verloren,’ hervatte de Groot-Kamerheer koel en met stugheid. ‘Ik moet u nog met eene vraag lastig vallen, Mylord; het is de laatste over dit onderwerp. Zult gij mij tegen zijn, zoo ik in haar voordeel spreek?’
#
# ‘Op mijn ridderwoord, neen!’ riep Devonshire schielijk; zijne oogen schitterden van vreugde over eene uitkomst, die zoozeer met zijne wenschen instemde en hij stond op en vatte Arundel bij de hand. Zoo brandend jaagde het bloed hem door de aderen, dat de andere, door het gloeien van die hand verschrikt, de zijne terugtrok als had hij op gloeiend ijzer getast, doch de Grraaf hield die vast en sprak met zichtbare vervoering: ‘Neem mijn dank, edele man! mijn innigsten dank, dat ik u zoo heb leeren kennnen,’ en snel, eer Arundel antwoorden kon, had hij hem verlaten.
#
# ‘Bij God! dien man begrijp ik niet!’ riep de Groot-Kamerheer hem in verbazing naziende.
#
# Nog slechts ten deele hersteld van de verschillende aandoeningen, die zijn gemoed geschokt hadden, liep de Graaf van Devonshire eene der gewone hofzalen binnen. Men zegt hem dat de Koningin naar hem gevraagd heeft; men wijst hem het vertrek aan waar zij zich bevindt; hij begeeft zich daarheen; hij ziet er den Kanselier en Benefield bij haar. Eensklaps is het hem duidelijk, dat dit tot eene vreeselijke ontknooping leiden kan, dat beiden met elkander in betrekking kunnen staan en het eens tot zijn verderf. Als wij een belangrijk geheim met ons omgedragen, is het ons alsof elk onzer bewegingen dat

# %%
for a in get_annotations_of_type('page', all_annotations):
    print(a)
# Out:
# {'label': 'page', 'begin_index': 0, 'end_index': 295, 'id': ''}
# {'label': 'page', 'begin_index': 295, 'end_index': 297, 'id': 'page-IV'}
# {'label': 'page', 'begin_index': 297, 'end_index': 297, 'id': 'page-1'}
# {'label': 'page', 'begin_index': 297, 'end_index': 298, 'id': 'page-3'}
# {'label': 'page', 'begin_index': 298, 'end_index': 302, 'id': 'page-4'}
# {'label': 'page', 'begin_index': 302, 'end_index': 315, 'id': 'page-5'}
# {'label': 'page', 'begin_index': 315, 'end_index': 319, 'id': 'page-6'}
# {'label': 'page', 'begin_index': 319, 'end_index': 325, 'id': 'page-7'}
# {'label': 'page', 'begin_index': 325, 'end_index': 331, 'id': 'page-8'}
# {'label': 'page', 'begin_index': 331, 'end_index': 334, 'id': 'page-9'}
# {'label': 'page', 'begin_index': 334, 'end_index': 344, 'id': 'page-10'}
# {'label': 'page', 'begin_index': 344, 'end_index': 350, 'id': 'page-11'}
# {'label': 'page', 'begin_index': 350, 'end_index': 350, 'id': 'page-12'}
# {'label': 'page', 'begin_index': 350, 'end_index': 350, 'id': 'page-13'}
# {'label': 'page', 'begin_index': 350, 'end_index': 356, 'id': 'page-14'}
# {'label': 'page', 'begin_index': 356, 'end_index': 358, 'id': 'page-15'}
# {'label': 'page', 'begin_index': 358, 'end_index': 366, 'id': 'page-16'}
# {'label': 'page', 'begin_index': 366, 'end_index': 368, 'id': 'page-17'}
# {'label': 'page', 'begin_index': 368, 'end_index': 372, 'id': 'page-18'}
# {'label': 'page', 'begin_index': 372, 'end_index': 383, 'id': 'page-19'}
# {'label': 'page', 'begin_index': 383, 'end_index': 386, 'id': 'page-20'}
# {'label': 'page', 'begin_index': 386, 'end_index': 394, 'id': 'page-21'}
# {'label': 'page', 'begin_index': 394, 'end_index': 404, 'id': 'page-22'}
# {'label': 'page', 'begin_index': 404, 'end_index': 406, 'id': 'page-23'}
# {'label': 'page', 'begin_index': 406, 'end_index': 409, 'id': 'page-24'}
# {'label': 'page', 'begin_index': 409, 'end_index': 414, 'id': 'page-25'}
# {'label': 'page', 'begin_index': 414, 'end_index': 429, 'id': 'page-26'}
# {'label': 'page', 'begin_index': 429, 'end_index': 439, 'id': 'page-27'}
# {'label': 'page', 'begin_index': 439, 'end_index': 445, 'id': 'page-28'}
# {'label': 'page', 'begin_index': 445, 'end_index': 456, 'id': 'page-29'}
# {'label': 'page', 'begin_index': 456, 'end_index': 463, 'id': 'page-30'}
# {'label': 'page', 'begin_index': 463, 'end_index': 469, 'id': 'page-31'}
# {'label': 'page', 'begin_index': 469, 'end_index': 476, 'id': 'page-32'}
# {'label': 'page', 'begin_index': 476, 'end_index': 486, 'id': 'page-33'}
# {'label': 'page', 'begin_index': 486, 'end_index': 491, 'id': 'page-34'}
# {'label': 'page', 'begin_index': 491, 'end_index': 494, 'id': 'page-35'}
# {'label': 'page', 'begin_index': 494, 'end_index': 500, 'id': 'page-36'}
# {'label': 'page', 'begin_index': 500, 'end_index': 507, 'id': 'page-37'}
# {'label': 'page', 'begin_index': 507, 'end_index': 519, 'id': 'page-38'}
# {'label': 'page', 'begin_index': 519, 'end_index': 526, 'id': 'page-39'}
# {'label': 'page', 'begin_index': 526, 'end_index': 530, 'id': 'page-40'}
# {'label': 'page', 'begin_index': 530, 'end_index': 538, 'id': 'page-41'}
# {'label': 'page', 'begin_index': 538, 'end_index': 552, 'id': 'page-42'}
# {'label': 'page', 'begin_index': 552, 'end_index': 554, 'id': 'page-43'}
# {'label': 'page', 'begin_index': 554, 'end_index': 557, 'id': 'page-44'}
# {'label': 'page', 'begin_index': 557, 'end_index': 562, 'id': 'page-45'}
# {'label': 'page', 'begin_index': 562, 'end_index': 579, 'id': 'page-46'}
# {'label': 'page', 'begin_index': 579, 'end_index': 583, 'id': 'page-47'}
# {'label': 'page', 'begin_index': 583, 'end_index': 590, 'id': 'page-48'}
# {'label': 'page', 'begin_index': 590, 'end_index': 598, 'id': 'page-49'}
# {'label': 'page', 'begin_index': 598, 'end_index': 610, 'id': 'page-50'}
# {'label': 'page', 'begin_index': 610, 'end_index': 614, 'id': 'page-51'}
# {'label': 'page', 'begin_index': 614, 'end_index': 619, 'id': 'page-52'}
# {'label': 'page', 'begin_index': 619, 'end_index': 627, 'id': 'page-53'}
# {'label': 'page', 'begin_index': 627, 'end_index': 632, 'id': 'page-54'}
# {'label': 'page', 'begin_index': 632, 'end_index': 635, 'id': 'page-55'}
# {'label': 'page', 'begin_index': 635, 'end_index': 635, 'id': 'page-56'}
# {'label': 'page', 'begin_index': 635, 'end_index': 638, 'id': 'page-57'}
# {'label': 'page', 'begin_index': 638, 'end_index': 644, 'id': 'page-58'}
# {'label': 'page', 'begin_index': 644, 'end_index': 659, 'id': 'page-59'}
# {'label': 'page', 'begin_index': 659, 'end_index': 671, 'id': 'page-60'}
# {'label': 'page', 'begin_index': 671, 'end_index': 683, 'id': 'page-61'}
# {'label': 'page', 'begin_index': 683, 'end_index': 692, 'id': 'page-62'}
# {'label': 'page', 'begin_index': 692, 'end_index': 706, 'id': 'page-63'}
# {'label': 'page', 'begin_index': 706, 'end_index': 718, 'id': 'page-64'}
# {'label': 'page', 'begin_index': 718, 'end_index': 733, 'id': 'page-65'}
# {'label': 'page', 'begin_index': 733, 'end_index': 733, 'id': 'page-66'}
# {'label': 'page', 'begin_index': 733, 'end_index': 742, 'id': 'page-67'}
# {'label': 'page', 'begin_index': 742, 'end_index': 752, 'id': 'page-68'}
# {'label': 'page', 'begin_index': 752, 'end_index': 757, 'id': 'page-69'}
# {'label': 'page', 'begin_index': 757, 'end_index': 760, 'id': 'page-70'}
# {'label': 'page', 'begin_index': 760, 'end_index': 762, 'id': 'page-71'}
# {'label': 'page', 'begin_index': 762, 'end_index': 767, 'id': 'page-72'}
# {'label': 'page', 'begin_index': 767, 'end_index': 774, 'id': 'page-73'}
# {'label': 'page', 'begin_index': 774, 'end_index': 778, 'id': 'page-74'}
# {'label': 'page', 'begin_index': 778, 'end_index': 781, 'id': 'page-75'}
# {'label': 'page', 'begin_index': 781, 'end_index': 783, 'id': 'page-76'}
# {'label': 'page', 'begin_index': 783, 'end_index': 791, 'id': 'page-77'}
# {'label': 'page', 'begin_index': 791, 'end_index': 803, 'id': 'page-78'}
# {'label': 'page', 'begin_index': 803, 'end_index': 806, 'id': 'page-79'}
# {'label': 'page', 'begin_index': 806, 'end_index': 810, 'id': 'page-80'}
# {'label': 'page', 'begin_index': 810, 'end_index': 814, 'id': 'page-81'}
# {'label': 'page', 'begin_index': 814, 'end_index': 823, 'id': 'page-82'}
# {'label': 'page', 'begin_index': 823, 'end_index': 836, 'id': 'page-83'}
# {'label': 'page', 'begin_index': 836, 'end_index': 840, 'id': 'page-84'}
# {'label': 'page', 'begin_index': 840, 'end_index': 850, 'id': 'page-85'}
# {'label': 'page', 'begin_index': 850, 'end_index': 862, 'id': 'page-86'}
# {'label': 'page', 'begin_index': 862, 'end_index': 867, 'id': 'page-87'}
# {'label': 'page', 'begin_index': 867, 'end_index': 875, 'id': 'page-88'}
# {'label': 'page', 'begin_index': 875, 'end_index': 880, 'id': 'page-89'}
# {'label': 'page', 'begin_index': 880, 'end_index': 881, 'id': 'page-90'}
# {'label': 'page', 'begin_index': 881, 'end_index': 883, 'id': 'page-91'}
# {'label': 'page', 'begin_index': 883, 'end_index': 894, 'id': 'page-92'}
# {'label': 'page', 'begin_index': 894, 'end_index': 912, 'id': 'page-93'}
# {'label': 'page', 'begin_index': 912, 'end_index': 923, 'id': 'page-94'}
# {'label': 'page', 'begin_index': 923, 'end_index': 930, 'id': 'page-95'}
# {'label': 'page', 'begin_index': 930, 'end_index': 937, 'id': 'page-96'}
# {'label': 'page', 'begin_index': 937, 'end_index': 944, 'id': 'page-97'}
# {'label': 'page', 'begin_index': 944, 'end_index': 948, 'id': 'page-98'}
# {'label': 'page', 'begin_index': 948, 'end_index': 955, 'id': 'page-99'}
# {'label': 'page', 'begin_index': 955, 'end_index': 961, 'id': 'page-100'}
# {'label': 'page', 'begin_index': 961, 'end_index': 967, 'id': 'page-101'}
# {'label': 'page', 'begin_index': 967, 'end_index': 970, 'id': 'page-102'}
# {'label': 'page', 'begin_index': 970, 'end_index': 973, 'id': 'page-103'}
# {'label': 'page', 'begin_index': 973, 'end_index': 975, 'id': 'page-104'}
# {'label': 'page', 'begin_index': 975, 'end_index': 977, 'id': 'page-105'}
# {'label': 'page', 'begin_index': 977, 'end_index': 978, 'id': 'page-106'}
# {'label': 'page', 'begin_index': 978, 'end_index': 981, 'id': 'page-107'}
# {'label': 'page', 'begin_index': 981, 'end_index': 981, 'id': 'page-108'}
# {'label': 'page', 'begin_index': 981, 'end_index': 984, 'id': 'page-109'}
# {'label': 'page', 'begin_index': 984, 'end_index': 986, 'id': 'page-110'}
# {'label': 'page', 'begin_index': 986, 'end_index': 1002, 'id': 'page-111'}
# {'label': 'page', 'begin_index': 1002, 'end_index': 1006, 'id': 'page-112'}
# {'label': 'page', 'begin_index': 1006, 'end_index': 1026, 'id': 'page-113'}
# {'label': 'page', 'begin_index': 1026, 'end_index': 1028, 'id': 'page-114'}
# {'label': 'page', 'begin_index': 1028, 'end_index': 1036, 'id': 'page-115'}
# {'label': 'page', 'begin_index': 1036, 'end_index': 1042, 'id': 'page-116'}
# {'label': 'page', 'begin_index': 1042, 'end_index': 1045, 'id': 'page-117'}
# {'label': 'page', 'begin_index': 1045, 'end_index': 1048, 'id': 'page-118'}
# {'label': 'page', 'begin_index': 1048, 'end_index': 1056, 'id': 'page-119'}
# {'label': 'page', 'begin_index': 1056, 'end_index': 1067, 'id': 'page-120'}
# {'label': 'page', 'begin_index': 1067, 'end_index': 1071, 'id': 'page-121'}
# {'label': 'page', 'begin_index': 1071, 'end_index': 1075, 'id': 'page-122'}
# {'label': 'page', 'begin_index': 1075, 'end_index': 1077, 'id': 'page-123'}
# {'label': 'page', 'begin_index': 1077, 'end_index': 1085, 'id': 'page-124'}
# {'label': 'page', 'begin_index': 1085, 'end_index': 1096, 'id': 'page-125'}
# {'label': 'page', 'begin_index': 1096, 'end_index': 1103, 'id': 'page-126'}
# {'label': 'page', 'begin_index': 1103, 'end_index': 1111, 'id': 'page-127'}
# {'label': 'page', 'begin_index': 1111, 'end_index': 1122, 'id': 'page-128'}
# {'label': 'page', 'begin_index': 1122, 'end_index': 1126, 'id': 'page-129'}
# {'label': 'page', 'begin_index': 1126, 'end_index': 1126, 'id': 'page-130'}
# {'label': 'page', 'begin_index': 1126, 'end_index': 1130, 'id': 'page-131'}
# {'label': 'page', 'begin_index': 1130, 'end_index': 1137, 'id': 'page-132'}
# {'label': 'page', 'begin_index': 1137, 'end_index': 1144, 'id': 'page-133'}
# {'label': 'page', 'begin_index': 1144, 'end_index': 1151, 'id': 'page-134'}
# {'label': 'page', 'begin_index': 1151, 'end_index': 1158, 'id': 'page-*1'}
# {'label': 'page', 'begin_index': 1158, 'end_index': 1164, 'id': 'page-135'}
# {'label': 'page', 'begin_index': 1164, 'end_index': 1180, 'id': 'page-136'}
# {'label': 'page', 'begin_index': 1180, 'end_index': 1194, 'id': 'page-137'}
# {'label': 'page', 'begin_index': 1194, 'end_index': 1197, 'id': 'page-138'}
# {'label': 'page', 'begin_index': 1197, 'end_index': 1205, 'id': 'page-139'}
# {'label': 'page', 'begin_index': 1205, 'end_index': 1212, 'id': 'page-140'}
# {'label': 'page', 'begin_index': 1212, 'end_index': 1219, 'id': 'page-141'}
# {'label': 'page', 'begin_index': 1219, 'end_index': 1240, 'id': 'page-142'}
# {'label': 'page', 'begin_index': 1240, 'end_index': 1244, 'id': 'page-143'}
# {'label': 'page', 'begin_index': 1244, 'end_index': 1246, 'id': 'page-144'}
# {'label': 'page', 'begin_index': 1246, 'end_index': 1252, 'id': 'page-145'}
# {'label': 'page', 'begin_index': 1252, 'end_index': 1262, 'id': 'page-146'}
# {'label': 'page', 'begin_index': 1262, 'end_index': 1272, 'id': 'page-147'}
# {'label': 'page', 'begin_index': 1272, 'end_index': 1290, 'id': 'page-148'}
# {'label': 'page', 'begin_index': 1290, 'end_index': 1296, 'id': 'page-149'}
# {'label': 'page', 'begin_index': 1296, 'end_index': 1302, 'id': 'page-150'}
# {'label': 'page', 'begin_index': 1302, 'end_index': 1315, 'id': 'page-151'}
# {'label': 'page', 'begin_index': 1315, 'end_index': 1320, 'id': 'page-152'}
# {'label': 'page', 'begin_index': 1320, 'end_index': 1345, 'id': 'page-153'}
# {'label': 'page', 'begin_index': 1345, 'end_index': 1349, 'id': 'page-154'}
# {'label': 'page', 'begin_index': 1349, 'end_index': 1364, 'id': 'page-155'}
# {'label': 'page', 'begin_index': 1364, 'end_index': 1376, 'id': 'page-156'}
# {'label': 'page', 'begin_index': 1376, 'end_index': 1379, 'id': 'page-157'}
# {'label': 'page', 'begin_index': 1379, 'end_index': 1385, 'id': 'page-158'}
# {'label': 'page', 'begin_index': 1385, 'end_index': 1386, 'id': 'page-159'}
# {'label': 'page', 'begin_index': 1386, 'end_index': 1393, 'id': 'page-160'}
# {'label': 'page', 'begin_index': 1393, 'end_index': 1398, 'id': 'page-161'}
# {'label': 'page', 'begin_index': 1398, 'end_index': 1410, 'id': 'page-162'}
# {'label': 'page', 'begin_index': 1410, 'end_index': 1415, 'id': 'page-163'}
# {'label': 'page', 'begin_index': 1415, 'end_index': 1423, 'id': 'page-164'}
# {'label': 'page', 'begin_index': 1423, 'end_index': 1442, 'id': 'page-165'}
# {'label': 'page', 'begin_index': 1442, 'end_index': 1446, 'id': 'page-166'}
# {'label': 'page', 'begin_index': 1446, 'end_index': 1458, 'id': 'page-167'}
# {'label': 'page', 'begin_index': 1458, 'end_index': 1466, 'id': 'page-168'}
# {'label': 'page', 'begin_index': 1466, 'end_index': 1472, 'id': 'page-169'}
# {'label': 'page', 'begin_index': 1472, 'end_index': 1478, 'id': 'page-170'}
# {'label': 'page', 'begin_index': 1478, 'end_index': 1487, 'id': 'page-171'}
# {'label': 'page', 'begin_index': 1487, 'end_index': 1499, 'id': 'page-172'}
# {'label': 'page', 'begin_index': 1499, 'end_index': 1506, 'id': 'page-173'}
# {'label': 'page', 'begin_index': 1506, 'end_index': 1521, 'id': 'page-174'}
# {'label': 'page', 'begin_index': 1521, 'end_index': 1523, 'id': 'page-175'}
# {'label': 'page', 'begin_index': 1523, 'end_index': 1527, 'id': 'page-176'}
# {'label': 'page', 'begin_index': 1527, 'end_index': 1537, 'id': 'page-177'}
# {'label': 'page', 'begin_index': 1537, 'end_index': 1538, 'id': 'page-178'}
# {'label': 'page', 'begin_index': 1538, 'end_index': 1546, 'id': 'page-179'}
# {'label': 'page', 'begin_index': 1546, 'end_index': 1550, 'id': 'page-180'}
# {'label': 'page', 'begin_index': 1550, 'end_index': 1560, 'id': 'page-181'}
# {'label': 'page', 'begin_index': 1560, 'end_index': 1573, 'id': 'page-182'}
# {'label': 'page', 'begin_index': 1573, 'end_index': 1574, 'id': 'page-183'}
# {'label': 'page', 'begin_index': 1574, 'end_index': 1580, 'id': 'page-184'}
# {'label': 'page', 'begin_index': 1580, 'end_index': 1584, 'id': 'page-185'}
# {'label': 'page', 'begin_index': 1584, 'end_index': 1595, 'id': 'page-186'}
# {'label': 'page', 'begin_index': 1595, 'end_index': 1614, 'id': 'page-187'}
# {'label': 'page', 'begin_index': 1614, 'end_index': 1618, 'id': 'page-188'}
# {'label': 'page', 'begin_index': 1618, 'end_index': 1629, 'id': 'page-189'}
# {'label': 'page', 'begin_index': 1629, 'end_index': 1643, 'id': 'page-190'}
# {'label': 'page', 'begin_index': 1643, 'end_index': 1647, 'id': 'page-191'}
# {'label': 'page', 'begin_index': 1647, 'end_index': 1655, 'id': 'page-192'}
# {'label': 'page', 'begin_index': 1655, 'end_index': 1665, 'id': 'page-193'}
# {'label': 'page', 'begin_index': 1665, 'end_index': 1676, 'id': 'page-194'}
# {'label': 'page', 'begin_index': 1676, 'end_index': 1691, 'id': 'page-195'}
# {'label': 'page', 'begin_index': 1691, 'end_index': 1691, 'id': 'page-196'}
# {'label': 'page', 'begin_index': 1691, 'end_index': 1703, 'id': 'page-197'}
# {'label': 'page', 'begin_index': 1703, 'end_index': 1717, 'id': 'page-198'}
# {'label': 'page', 'begin_index': 1717, 'end_index': 1718, 'id': 'page-199'}
# {'label': 'page', 'begin_index': 1718, 'end_index': 1722, 'id': 'page-200'}
# {'label': 'page', 'begin_index': 1722, 'end_index': 1725, 'id': 'page-201'}
# {'label': 'page', 'begin_index': 1725, 'end_index': 1727, 'id': 'page-202'}
# {'label': 'page', 'begin_index': 1727, 'end_index': 1729, 'id': 'page-203'}
# {'label': 'page', 'begin_index': 1729, 'end_index': 1732, 'id': 'page-204'}
# {'label': 'page', 'begin_index': 1732, 'end_index': 1735, 'id': 'page-205'}
# {'label': 'page', 'begin_index': 1735, 'end_index': 1744, 'id': 'page-206'}
# {'label': 'page', 'begin_index': 1744, 'end_index': 1746, 'id': 'page-207'}
# {'label': 'page', 'begin_index': 1746, 'end_index': 1756, 'id': 'page-208'}
# {'label': 'page', 'begin_index': 1756, 'end_index': 1757, 'id': 'page-209'}
# {'label': 'page', 'begin_index': 1757, 'end_index': 1765, 'id': 'page-210'}
# {'label': 'page', 'begin_index': 1765, 'end_index': 1769, 'id': 'page-211'}
# {'label': 'page', 'begin_index': 1769, 'end_index': 1773, 'id': 'page-212'}
# {'label': 'page', 'begin_index': 1773, 'end_index': 1775, 'id': 'page-213'}
# {'label': 'page', 'begin_index': 1775, 'end_index': 1788, 'id': 'page-214'}
# {'label': 'page', 'begin_index': 1788, 'end_index': 1789, 'id': 'page-215'}
# {'label': 'page', 'begin_index': 1789, 'end_index': 1796, 'id': 'page-216'}
# {'label': 'page', 'begin_index': 1796, 'end_index': 1800, 'id': 'page-217'}
# {'label': 'page', 'begin_index': 1800, 'end_index': 1804, 'id': 'page-218'}
# {'label': 'page', 'begin_index': 1804, 'end_index': 1815, 'id': 'page-219'}
# {'label': 'page', 'begin_index': 1815, 'end_index': 1819, 'id': 'page-220'}
# {'label': 'page', 'begin_index': 1819, 'end_index': 1822, 'id': 'page-221'}
# {'label': 'page', 'begin_index': 1822, 'end_index': 1827, 'id': 'page-222'}
# {'label': 'page', 'begin_index': 1827, 'end_index': 1834, 'id': 'page-223'}
# {'label': 'page', 'begin_index': 1834, 'end_index': 1838, 'id': 'page-224'}
# {'label': 'page', 'begin_index': 1838, 'end_index': 1841, 'id': 'page-225'}
# {'label': 'page', 'begin_index': 1841, 'end_index': 1844, 'id': 'page-226'}
# {'label': 'page', 'begin_index': 1844, 'end_index': 1846, 'id': 'page-227'}
# {'label': 'page', 'begin_index': 1846, 'end_index': 1850, 'id': 'page-228'}
# {'label': 'page', 'begin_index': 1850, 'end_index': 1852, 'id': 'page-229'}
# {'label': 'page', 'begin_index': 1852, 'end_index': 1859, 'id': 'page-230'}
# {'label': 'page', 'begin_index': 1859, 'end_index': 1864, 'id': 'page-231'}
# {'label': 'page', 'begin_index': 1864, 'end_index': 1882, 'id': 'page-232'}
# {'label': 'page', 'begin_index': 1882, 'end_index': 1884, 'id': 'page-233'}
# {'label': 'page', 'begin_index': 1884, 'end_index': 1897, 'id': 'page-234'}
# {'label': 'page', 'begin_index': 1897, 'end_index': 1901, 'id': 'page-235'}
# {'label': 'page', 'begin_index': 1901, 'end_index': 1914, 'id': 'page-236'}
# {'label': 'page', 'begin_index': 1914, 'end_index': 1917, 'id': 'page-237'}
# {'label': 'page', 'begin_index': 1917, 'end_index': 1923, 'id': 'page-238'}
# {'label': 'page', 'begin_index': 1923, 'end_index': 1929, 'id': 'page-239'}
# {'label': 'page', 'begin_index': 1929, 'end_index': 1934, 'id': 'page-240'}
# {'label': 'page', 'begin_index': 1934, 'end_index': 1949, 'id': 'page-241'}
# {'label': 'page', 'begin_index': 1949, 'end_index': 1950, 'id': 'page-242'}
# {'label': 'page', 'begin_index': 1950, 'end_index': 1962, 'id': 'page-243'}
# {'label': 'page', 'begin_index': 1962, 'end_index': 1973, 'id': 'page-244'}
# {'label': 'page', 'begin_index': 1973, 'end_index': 1981, 'id': 'page-245'}
# {'label': 'page', 'begin_index': 1981, 'end_index': 1990, 'id': 'page-246'}
# {'label': 'page', 'begin_index': 1990, 'end_index': 1997, 'id': 'page-247'}
# {'label': 'page', 'begin_index': 1997, 'end_index': 2001, 'id': 'page-248'}
# {'label': 'page', 'begin_index': 2001, 'end_index': 2003, 'id': 'page-249'}
# {'label': 'page', 'begin_index': 2003, 'end_index': 2007, 'id': 'page-250'}
# {'label': 'page', 'begin_index': 2007, 'end_index': 2013, 'id': 'page-251'}
# {'label': 'page', 'begin_index': 2013, 'end_index': 2021, 'id': 'page-252'}
# {'label': 'page', 'begin_index': 2021, 'end_index': 2026, 'id': 'page-*3'}
# {'label': 'page', 'begin_index': 2026, 'end_index': 2032, 'id': 'page-253'}
# {'label': 'page', 'begin_index': 2032, 'end_index': 2038, 'id': 'page-254'}
# {'label': 'page', 'begin_index': 2038, 'end_index': 2048, 'id': 'page-255'}
# {'label': 'page', 'begin_index': 2048, 'end_index': 2050, 'id': 'page-256'}
# {'label': 'page', 'begin_index': 2050, 'end_index': 2053, 'id': 'page-257'}
# {'label': 'page', 'begin_index': 2053, 'end_index': 2065, 'id': 'page-258'}
# {'label': 'page', 'begin_index': 2065, 'end_index': 2092, 'id': 'page-259'}
# {'label': 'page', 'begin_index': 2092, 'end_index': 2092, 'id': 'page-260'}
# {'label': 'page', 'begin_index': 2092, 'end_index': 2099, 'id': 'page-261'}
# {'label': 'page', 'begin_index': 2099, 'end_index': 2107, 'id': 'page-262'}
# {'label': 'page', 'begin_index': 2107, 'end_index': 2115, 'id': 'page-263'}
# {'label': 'page', 'begin_index': 2115, 'end_index': 2135, 'id': 'page-264'}
# {'label': 'page', 'begin_index': 2135, 'end_index': 2135, 'id': 'page-265'}
# {'label': 'page', 'begin_index': 2135, 'end_index': 2142, 'id': 'page-266'}
# {'label': 'page', 'begin_index': 2142, 'end_index': 2145, 'id': 'page-267'}
# {'label': 'page', 'begin_index': 2145, 'end_index': 2147, 'id': 'page-268'}
# {'label': 'page', 'begin_index': 2147, 'end_index': 2150, 'id': 'page-269'}
# {'label': 'page', 'begin_index': 2150, 'end_index': 2152, 'id': 'page-270'}
# {'label': 'page', 'begin_index': 2152, 'end_index': 2158, 'id': 'page-271'}
# {'label': 'page', 'begin_index': 2158, 'end_index': 2163, 'id': 'page-272'}
# {'label': 'page', 'begin_index': 2163, 'end_index': 2164, 'id': 'page-273'}
# {'label': 'page', 'begin_index': 2164, 'end_index': 2171, 'id': 'page-274'}
# {'label': 'page', 'begin_index': 2171, 'end_index': 2179, 'id': 'page-275'}
# {'label': 'page', 'begin_index': 2179, 'end_index': 2181, 'id': 'page-276'}
# {'label': 'page', 'begin_index': 2181, 'end_index': 2195, 'id': 'page-277'}
# {'label': 'page', 'begin_index': 2195, 'end_index': 2197, 'id': 'page-278'}
# {'label': 'page', 'begin_index': 2197, 'end_index': 2204, 'id': 'page-279'}
# {'label': 'page', 'begin_index': 2204, 'end_index': 2217, 'id': 'page-280'}
# {'label': 'page', 'begin_index': 2217, 'end_index': 2217, 'id': 'page-281'}
# {'label': 'page', 'begin_index': 2217, 'end_index': 2218, 'id': 'page-283'}
# {'label': 'page', 'begin_index': 2218, 'end_index': 2229, 'id': 'page-284'}
# {'label': 'page', 'begin_index': 2229, 'end_index': 2229, 'id': 'page-285'}
# {'label': 'page', 'begin_index': 2229, 'end_index': 2238, 'id': 'page-286'}
# {'label': 'page', 'begin_index': 2238, 'end_index': 2245, 'id': 'page-287'}
# {'label': 'page', 'begin_index': 2245, 'end_index': 2254, 'id': 'page-288'}
# {'label': 'page', 'begin_index': 2254, 'end_index': 2254, 'id': 'page-289'}
# {'label': 'page', 'begin_index': 2254, 'end_index': 2259, 'id': 'page-290'}
# {'label': 'page', 'begin_index': 2259, 'end_index': 2259, 'id': 'page-291'}
# {'label': 'page', 'begin_index': 2259, 'end_index': 2262, 'id': 'page-292'}
# {'label': 'page', 'begin_index': 2262, 'end_index': 2265, 'id': 'page-293'}
# {'label': 'page', 'begin_index': 2265, 'end_index': 2272, 'id': 'page-294'}
# {'label': 'page', 'begin_index': 2272, 'end_index': 2284, 'id': 'page-295'}
# {'label': 'page', 'begin_index': 2284, 'end_index': 2291, 'id': 'page-296'}
# {'label': 'page', 'begin_index': 2291, 'end_index': 2298, 'id': 'page-297'}
# {'label': 'page', 'begin_index': 2298, 'end_index': 2313, 'id': 'page-298'}
# {'label': 'page', 'begin_index': 2313, 'end_index': 2320, 'id': 'page-299'}
# {'label': 'page', 'begin_index': 2320, 'end_index': 2327, 'id': 'page-300'}
# {'label': 'page', 'begin_index': 2327, 'end_index': 2348, 'id': 'page-301'}
# {'label': 'page', 'begin_index': 2348, 'end_index': 2355, 'id': 'page-302'}
# {'label': 'page', 'begin_index': 2355, 'end_index': 2362, 'id': 'page-303'}
# {'label': 'page', 'begin_index': 2362, 'end_index': 2362, 'id': 'page-304'}
# {'label': 'page', 'begin_index': 2362, 'end_index': 2367, 'id': 'page-305'}
# {'label': 'page', 'begin_index': 2367, 'end_index': 2369, 'id': 'page-306'}
# {'label': 'page', 'begin_index': 2369, 'end_index': 2373, 'id': 'page-307'}
# {'label': 'page', 'begin_index': 2373, 'end_index': 2373, 'id': 'page-308'}
# {'label': 'page', 'begin_index': 2373, 'end_index': 2376, 'id': 'page-309'}
# {'label': 'page', 'begin_index': 2376, 'end_index': 2381, 'id': 'page-310'}
# {'label': 'page', 'begin_index': 2381, 'end_index': 2381, 'id': 'page-311'}
# {'label': 'page', 'begin_index': 2381, 'end_index': 2388, 'id': 'page-312'}
# {'label': 'page', 'begin_index': 2388, 'end_index': 2392, 'id': 'page-313'}
# {'label': 'page', 'begin_index': 2392, 'end_index': 2392, 'id': 'page-314'}
# {'label': 'page', 'begin_index': 2392, 'end_index': 2395, 'id': 'page-315'}
# {'label': 'page', 'begin_index': 2395, 'end_index': 2402, 'id': 'page-316'}
# {'label': 'page', 'begin_index': 2402, 'end_index': 2410, 'id': 'page-317'}
# {'label': 'page', 'begin_index': 2410, 'end_index': 2431, 'id': 'page-318'}
# {'label': 'page', 'begin_index': 2431, 'end_index': 2433, 'id': 'page-319'}
# {'label': 'page', 'begin_index': 2433, 'end_index': 2443, 'id': 'page-320'}
# {'label': 'page', 'begin_index': 2443, 'end_index': 2456, 'id': 'page-321'}
# {'label': 'page', 'begin_index': 2456, 'end_index': 2462, 'id': 'page-322'}
# {'label': 'page', 'begin_index': 2462, 'end_index': 2477, 'id': 'page-323'}
# {'label': 'page', 'begin_index': 2477, 'end_index': 2479, 'id': 'page-324'}
# {'label': 'page', 'begin_index': 2479, 'end_index': 2483, 'id': 'page-325'}
# {'label': 'page', 'begin_index': 2483, 'end_index': 2502, 'id': 'page-326'}
# {'label': 'page', 'begin_index': 2502, 'end_index': 2507, 'id': 'page-327'}
# {'label': 'page', 'begin_index': 2507, 'end_index': 2511, 'id': 'page-328'}
# {'label': 'page', 'begin_index': 2511, 'end_index': 2517, 'id': 'page-329'}
# {'label': 'page', 'begin_index': 2517, 'end_index': 2520, 'id': 'page-330'}
# {'label': 'page', 'begin_index': 2520, 'end_index': 2522, 'id': 'page-331'}
# {'label': 'page', 'begin_index': 2522, 'end_index': 2526, 'id': 'page-332'}
# {'label': 'page', 'begin_index': 2526, 'end_index': 2539, 'id': 'page-333'}
# {'label': 'page', 'begin_index': 2539, 'end_index': 2548, 'id': 'page-334'}
# {'label': 'page', 'begin_index': 2548, 'end_index': 2559, 'id': 'page-335'}
# {'label': 'page', 'begin_index': 2559, 'end_index': 2568, 'id': 'page-336'}
# {'label': 'page', 'begin_index': 2568, 'end_index': 2576, 'id': 'page-337'}
# {'label': 'page', 'begin_index': 2576, 'end_index': 2589, 'id': 'page-338'}
# {'label': 'page', 'begin_index': 2589, 'end_index': 2596, 'id': 'page-339'}
# {'label': 'page', 'begin_index': 2596, 'end_index': 2600, 'id': 'page-340'}
# {'label': 'page', 'begin_index': 2600, 'end_index': 2610, 'id': 'page-341'}
# {'label': 'page', 'begin_index': 2610, 'end_index': 2625, 'id': 'page-342'}
# {'label': 'page', 'begin_index': 2625, 'end_index': 2626, 'id': 'page-*5'}
# {'label': 'page', 'begin_index': 2626, 'end_index': 2639, 'id': 'page-343'}
# {'label': 'page', 'begin_index': 2639, 'end_index': 2644, 'id': 'page-344'}
# {'label': 'page', 'begin_index': 2644, 'end_index': 2646, 'id': 'page-345'}
# {'label': 'page', 'begin_index': 2646, 'end_index': 2668, 'id': 'page-346'}
# {'label': 'page', 'begin_index': 2668, 'end_index': 2672, 'id': 'page-347'}
# {'label': 'page', 'begin_index': 2672, 'end_index': 2678, 'id': 'page-348'}
# {'label': 'page', 'begin_index': 2678, 'end_index': 2680, 'id': 'page-349'}
# {'label': 'page', 'begin_index': 2680, 'end_index': 2681, 'id': 'page-351'}
# {'label': 'page', 'begin_index': 2681, 'end_index': 2682, 'id': 'page-352'}
# {'label': 'page', 'begin_index': 2682, 'end_index': 2688, 'id': 'page-353'}
# {'label': 'page', 'begin_index': 2688, 'end_index': 2695, 'id': 'page-354'}
# {'label': 'page', 'begin_index': 2695, 'end_index': 2703, 'id': 'page-355'}
# {'label': 'page', 'begin_index': 2703, 'end_index': 2706, 'id': 'page-356'}
# {'label': 'page', 'begin_index': 2706, 'end_index': 2714, 'id': 'page-357'}
# {'label': 'page', 'begin_index': 2714, 'end_index': 2721, 'id': 'page-358'}
# {'label': 'page', 'begin_index': 2721, 'end_index': 2727, 'id': 'page-359'}
# {'label': 'page', 'begin_index': 2727, 'end_index': 2731, 'id': 'page-360'}
# {'label': 'page', 'begin_index': 2731, 'end_index': 2750, 'id': 'page-361'}
# {'label': 'page', 'begin_index': 2750, 'end_index': 2766, 'id': 'page-362'}
# {'label': 'page', 'begin_index': 2766, 'end_index': 2774, 'id': 'page-363'}
# {'label': 'page', 'begin_index': 2774, 'end_index': 2777, 'id': 'page-365'}
# {'label': 'page', 'begin_index': 2777, 'end_index': 2784, 'id': 'page-367'}
# {'label': 'page', 'begin_index': 2784, 'end_index': 2793, 'id': 'page-368'}
# {'label': 'page', 'begin_index': 2793, 'end_index': 2813, 'id': 'page-369'}
# {'label': 'page', 'begin_index': 2813, 'end_index': 2829, 'id': 'page-370'}
# {'label': 'page', 'begin_index': 2829, 'end_index': 2860, 'id': 'page-371'}
# {'label': 'page', 'begin_index': 2860, 'end_index': 2886, 'id': 'page-372'}
# {'label': 'page', 'begin_index': 2886, 'end_index': 2898, 'id': 'page-373'}
# {'label': 'page', 'begin_index': 2898, 'end_index': 2913, 'id': 'page-374'}
# {'label': 'page', 'begin_index': 2913, 'end_index': 2931, 'id': 'page-375'}
# {'label': 'page', 'begin_index': 2931, 'end_index': 2953, 'id': 'page-376'}
# {'label': 'page', 'begin_index': 2953, 'end_index': 2958, 'id': 'page-377'}
# {'label': 'page', 'begin_index': 2958, 'end_index': 2965, 'id': 'page-378'}
# {'label': 'page', 'begin_index': 2965, 'end_index': 2970, 'id': 'page-379'}
# {'label': 'page', 'begin_index': 2970, 'end_index': 2975, 'id': 'page-380'}
# {'label': 'page', 'begin_index': 2975, 'end_index': 2978, 'id': 'page-381'}
# {'label': 'page', 'begin_index': 2978, 'end_index': 2982, 'id': 'page-382'}
# {'label': 'page', 'begin_index': 2982, 'end_index': 2991, 'id': 'page-383'}
# {'label': 'page', 'begin_index': 2991, 'end_index': 2993, 'id': 'page-384'}
# {'label': 'page', 'begin_index': 2993, 'end_index': 3001, 'id': 'page-385'}
# {'label': 'page', 'begin_index': 3001, 'end_index': 3004, 'id': 'page-386'}
# {'label': 'page', 'begin_index': 3004, 'end_index': 3022, 'id': 'page-387'}
# {'label': 'page', 'begin_index': 3022, 'end_index': 3041, 'id': 'page-388'}
# {'label': 'page', 'begin_index': 3041, 'end_index': 3042, 'id': 'page-389'}
# {'label': 'page', 'begin_index': 3042, 'end_index': 3049, 'id': 'page-390'}
# {'label': 'page', 'begin_index': 3049, 'end_index': 3057, 'id': 'page-391'}
# {'label': 'page', 'begin_index': 3057, 'end_index': 3069, 'id': 'page-392'}
# {'label': 'page', 'begin_index': 3069, 'end_index': 3089, 'id': 'page-393'}
# {'label': 'page', 'begin_index': 3089, 'end_index': 3099, 'id': 'page-394'}
# {'label': 'page', 'begin_index': 3099, 'end_index': 3104, 'id': 'page-395'}
# {'label': 'page', 'begin_index': 3104, 'end_index': 3110, 'id': 'page-396'}
# {'label': 'page', 'begin_index': 3110, 'end_index': 3114, 'id': 'page-397'}

# %%
import json

# write all_textlines to a file
with open('../data/all_tei_textlines.txt', 'w') as filehandle:
    json.dump(all_textelements, filehandle)

# %%
for a in get_annotations_of_type('page', all_annotations):
    print(json.dumps(a, sort_keys=False, indent=2))
# Out:
# {
#   "label": "page",
#   "begin_index": 0,
#   "end_index": 295,
#   "id": ""
# }
# {
#   "label": "page",
#   "begin_index": 295,
#   "end_index": 297,
#   "id": "page-IV"
# }
# {
#   "label": "page",
#   "begin_index": 297,
#   "end_index": 297,
#   "id": "page-1"
# }
# {
#   "label": "page",
#   "begin_index": 297,
#   "end_index": 298,
#   "id": "page-3"
# }
# {
#   "label": "page",
#   "begin_index": 298,
#   "end_index": 302,
#   "id": "page-4"
# }
# {
#   "label": "page",
#   "begin_index": 302,
#   "end_index": 315,
#   "id": "page-5"
# }
# {
#   "label": "page",
#   "begin_index": 315,
#   "end_index": 319,
#   "id": "page-6"
# }
# {
#   "label": "page",
#   "begin_index": 319,
#   "end_index": 325,
#   "id": "page-7"
# }
# {
#   "label": "page",
#   "begin_index": 325,
#   "end_index": 331,
#   "id": "page-8"
# }
# {
#   "label": "page",
#   "begin_index": 331,
#   "end_index": 334,
#   "id": "page-9"
# }
# {
#   "label": "page",
#   "begin_index": 334,
#   "end_index": 344,
#   "id": "page-10"
# }
# {
#   "label": "page",
#   "begin_index": 344,
#   "end_index": 350,
#   "id": "page-11"
# }
# {
#   "label": "page",
#   "begin_index": 350,
#   "end_index": 350,
#   "id": "page-12"
# }
# {
#   "label": "page",
#   "begin_index": 350,
#   "end_index": 350,
#   "id": "page-13"
# }
# {
#   "label": "page",
#   "begin_index": 350,
#   "end_index": 356,
#   "id": "page-14"
# }
# {
#   "label": "page",
#   "begin_index": 356,
#   "end_index": 358,
#   "id": "page-15"
# }
# {
#   "label": "page",
#   "begin_index": 358,
#   "end_index": 366,
#   "id": "page-16"
# }
# {
#   "label": "page",
#   "begin_index": 366,
#   "end_index": 368,
#   "id": "page-17"
# }
# {
#   "label": "page",
#   "begin_index": 368,
#   "end_index": 372,
#   "id": "page-18"
# }
# {
#   "label": "page",
#   "begin_index": 372,
#   "end_index": 383,
#   "id": "page-19"
# }
# {
#   "label": "page",
#   "begin_index": 383,
#   "end_index": 386,
#   "id": "page-20"
# }
# {
#   "label": "page",
#   "begin_index": 386,
#   "end_index": 394,
#   "id": "page-21"
# }
# {
#   "label": "page",
#   "begin_index": 394,
#   "end_index": 404,
#   "id": "page-22"
# }
# {
#   "label": "page",
#   "begin_index": 404,
#   "end_index": 406,
#   "id": "page-23"
# }
# {
#   "label": "page",
#   "begin_index": 406,
#   "end_index": 409,
#   "id": "page-24"
# }
# {
#   "label": "page",
#   "begin_index": 409,
#   "end_index": 414,
#   "id": "page-25"
# }
# {
#   "label": "page",
#   "begin_index": 414,
#   "end_index": 429,
#   "id": "page-26"
# }
# {
#   "label": "page",
#   "begin_index": 429,
#   "end_index": 439,
#   "id": "page-27"
# }
# {
#   "label": "page",
#   "begin_index": 439,
#   "end_index": 445,
#   "id": "page-28"
# }
# {
#   "label": "page",
#   "begin_index": 445,
#   "end_index": 456,
#   "id": "page-29"
# }
# {
#   "label": "page",
#   "begin_index": 456,
#   "end_index": 463,
#   "id": "page-30"
# }
# {
#   "label": "page",
#   "begin_index": 463,
#   "end_index": 469,
#   "id": "page-31"
# }
# {
#   "label": "page",
#   "begin_index": 469,
#   "end_index": 476,
#   "id": "page-32"
# }
# {
#   "label": "page",
#   "begin_index": 476,
#   "end_index": 486,
#   "id": "page-33"
# }
# {
#   "label": "page",
#   "begin_index": 486,
#   "end_index": 491,
#   "id": "page-34"
# }
# {
#   "label": "page",
#   "begin_index": 491,
#   "end_index": 494,
#   "id": "page-35"
# }
# {
#   "label": "page",
#   "begin_index": 494,
#   "end_index": 500,
#   "id": "page-36"
# }
# {
#   "label": "page",
#   "begin_index": 500,
#   "end_index": 507,
#   "id": "page-37"
# }
# {
#   "label": "page",
#   "begin_index": 507,
#   "end_index": 519,
#   "id": "page-38"
# }
# {
#   "label": "page",
#   "begin_index": 519,
#   "end_index": 526,
#   "id": "page-39"
# }
# {
#   "label": "page",
#   "begin_index": 526,
#   "end_index": 530,
#   "id": "page-40"
# }
# {
#   "label": "page",
#   "begin_index": 530,
#   "end_index": 538,
#   "id": "page-41"
# }
# {
#   "label": "page",
#   "begin_index": 538,
#   "end_index": 552,
#   "id": "page-42"
# }
# {
#   "label": "page",
#   "begin_index": 552,
#   "end_index": 554,
#   "id": "page-43"
# }
# {
#   "label": "page",
#   "begin_index": 554,
#   "end_index": 557,
#   "id": "page-44"
# }
# {
#   "label": "page",
#   "begin_index": 557,
#   "end_index": 562,
#   "id": "page-45"
# }
# {
#   "label": "page",
#   "begin_index": 562,
#   "end_index": 579,
#   "id": "page-46"
# }
# {
#   "label": "page",
#   "begin_index": 579,
#   "end_index": 583,
#   "id": "page-47"
# }
# {
#   "label": "page",
#   "begin_index": 583,
#   "end_index": 590,
#   "id": "page-48"
# }
# {
#   "label": "page",
#   "begin_index": 590,
#   "end_index": 598,
#   "id": "page-49"
# }
# {
#   "label": "page",
#   "begin_index": 598,
#   "end_index": 610,
#   "id": "page-50"
# }
# {
#   "label": "page",
#   "begin_index": 610,
#   "end_index": 614,
#   "id": "page-51"
# }
# {
#   "label": "page",
#   "begin_index": 614,
#   "end_index": 619,
#   "id": "page-52"
# }
# {
#   "label": "page",
#   "begin_index": 619,
#   "end_index": 627,
#   "id": "page-53"
# }
# {
#   "label": "page",
#   "begin_index": 627,
#   "end_index": 632,
#   "id": "page-54"
# }
# {
#   "label": "page",
#   "begin_index": 632,
#   "end_index": 635,
#   "id": "page-55"
# }
# {
#   "label": "page",
#   "begin_index": 635,
#   "end_index": 635,
#   "id": "page-56"
# }
# {
#   "label": "page",
#   "begin_index": 635,
#   "end_index": 638,
#   "id": "page-57"
# }
# {
#   "label": "page",
#   "begin_index": 638,
#   "end_index": 644,
#   "id": "page-58"
# }
# {
#   "label": "page",
#   "begin_index": 644,
#   "end_index": 659,
#   "id": "page-59"
# }
# {
#   "label": "page",
#   "begin_index": 659,
#   "end_index": 671,
#   "id": "page-60"
# }
# {
#   "label": "page",
#   "begin_index": 671,
#   "end_index": 683,
#   "id": "page-61"
# }
# {
#   "label": "page",
#   "begin_index": 683,
#   "end_index": 692,
#   "id": "page-62"
# }
# {
#   "label": "page",
#   "begin_index": 692,
#   "end_index": 706,
#   "id": "page-63"
# }
# {
#   "label": "page",
#   "begin_index": 706,
#   "end_index": 718,
#   "id": "page-64"
# }
# {
#   "label": "page",
#   "begin_index": 718,
#   "end_index": 733,
#   "id": "page-65"
# }
# {
#   "label": "page",
#   "begin_index": 733,
#   "end_index": 733,
#   "id": "page-66"
# }
# {
#   "label": "page",
#   "begin_index": 733,
#   "end_index": 742,
#   "id": "page-67"
# }
# {
#   "label": "page",
#   "begin_index": 742,
#   "end_index": 752,
#   "id": "page-68"
# }
# {
#   "label": "page",
#   "begin_index": 752,
#   "end_index": 757,
#   "id": "page-69"
# }
# {
#   "label": "page",
#   "begin_index": 757,
#   "end_index": 760,
#   "id": "page-70"
# }
# {
#   "label": "page",
#   "begin_index": 760,
#   "end_index": 762,
#   "id": "page-71"
# }
# {
#   "label": "page",
#   "begin_index": 762,
#   "end_index": 767,
#   "id": "page-72"
# }
# {
#   "label": "page",
#   "begin_index": 767,
#   "end_index": 774,
#   "id": "page-73"
# }
# {
#   "label": "page",
#   "begin_index": 774,
#   "end_index": 778,
#   "id": "page-74"
# }
# {
#   "label": "page",
#   "begin_index": 778,
#   "end_index": 781,
#   "id": "page-75"
# }
# {
#   "label": "page",
#   "begin_index": 781,
#   "end_index": 783,
#   "id": "page-76"
# }
# {
#   "label": "page",
#   "begin_index": 783,
#   "end_index": 791,
#   "id": "page-77"
# }
# {
#   "label": "page",
#   "begin_index": 791,
#   "end_index": 803,
#   "id": "page-78"
# }
# {
#   "label": "page",
#   "begin_index": 803,
#   "end_index": 806,
#   "id": "page-79"
# }
# {
#   "label": "page",
#   "begin_index": 806,
#   "end_index": 810,
#   "id": "page-80"
# }
# {
#   "label": "page",
#   "begin_index": 810,
#   "end_index": 814,
#   "id": "page-81"
# }
# {
#   "label": "page",
#   "begin_index": 814,
#   "end_index": 823,
#   "id": "page-82"
# }
# {
#   "label": "page",
#   "begin_index": 823,
#   "end_index": 836,
#   "id": "page-83"
# }
# {
#   "label": "page",
#   "begin_index": 836,
#   "end_index": 840,
#   "id": "page-84"
# }
# {
#   "label": "page",
#   "begin_index": 840,
#   "end_index": 850,
#   "id": "page-85"
# }
# {
#   "label": "page",
#   "begin_index": 850,
#   "end_index": 862,
#   "id": "page-86"
# }
# {
#   "label": "page",
#   "begin_index": 862,
#   "end_index": 867,
#   "id": "page-87"
# }
# {
#   "label": "page",
#   "begin_index": 867,
#   "end_index": 875,
#   "id": "page-88"
# }
# {
#   "label": "page",
#   "begin_index": 875,
#   "end_index": 880,
#   "id": "page-89"
# }
# {
#   "label": "page",
#   "begin_index": 880,
#   "end_index": 881,
#   "id": "page-90"
# }
# {
#   "label": "page",
#   "begin_index": 881,
#   "end_index": 883,
#   "id": "page-91"
# }
# {
#   "label": "page",
#   "begin_index": 883,
#   "end_index": 894,
#   "id": "page-92"
# }
# {
#   "label": "page",
#   "begin_index": 894,
#   "end_index": 912,
#   "id": "page-93"
# }
# {
#   "label": "page",
#   "begin_index": 912,
#   "end_index": 923,
#   "id": "page-94"
# }
# {
#   "label": "page",
#   "begin_index": 923,
#   "end_index": 930,
#   "id": "page-95"
# }
# {
#   "label": "page",
#   "begin_index": 930,
#   "end_index": 937,
#   "id": "page-96"
# }
# {
#   "label": "page",
#   "begin_index": 937,
#   "end_index": 944,
#   "id": "page-97"
# }
# {
#   "label": "page",
#   "begin_index": 944,
#   "end_index": 948,
#   "id": "page-98"
# }
# {
#   "label": "page",
#   "begin_index": 948,
#   "end_index": 955,
#   "id": "page-99"
# }
# {
#   "label": "page",
#   "begin_index": 955,
#   "end_index": 961,
#   "id": "page-100"
# }
# {
#   "label": "page",
#   "begin_index": 961,
#   "end_index": 967,
#   "id": "page-101"
# }
# {
#   "label": "page",
#   "begin_index": 967,
#   "end_index": 970,
#   "id": "page-102"
# }
# {
#   "label": "page",
#   "begin_index": 970,
#   "end_index": 973,
#   "id": "page-103"
# }
# {
#   "label": "page",
#   "begin_index": 973,
#   "end_index": 975,
#   "id": "page-104"
# }
# {
#   "label": "page",
#   "begin_index": 975,
#   "end_index": 977,
#   "id": "page-105"
# }
# {
#   "label": "page",
#   "begin_index": 977,
#   "end_index": 978,
#   "id": "page-106"
# }
# {
#   "label": "page",
#   "begin_index": 978,
#   "end_index": 981,
#   "id": "page-107"
# }
# {
#   "label": "page",
#   "begin_index": 981,
#   "end_index": 981,
#   "id": "page-108"
# }
# {
#   "label": "page",
#   "begin_index": 981,
#   "end_index": 984,
#   "id": "page-109"
# }
# {
#   "label": "page",
#   "begin_index": 984,
#   "end_index": 986,
#   "id": "page-110"
# }
# {
#   "label": "page",
#   "begin_index": 986,
#   "end_index": 1002,
#   "id": "page-111"
# }
# {
#   "label": "page",
#   "begin_index": 1002,
#   "end_index": 1006,
#   "id": "page-112"
# }
# {
#   "label": "page",
#   "begin_index": 1006,
#   "end_index": 1026,
#   "id": "page-113"
# }
# {
#   "label": "page",
#   "begin_index": 1026,
#   "end_index": 1028,
#   "id": "page-114"
# }
# {
#   "label": "page",
#   "begin_index": 1028,
#   "end_index": 1036,
#   "id": "page-115"
# }
# {
#   "label": "page",
#   "begin_index": 1036,
#   "end_index": 1042,
#   "id": "page-116"
# }
# {
#   "label": "page",
#   "begin_index": 1042,
#   "end_index": 1045,
#   "id": "page-117"
# }
# {
#   "label": "page",
#   "begin_index": 1045,
#   "end_index": 1048,
#   "id": "page-118"
# }
# {
#   "label": "page",
#   "begin_index": 1048,
#   "end_index": 1056,
#   "id": "page-119"
# }
# {
#   "label": "page",
#   "begin_index": 1056,
#   "end_index": 1067,
#   "id": "page-120"
# }
# {
#   "label": "page",
#   "begin_index": 1067,
#   "end_index": 1071,
#   "id": "page-121"
# }
# {
#   "label": "page",
#   "begin_index": 1071,
#   "end_index": 1075,
#   "id": "page-122"
# }
# {
#   "label": "page",
#   "begin_index": 1075,
#   "end_index": 1077,
#   "id": "page-123"
# }
# {
#   "label": "page",
#   "begin_index": 1077,
#   "end_index": 1085,
#   "id": "page-124"
# }
# {
#   "label": "page",
#   "begin_index": 1085,
#   "end_index": 1096,
#   "id": "page-125"
# }
# {
#   "label": "page",
#   "begin_index": 1096,
#   "end_index": 1103,
#   "id": "page-126"
# }
# {
#   "label": "page",
#   "begin_index": 1103,
#   "end_index": 1111,
#   "id": "page-127"
# }
# {
#   "label": "page",
#   "begin_index": 1111,
#   "end_index": 1122,
#   "id": "page-128"
# }
# {
#   "label": "page",
#   "begin_index": 1122,
#   "end_index": 1126,
#   "id": "page-129"
# }
# {
#   "label": "page",
#   "begin_index": 1126,
#   "end_index": 1126,
#   "id": "page-130"
# }
# {
#   "label": "page",
#   "begin_index": 1126,
#   "end_index": 1130,
#   "id": "page-131"
# }
# {
#   "label": "page",
#   "begin_index": 1130,
#   "end_index": 1137,
#   "id": "page-132"
# }
# {
#   "label": "page",
#   "begin_index": 1137,
#   "end_index": 1144,
#   "id": "page-133"
# }
# {
#   "label": "page",
#   "begin_index": 1144,
#   "end_index": 1151,
#   "id": "page-134"
# }
# {
#   "label": "page",
#   "begin_index": 1151,
#   "end_index": 1158,
#   "id": "page-*1"
# }
# {
#   "label": "page",
#   "begin_index": 1158,
#   "end_index": 1164,
#   "id": "page-135"
# }
# {
#   "label": "page",
#   "begin_index": 1164,
#   "end_index": 1180,
#   "id": "page-136"
# }
# {
#   "label": "page",
#   "begin_index": 1180,
#   "end_index": 1194,
#   "id": "page-137"
# }
# {
#   "label": "page",
#   "begin_index": 1194,
#   "end_index": 1197,
#   "id": "page-138"
# }
# {
#   "label": "page",
#   "begin_index": 1197,
#   "end_index": 1205,
#   "id": "page-139"
# }
# {
#   "label": "page",
#   "begin_index": 1205,
#   "end_index": 1212,
#   "id": "page-140"
# }
# {
#   "label": "page",
#   "begin_index": 1212,
#   "end_index": 1219,
#   "id": "page-141"
# }
# {
#   "label": "page",
#   "begin_index": 1219,
#   "end_index": 1240,
#   "id": "page-142"
# }
# {
#   "label": "page",
#   "begin_index": 1240,
#   "end_index": 1244,
#   "id": "page-143"
# }
# {
#   "label": "page",
#   "begin_index": 1244,
#   "end_index": 1246,
#   "id": "page-144"
# }
# {
#   "label": "page",
#   "begin_index": 1246,
#   "end_index": 1252,
#   "id": "page-145"
# }
# {
#   "label": "page",
#   "begin_index": 1252,
#   "end_index": 1262,
#   "id": "page-146"
# }
# {
#   "label": "page",
#   "begin_index": 1262,
#   "end_index": 1272,
#   "id": "page-147"
# }
# {
#   "label": "page",
#   "begin_index": 1272,
#   "end_index": 1290,
#   "id": "page-148"
# }
# {
#   "label": "page",
#   "begin_index": 1290,
#   "end_index": 1296,
#   "id": "page-149"
# }
# {
#   "label": "page",
#   "begin_index": 1296,
#   "end_index": 1302,
#   "id": "page-150"
# }
# {
#   "label": "page",
#   "begin_index": 1302,
#   "end_index": 1315,
#   "id": "page-151"
# }
# {
#   "label": "page",
#   "begin_index": 1315,
#   "end_index": 1320,
#   "id": "page-152"
# }
# {
#   "label": "page",
#   "begin_index": 1320,
#   "end_index": 1345,
#   "id": "page-153"
# }
# {
#   "label": "page",
#   "begin_index": 1345,
#   "end_index": 1349,
#   "id": "page-154"
# }
# {
#   "label": "page",
#   "begin_index": 1349,
#   "end_index": 1364,
#   "id": "page-155"
# }
# {
#   "label": "page",
#   "begin_index": 1364,
#   "end_index": 1376,
#   "id": "page-156"
# }
# {
#   "label": "page",
#   "begin_index": 1376,
#   "end_index": 1379,
#   "id": "page-157"
# }
# {
#   "label": "page",
#   "begin_index": 1379,
#   "end_index": 1385,
#   "id": "page-158"
# }
# {
#   "label": "page",
#   "begin_index": 1385,
#   "end_index": 1386,
#   "id": "page-159"
# }
# {
#   "label": "page",
#   "begin_index": 1386,
#   "end_index": 1393,
#   "id": "page-160"
# }
# {
#   "label": "page",
#   "begin_index": 1393,
#   "end_index": 1398,
#   "id": "page-161"
# }
# {
#   "label": "page",
#   "begin_index": 1398,
#   "end_index": 1410,
#   "id": "page-162"
# }
# {
#   "label": "page",
#   "begin_index": 1410,
#   "end_index": 1415,
#   "id": "page-163"
# }
# {
#   "label": "page",
#   "begin_index": 1415,
#   "end_index": 1423,
#   "id": "page-164"
# }
# {
#   "label": "page",
#   "begin_index": 1423,
#   "end_index": 1442,
#   "id": "page-165"
# }
# {
#   "label": "page",
#   "begin_index": 1442,
#   "end_index": 1446,
#   "id": "page-166"
# }
# {
#   "label": "page",
#   "begin_index": 1446,
#   "end_index": 1458,
#   "id": "page-167"
# }
# {
#   "label": "page",
#   "begin_index": 1458,
#   "end_index": 1466,
#   "id": "page-168"
# }
# {
#   "label": "page",
#   "begin_index": 1466,
#   "end_index": 1472,
#   "id": "page-169"
# }
# {
#   "label": "page",
#   "begin_index": 1472,
#   "end_index": 1478,
#   "id": "page-170"
# }
# {
#   "label": "page",
#   "begin_index": 1478,
#   "end_index": 1487,
#   "id": "page-171"
# }
# {
#   "label": "page",
#   "begin_index": 1487,
#   "end_index": 1499,
#   "id": "page-172"
# }
# {
#   "label": "page",
#   "begin_index": 1499,
#   "end_index": 1506,
#   "id": "page-173"
# }
# {
#   "label": "page",
#   "begin_index": 1506,
#   "end_index": 1521,
#   "id": "page-174"
# }
# {
#   "label": "page",
#   "begin_index": 1521,
#   "end_index": 1523,
#   "id": "page-175"
# }
# {
#   "label": "page",
#   "begin_index": 1523,
#   "end_index": 1527,
#   "id": "page-176"
# }
# {
#   "label": "page",
#   "begin_index": 1527,
#   "end_index": 1537,
#   "id": "page-177"
# }
# {
#   "label": "page",
#   "begin_index": 1537,
#   "end_index": 1538,
#   "id": "page-178"
# }
# {
#   "label": "page",
#   "begin_index": 1538,
#   "end_index": 1546,
#   "id": "page-179"
# }
# {
#   "label": "page",
#   "begin_index": 1546,
#   "end_index": 1550,
#   "id": "page-180"
# }
# {
#   "label": "page",
#   "begin_index": 1550,
#   "end_index": 1560,
#   "id": "page-181"
# }
# {
#   "label": "page",
#   "begin_index": 1560,
#   "end_index": 1573,
#   "id": "page-182"
# }
# {
#   "label": "page",
#   "begin_index": 1573,
#   "end_index": 1574,
#   "id": "page-183"
# }
# {
#   "label": "page",
#   "begin_index": 1574,
#   "end_index": 1580,
#   "id": "page-184"
# }
# {
#   "label": "page",
#   "begin_index": 1580,
#   "end_index": 1584,
#   "id": "page-185"
# }
# {
#   "label": "page",
#   "begin_index": 1584,
#   "end_index": 1595,
#   "id": "page-186"
# }
# {
#   "label": "page",
#   "begin_index": 1595,
#   "end_index": 1614,
#   "id": "page-187"
# }
# {
#   "label": "page",
#   "begin_index": 1614,
#   "end_index": 1618,
#   "id": "page-188"
# }
# {
#   "label": "page",
#   "begin_index": 1618,
#   "end_index": 1629,
#   "id": "page-189"
# }
# {
#   "label": "page",
#   "begin_index": 1629,
#   "end_index": 1643,
#   "id": "page-190"
# }
# {
#   "label": "page",
#   "begin_index": 1643,
#   "end_index": 1647,
#   "id": "page-191"
# }
# {
#   "label": "page",
#   "begin_index": 1647,
#   "end_index": 1655,
#   "id": "page-192"
# }
# {
#   "label": "page",
#   "begin_index": 1655,
#   "end_index": 1665,
#   "id": "page-193"
# }
# {
#   "label": "page",
#   "begin_index": 1665,
#   "end_index": 1676,
#   "id": "page-194"
# }
# {
#   "label": "page",
#   "begin_index": 1676,
#   "end_index": 1691,
#   "id": "page-195"
# }
# {
#   "label": "page",
#   "begin_index": 1691,
#   "end_index": 1691,
#   "id": "page-196"
# }
# {
#   "label": "page",
#   "begin_index": 1691,
#   "end_index": 1703,
#   "id": "page-197"
# }
# {
#   "label": "page",
#   "begin_index": 1703,
#   "end_index": 1717,
#   "id": "page-198"
# }
# {
#   "label": "page",
#   "begin_index": 1717,
#   "end_index": 1718,
#   "id": "page-199"
# }
# {
#   "label": "page",
#   "begin_index": 1718,
#   "end_index": 1722,
#   "id": "page-200"
# }
# {
#   "label": "page",
#   "begin_index": 1722,
#   "end_index": 1725,
#   "id": "page-201"
# }
# {
#   "label": "page",
#   "begin_index": 1725,
#   "end_index": 1727,
#   "id": "page-202"
# }
# {
#   "label": "page",
#   "begin_index": 1727,
#   "end_index": 1729,
#   "id": "page-203"
# }
# {
#   "label": "page",
#   "begin_index": 1729,
#   "end_index": 1732,
#   "id": "page-204"
# }
# {
#   "label": "page",
#   "begin_index": 1732,
#   "end_index": 1735,
#   "id": "page-205"
# }
# {
#   "label": "page",
#   "begin_index": 1735,
#   "end_index": 1744,
#   "id": "page-206"
# }
# {
#   "label": "page",
#   "begin_index": 1744,
#   "end_index": 1746,
#   "id": "page-207"
# }
# {
#   "label": "page",
#   "begin_index": 1746,
#   "end_index": 1756,
#   "id": "page-208"
# }
# {
#   "label": "page",
#   "begin_index": 1756,
#   "end_index": 1757,
#   "id": "page-209"
# }
# {
#   "label": "page",
#   "begin_index": 1757,
#   "end_index": 1765,
#   "id": "page-210"
# }
# {
#   "label": "page",
#   "begin_index": 1765,
#   "end_index": 1769,
#   "id": "page-211"
# }
# {
#   "label": "page",
#   "begin_index": 1769,
#   "end_index": 1773,
#   "id": "page-212"
# }
# {
#   "label": "page",
#   "begin_index": 1773,
#   "end_index": 1775,
#   "id": "page-213"
# }
# {
#   "label": "page",
#   "begin_index": 1775,
#   "end_index": 1788,
#   "id": "page-214"
# }
# {
#   "label": "page",
#   "begin_index": 1788,
#   "end_index": 1789,
#   "id": "page-215"
# }
# {
#   "label": "page",
#   "begin_index": 1789,
#   "end_index": 1796,
#   "id": "page-216"
# }
# {
#   "label": "page",
#   "begin_index": 1796,
#   "end_index": 1800,
#   "id": "page-217"
# }
# {
#   "label": "page",
#   "begin_index": 1800,
#   "end_index": 1804,
#   "id": "page-218"
# }
# {
#   "label": "page",
#   "begin_index": 1804,
#   "end_index": 1815,
#   "id": "page-219"
# }
# {
#   "label": "page",
#   "begin_index": 1815,
#   "end_index": 1819,
#   "id": "page-220"
# }
# {
#   "label": "page",
#   "begin_index": 1819,
#   "end_index": 1822,
#   "id": "page-221"
# }
# {
#   "label": "page",
#   "begin_index": 1822,
#   "end_index": 1827,
#   "id": "page-222"
# }
# {
#   "label": "page",
#   "begin_index": 1827,
#   "end_index": 1834,
#   "id": "page-223"
# }
# {
#   "label": "page",
#   "begin_index": 1834,
#   "end_index": 1838,
#   "id": "page-224"
# }
# {
#   "label": "page",
#   "begin_index": 1838,
#   "end_index": 1841,
#   "id": "page-225"
# }
# {
#   "label": "page",
#   "begin_index": 1841,
#   "end_index": 1844,
#   "id": "page-226"
# }
# {
#   "label": "page",
#   "begin_index": 1844,
#   "end_index": 1846,
#   "id": "page-227"
# }
# {
#   "label": "page",
#   "begin_index": 1846,
#   "end_index": 1850,
#   "id": "page-228"
# }
# {
#   "label": "page",
#   "begin_index": 1850,
#   "end_index": 1852,
#   "id": "page-229"
# }
# {
#   "label": "page",
#   "begin_index": 1852,
#   "end_index": 1859,
#   "id": "page-230"
# }
# {
#   "label": "page",
#   "begin_index": 1859,
#   "end_index": 1864,
#   "id": "page-231"
# }
# {
#   "label": "page",
#   "begin_index": 1864,
#   "end_index": 1882,
#   "id": "page-232"
# }
# {
#   "label": "page",
#   "begin_index": 1882,
#   "end_index": 1884,
#   "id": "page-233"
# }
# {
#   "label": "page",
#   "begin_index": 1884,
#   "end_index": 1897,
#   "id": "page-234"
# }
# {
#   "label": "page",
#   "begin_index": 1897,
#   "end_index": 1901,
#   "id": "page-235"
# }
# {
#   "label": "page",
#   "begin_index": 1901,
#   "end_index": 1914,
#   "id": "page-236"
# }
# {
#   "label": "page",
#   "begin_index": 1914,
#   "end_index": 1917,
#   "id": "page-237"
# }
# {
#   "label": "page",
#   "begin_index": 1917,
#   "end_index": 1923,
#   "id": "page-238"
# }
# {
#   "label": "page",
#   "begin_index": 1923,
#   "end_index": 1929,
#   "id": "page-239"
# }
# {
#   "label": "page",
#   "begin_index": 1929,
#   "end_index": 1934,
#   "id": "page-240"
# }
# {
#   "label": "page",
#   "begin_index": 1934,
#   "end_index": 1949,
#   "id": "page-241"
# }
# {
#   "label": "page",
#   "begin_index": 1949,
#   "end_index": 1950,
#   "id": "page-242"
# }
# {
#   "label": "page",
#   "begin_index": 1950,
#   "end_index": 1962,
#   "id": "page-243"
# }
# {
#   "label": "page",
#   "begin_index": 1962,
#   "end_index": 1973,
#   "id": "page-244"
# }
# {
#   "label": "page",
#   "begin_index": 1973,
#   "end_index": 1981,
#   "id": "page-245"
# }
# {
#   "label": "page",
#   "begin_index": 1981,
#   "end_index": 1990,
#   "id": "page-246"
# }
# {
#   "label": "page",
#   "begin_index": 1990,
#   "end_index": 1997,
#   "id": "page-247"
# }
# {
#   "label": "page",
#   "begin_index": 1997,
#   "end_index": 2001,
#   "id": "page-248"
# }
# {
#   "label": "page",
#   "begin_index": 2001,
#   "end_index": 2003,
#   "id": "page-249"
# }
# {
#   "label": "page",
#   "begin_index": 2003,
#   "end_index": 2007,
#   "id": "page-250"
# }
# {
#   "label": "page",
#   "begin_index": 2007,
#   "end_index": 2013,
#   "id": "page-251"
# }
# {
#   "label": "page",
#   "begin_index": 2013,
#   "end_index": 2021,
#   "id": "page-252"
# }
# {
#   "label": "page",
#   "begin_index": 2021,
#   "end_index": 2026,
#   "id": "page-*3"
# }
# {
#   "label": "page",
#   "begin_index": 2026,
#   "end_index": 2032,
#   "id": "page-253"
# }
# {
#   "label": "page",
#   "begin_index": 2032,
#   "end_index": 2038,
#   "id": "page-254"
# }
# {
#   "label": "page",
#   "begin_index": 2038,
#   "end_index": 2048,
#   "id": "page-255"
# }
# {
#   "label": "page",
#   "begin_index": 2048,
#   "end_index": 2050,
#   "id": "page-256"
# }
# {
#   "label": "page",
#   "begin_index": 2050,
#   "end_index": 2053,
#   "id": "page-257"
# }
# {
#   "label": "page",
#   "begin_index": 2053,
#   "end_index": 2065,
#   "id": "page-258"
# }
# {
#   "label": "page",
#   "begin_index": 2065,
#   "end_index": 2092,
#   "id": "page-259"
# }
# {
#   "label": "page",
#   "begin_index": 2092,
#   "end_index": 2092,
#   "id": "page-260"
# }
# {
#   "label": "page",
#   "begin_index": 2092,
#   "end_index": 2099,
#   "id": "page-261"
# }
# {
#   "label": "page",
#   "begin_index": 2099,
#   "end_index": 2107,
#   "id": "page-262"
# }
# {
#   "label": "page",
#   "begin_index": 2107,
#   "end_index": 2115,
#   "id": "page-263"
# }
# {
#   "label": "page",
#   "begin_index": 2115,
#   "end_index": 2135,
#   "id": "page-264"
# }
# {
#   "label": "page",
#   "begin_index": 2135,
#   "end_index": 2135,
#   "id": "page-265"
# }
# {
#   "label": "page",
#   "begin_index": 2135,
#   "end_index": 2142,
#   "id": "page-266"
# }
# {
#   "label": "page",
#   "begin_index": 2142,
#   "end_index": 2145,
#   "id": "page-267"
# }
# {
#   "label": "page",
#   "begin_index": 2145,
#   "end_index": 2147,
#   "id": "page-268"
# }
# {
#   "label": "page",
#   "begin_index": 2147,
#   "end_index": 2150,
#   "id": "page-269"
# }
# {
#   "label": "page",
#   "begin_index": 2150,
#   "end_index": 2152,
#   "id": "page-270"
# }
# {
#   "label": "page",
#   "begin_index": 2152,
#   "end_index": 2158,
#   "id": "page-271"
# }
# {
#   "label": "page",
#   "begin_index": 2158,
#   "end_index": 2163,
#   "id": "page-272"
# }
# {
#   "label": "page",
#   "begin_index": 2163,
#   "end_index": 2164,
#   "id": "page-273"
# }
# {
#   "label": "page",
#   "begin_index": 2164,
#   "end_index": 2171,
#   "id": "page-274"
# }
# {
#   "label": "page",
#   "begin_index": 2171,
#   "end_index": 2179,
#   "id": "page-275"
# }
# {
#   "label": "page",
#   "begin_index": 2179,
#   "end_index": 2181,
#   "id": "page-276"
# }
# {
#   "label": "page",
#   "begin_index": 2181,
#   "end_index": 2195,
#   "id": "page-277"
# }
# {
#   "label": "page",
#   "begin_index": 2195,
#   "end_index": 2197,
#   "id": "page-278"
# }
# {
#   "label": "page",
#   "begin_index": 2197,
#   "end_index": 2204,
#   "id": "page-279"
# }
# {
#   "label": "page",
#   "begin_index": 2204,
#   "end_index": 2217,
#   "id": "page-280"
# }
# {
#   "label": "page",
#   "begin_index": 2217,
#   "end_index": 2217,
#   "id": "page-281"
# }
# {
#   "label": "page",
#   "begin_index": 2217,
#   "end_index": 2218,
#   "id": "page-283"
# }
# {
#   "label": "page",
#   "begin_index": 2218,
#   "end_index": 2229,
#   "id": "page-284"
# }
# {
#   "label": "page",
#   "begin_index": 2229,
#   "end_index": 2229,
#   "id": "page-285"
# }
# {
#   "label": "page",
#   "begin_index": 2229,
#   "end_index": 2238,
#   "id": "page-286"
# }
# {
#   "label": "page",
#   "begin_index": 2238,
#   "end_index": 2245,
#   "id": "page-287"
# }
# {
#   "label": "page",
#   "begin_index": 2245,
#   "end_index": 2254,
#   "id": "page-288"
# }
# {
#   "label": "page",
#   "begin_index": 2254,
#   "end_index": 2254,
#   "id": "page-289"
# }
# {
#   "label": "page",
#   "begin_index": 2254,
#   "end_index": 2259,
#   "id": "page-290"
# }
# {
#   "label": "page",
#   "begin_index": 2259,
#   "end_index": 2259,
#   "id": "page-291"
# }
# {
#   "label": "page",
#   "begin_index": 2259,
#   "end_index": 2262,
#   "id": "page-292"
# }
# {
#   "label": "page",
#   "begin_index": 2262,
#   "end_index": 2265,
#   "id": "page-293"
# }
# {
#   "label": "page",
#   "begin_index": 2265,
#   "end_index": 2272,
#   "id": "page-294"
# }
# {
#   "label": "page",
#   "begin_index": 2272,
#   "end_index": 2284,
#   "id": "page-295"
# }
# {
#   "label": "page",
#   "begin_index": 2284,
#   "end_index": 2291,
#   "id": "page-296"
# }
# {
#   "label": "page",
#   "begin_index": 2291,
#   "end_index": 2298,
#   "id": "page-297"
# }
# {
#   "label": "page",
#   "begin_index": 2298,
#   "end_index": 2313,
#   "id": "page-298"
# }
# {
#   "label": "page",
#   "begin_index": 2313,
#   "end_index": 2320,
#   "id": "page-299"
# }
# {
#   "label": "page",
#   "begin_index": 2320,
#   "end_index": 2327,
#   "id": "page-300"
# }
# {
#   "label": "page",
#   "begin_index": 2327,
#   "end_index": 2348,
#   "id": "page-301"
# }
# {
#   "label": "page",
#   "begin_index": 2348,
#   "end_index": 2355,
#   "id": "page-302"
# }
# {
#   "label": "page",
#   "begin_index": 2355,
#   "end_index": 2362,
#   "id": "page-303"
# }
# {
#   "label": "page",
#   "begin_index": 2362,
#   "end_index": 2362,
#   "id": "page-304"
# }
# {
#   "label": "page",
#   "begin_index": 2362,
#   "end_index": 2367,
#   "id": "page-305"
# }
# {
#   "label": "page",
#   "begin_index": 2367,
#   "end_index": 2369,
#   "id": "page-306"
# }
# {
#   "label": "page",
#   "begin_index": 2369,
#   "end_index": 2373,
#   "id": "page-307"
# }
# {
#   "label": "page",
#   "begin_index": 2373,
#   "end_index": 2373,
#   "id": "page-308"
# }
# {
#   "label": "page",
#   "begin_index": 2373,
#   "end_index": 2376,
#   "id": "page-309"
# }
# {
#   "label": "page",
#   "begin_index": 2376,
#   "end_index": 2381,
#   "id": "page-310"
# }
# {
#   "label": "page",
#   "begin_index": 2381,
#   "end_index": 2381,
#   "id": "page-311"
# }
# {
#   "label": "page",
#   "begin_index": 2381,
#   "end_index": 2388,
#   "id": "page-312"
# }
# {
#   "label": "page",
#   "begin_index": 2388,
#   "end_index": 2392,
#   "id": "page-313"
# }
# {
#   "label": "page",
#   "begin_index": 2392,
#   "end_index": 2392,
#   "id": "page-314"
# }
# {
#   "label": "page",
#   "begin_index": 2392,
#   "end_index": 2395,
#   "id": "page-315"
# }
# {
#   "label": "page",
#   "begin_index": 2395,
#   "end_index": 2402,
#   "id": "page-316"
# }
# {
#   "label": "page",
#   "begin_index": 2402,
#   "end_index": 2410,
#   "id": "page-317"
# }
# {
#   "label": "page",
#   "begin_index": 2410,
#   "end_index": 2431,
#   "id": "page-318"
# }
# {
#   "label": "page",
#   "begin_index": 2431,
#   "end_index": 2433,
#   "id": "page-319"
# }
# {
#   "label": "page",
#   "begin_index": 2433,
#   "end_index": 2443,
#   "id": "page-320"
# }
# {
#   "label": "page",
#   "begin_index": 2443,
#   "end_index": 2456,
#   "id": "page-321"
# }
# {
#   "label": "page",
#   "begin_index": 2456,
#   "end_index": 2462,
#   "id": "page-322"
# }
# {
#   "label": "page",
#   "begin_index": 2462,
#   "end_index": 2477,
#   "id": "page-323"
# }
# {
#   "label": "page",
#   "begin_index": 2477,
#   "end_index": 2479,
#   "id": "page-324"
# }
# {
#   "label": "page",
#   "begin_index": 2479,
#   "end_index": 2483,
#   "id": "page-325"
# }
# {
#   "label": "page",
#   "begin_index": 2483,
#   "end_index": 2502,
#   "id": "page-326"
# }
# {
#   "label": "page",
#   "begin_index": 2502,
#   "end_index": 2507,
#   "id": "page-327"
# }
# {
#   "label": "page",
#   "begin_index": 2507,
#   "end_index": 2511,
#   "id": "page-328"
# }
# {
#   "label": "page",
#   "begin_index": 2511,
#   "end_index": 2517,
#   "id": "page-329"
# }
# {
#   "label": "page",
#   "begin_index": 2517,
#   "end_index": 2520,
#   "id": "page-330"
# }
# {
#   "label": "page",
#   "begin_index": 2520,
#   "end_index": 2522,
#   "id": "page-331"
# }
# {
#   "label": "page",
#   "begin_index": 2522,
#   "end_index": 2526,
#   "id": "page-332"
# }
# {
#   "label": "page",
#   "begin_index": 2526,
#   "end_index": 2539,
#   "id": "page-333"
# }
# {
#   "label": "page",
#   "begin_index": 2539,
#   "end_index": 2548,
#   "id": "page-334"
# }
# {
#   "label": "page",
#   "begin_index": 2548,
#   "end_index": 2559,
#   "id": "page-335"
# }
# {
#   "label": "page",
#   "begin_index": 2559,
#   "end_index": 2568,
#   "id": "page-336"
# }
# {
#   "label": "page",
#   "begin_index": 2568,
#   "end_index": 2576,
#   "id": "page-337"
# }
# {
#   "label": "page",
#   "begin_index": 2576,
#   "end_index": 2589,
#   "id": "page-338"
# }
# {
#   "label": "page",
#   "begin_index": 2589,
#   "end_index": 2596,
#   "id": "page-339"
# }
# {
#   "label": "page",
#   "begin_index": 2596,
#   "end_index": 2600,
#   "id": "page-340"
# }
# {
#   "label": "page",
#   "begin_index": 2600,
#   "end_index": 2610,
#   "id": "page-341"
# }
# {
#   "label": "page",
#   "begin_index": 2610,
#   "end_index": 2625,
#   "id": "page-342"
# }
# {
#   "label": "page",
#   "begin_index": 2625,
#   "end_index": 2626,
#   "id": "page-*5"
# }
# {
#   "label": "page",
#   "begin_index": 2626,
#   "end_index": 2639,
#   "id": "page-343"
# }
# {
#   "label": "page",
#   "begin_index": 2639,
#   "end_index": 2644,
#   "id": "page-344"
# }
# {
#   "label": "page",
#   "begin_index": 2644,
#   "end_index": 2646,
#   "id": "page-345"
# }
# {
#   "label": "page",
#   "begin_index": 2646,
#   "end_index": 2668,
#   "id": "page-346"
# }
# {
#   "label": "page",
#   "begin_index": 2668,
#   "end_index": 2672,
#   "id": "page-347"
# }
# {
#   "label": "page",
#   "begin_index": 2672,
#   "end_index": 2678,
#   "id": "page-348"
# }
# {
#   "label": "page",
#   "begin_index": 2678,
#   "end_index": 2680,
#   "id": "page-349"
# }
# {
#   "label": "page",
#   "begin_index": 2680,
#   "end_index": 2681,
#   "id": "page-351"
# }
# {
#   "label": "page",
#   "begin_index": 2681,
#   "end_index": 2682,
#   "id": "page-352"
# }
# {
#   "label": "page",
#   "begin_index": 2682,
#   "end_index": 2688,
#   "id": "page-353"
# }
# {
#   "label": "page",
#   "begin_index": 2688,
#   "end_index": 2695,
#   "id": "page-354"
# }
# {
#   "label": "page",
#   "begin_index": 2695,
#   "end_index": 2703,
#   "id": "page-355"
# }
# {
#   "label": "page",
#   "begin_index": 2703,
#   "end_index": 2706,
#   "id": "page-356"
# }
# {
#   "label": "page",
#   "begin_index": 2706,
#   "end_index": 2714,
#   "id": "page-357"
# }
# {
#   "label": "page",
#   "begin_index": 2714,
#   "end_index": 2721,
#   "id": "page-358"
# }
# {
#   "label": "page",
#   "begin_index": 2721,
#   "end_index": 2727,
#   "id": "page-359"
# }
# {
#   "label": "page",
#   "begin_index": 2727,
#   "end_index": 2731,
#   "id": "page-360"
# }
# {
#   "label": "page",
#   "begin_index": 2731,
#   "end_index": 2750,
#   "id": "page-361"
# }
# {
#   "label": "page",
#   "begin_index": 2750,
#   "end_index": 2766,
#   "id": "page-362"
# }
# {
#   "label": "page",
#   "begin_index": 2766,
#   "end_index": 2774,
#   "id": "page-363"
# }
# {
#   "label": "page",
#   "begin_index": 2774,
#   "end_index": 2777,
#   "id": "page-365"
# }
# {
#   "label": "page",
#   "begin_index": 2777,
#   "end_index": 2784,
#   "id": "page-367"
# }
# {
#   "label": "page",
#   "begin_index": 2784,
#   "end_index": 2793,
#   "id": "page-368"
# }
# {
#   "label": "page",
#   "begin_index": 2793,
#   "end_index": 2813,
#   "id": "page-369"
# }
# {
#   "label": "page",
#   "begin_index": 2813,
#   "end_index": 2829,
#   "id": "page-370"
# }
# {
#   "label": "page",
#   "begin_index": 2829,
#   "end_index": 2860,
#   "id": "page-371"
# }
# {
#   "label": "page",
#   "begin_index": 2860,
#   "end_index": 2886,
#   "id": "page-372"
# }
# {
#   "label": "page",
#   "begin_index": 2886,
#   "end_index": 2898,
#   "id": "page-373"
# }
# {
#   "label": "page",
#   "begin_index": 2898,
#   "end_index": 2913,
#   "id": "page-374"
# }
# {
#   "label": "page",
#   "begin_index": 2913,
#   "end_index": 2931,
#   "id": "page-375"
# }
# {
#   "label": "page",
#   "begin_index": 2931,
#   "end_index": 2953,
#   "id": "page-376"
# }
# {
#   "label": "page",
#   "begin_index": 2953,
#   "end_index": 2958,
#   "id": "page-377"
# }
# {
#   "label": "page",
#   "begin_index": 2958,
#   "end_index": 2965,
#   "id": "page-378"
# }
# {
#   "label": "page",
#   "begin_index": 2965,
#   "end_index": 2970,
#   "id": "page-379"
# }
# {
#   "label": "page",
#   "begin_index": 2970,
#   "end_index": 2975,
#   "id": "page-380"
# }
# {
#   "label": "page",
#   "begin_index": 2975,
#   "end_index": 2978,
#   "id": "page-381"
# }
# {
#   "label": "page",
#   "begin_index": 2978,
#   "end_index": 2982,
#   "id": "page-382"
# }
# {
#   "label": "page",
#   "begin_index": 2982,
#   "end_index": 2991,
#   "id": "page-383"
# }
# {
#   "label": "page",
#   "begin_index": 2991,
#   "end_index": 2993,
#   "id": "page-384"
# }
# {
#   "label": "page",
#   "begin_index": 2993,
#   "end_index": 3001,
#   "id": "page-385"
# }
# {
#   "label": "page",
#   "begin_index": 3001,
#   "end_index": 3004,
#   "id": "page-386"
# }
# {
#   "label": "page",
#   "begin_index": 3004,
#   "end_index": 3022,
#   "id": "page-387"
# }
# {
#   "label": "page",
#   "begin_index": 3022,
#   "end_index": 3041,
#   "id": "page-388"
# }
# {
#   "label": "page",
#   "begin_index": 3041,
#   "end_index": 3042,
#   "id": "page-389"
# }
# {
#   "label": "page",
#   "begin_index": 3042,
#   "end_index": 3049,
#   "id": "page-390"
# }
# {
#   "label": "page",
#   "begin_index": 3049,
#   "end_index": 3057,
#   "id": "page-391"
# }
# {
#   "label": "page",
#   "begin_index": 3057,
#   "end_index": 3069,
#   "id": "page-392"
# }
# {
#   "label": "page",
#   "begin_index": 3069,
#   "end_index": 3089,
#   "id": "page-393"
# }
# {
#   "label": "page",
#   "begin_index": 3089,
#   "end_index": 3099,
#   "id": "page-394"
# }
# {
#   "label": "page",
#   "begin_index": 3099,
#   "end_index": 3104,
#   "id": "page-395"
# }
# {
#   "label": "page",
#   "begin_index": 3104,
#   "end_index": 3110,
#   "id": "page-396"
# }
# {
#   "label": "page",
#   "begin_index": 3110,
#   "end_index": 3114,
#   "id": "page-397"
# }

# %%
for a in get_annotations_of_type('paragraph', all_annotations):
    print(json.dumps(a, sort_keys=False, indent=2))
# Out:
# {
#   "label": "paragraph",
#   "begin_index": 0,
#   "end_index": 0,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 1,
#   "end_index": 1,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2,
#   "end_index": 2,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3,
#   "end_index": 3,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 4,
#   "end_index": 14,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 15,
#   "end_index": 15,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 16,
#   "end_index": 16,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 17,
#   "end_index": 17,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 18,
#   "end_index": 18,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 19,
#   "end_index": 21,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 22,
#   "end_index": 22,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 23,
#   "end_index": 23,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 24,
#   "end_index": 26,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 27,
#   "end_index": 28,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 29,
#   "end_index": 29,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 30,
#   "end_index": 30,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 31,
#   "end_index": 31,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 32,
#   "end_index": 32,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 33,
#   "end_index": 33,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 34,
#   "end_index": 34,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 35,
#   "end_index": 35,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 36,
#   "end_index": 36,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 37,
#   "end_index": 41,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 42,
#   "end_index": 43,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 44,
#   "end_index": 44,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 45,
#   "end_index": 47,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 48,
#   "end_index": 48,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 49,
#   "end_index": 49,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 50,
#   "end_index": 52,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 53,
#   "end_index": 53,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 54,
#   "end_index": 54,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 55,
#   "end_index": 178,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 179,
#   "end_index": 179,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 180,
#   "end_index": 182,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 183,
#   "end_index": 289,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 290,
#   "end_index": 290,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 291,
#   "end_index": 291,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 292,
#   "end_index": 292,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 293,
#   "end_index": 295,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 296,
#   "end_index": 296,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 297,
#   "end_index": 297,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 298,
#   "end_index": 297,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 298,
#   "end_index": 297,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 298,
#   "end_index": 297,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 298,
#   "end_index": 297,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 298,
#   "end_index": 297,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 298,
#   "end_index": 297,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 298,
#   "end_index": 297,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 298,
#   "end_index": 297,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 298,
#   "end_index": 297,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 300,
#   "end_index": 300,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 301,
#   "end_index": 302,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 303,
#   "end_index": 303,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 304,
#   "end_index": 304,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 305,
#   "end_index": 305,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 306,
#   "end_index": 306,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 307,
#   "end_index": 307,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 308,
#   "end_index": 309,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 310,
#   "end_index": 310,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 311,
#   "end_index": 311,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 312,
#   "end_index": 312,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 313,
#   "end_index": 315,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 316,
#   "end_index": 316,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 317,
#   "end_index": 317,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 318,
#   "end_index": 319,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 320,
#   "end_index": 320,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 321,
#   "end_index": 321,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 322,
#   "end_index": 322,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 323,
#   "end_index": 323,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 324,
#   "end_index": 325,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 326,
#   "end_index": 326,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 327,
#   "end_index": 327,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 328,
#   "end_index": 328,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 329,
#   "end_index": 329,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 330,
#   "end_index": 330,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 331,
#   "end_index": 331,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 332,
#   "end_index": 332,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 333,
#   "end_index": 334,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 335,
#   "end_index": 335,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 336,
#   "end_index": 336,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 337,
#   "end_index": 337,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 338,
#   "end_index": 338,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 339,
#   "end_index": 339,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 340,
#   "end_index": 340,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 341,
#   "end_index": 344,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 345,
#   "end_index": 345,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 346,
#   "end_index": 346,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 347,
#   "end_index": 350,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 351,
#   "end_index": 356,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 357,
#   "end_index": 358,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 359,
#   "end_index": 359,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 360,
#   "end_index": 360,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 361,
#   "end_index": 361,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 362,
#   "end_index": 362,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 363,
#   "end_index": 363,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 364,
#   "end_index": 364,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 365,
#   "end_index": 366,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 367,
#   "end_index": 368,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 369,
#   "end_index": 372,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 373,
#   "end_index": 373,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 374,
#   "end_index": 374,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 375,
#   "end_index": 375,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 376,
#   "end_index": 376,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 377,
#   "end_index": 377,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 378,
#   "end_index": 378,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 379,
#   "end_index": 381,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 382,
#   "end_index": 383,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 384,
#   "end_index": 386,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 387,
#   "end_index": 387,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 388,
#   "end_index": 388,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 389,
#   "end_index": 394,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 395,
#   "end_index": 395,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 396,
#   "end_index": 396,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 397,
#   "end_index": 397,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 398,
#   "end_index": 399,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 400,
#   "end_index": 404,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 405,
#   "end_index": 406,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 407,
#   "end_index": 407,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 408,
#   "end_index": 408,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 409,
#   "end_index": 409,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 410,
#   "end_index": 410,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 411,
#   "end_index": 411,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 412,
#   "end_index": 412,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 413,
#   "end_index": 414,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 415,
#   "end_index": 415,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 416,
#   "end_index": 416,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 417,
#   "end_index": 417,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 418,
#   "end_index": 418,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 419,
#   "end_index": 419,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 420,
#   "end_index": 420,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 421,
#   "end_index": 421,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 422,
#   "end_index": 422,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 423,
#   "end_index": 423,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 424,
#   "end_index": 424,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 425,
#   "end_index": 425,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 426,
#   "end_index": 426,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 427,
#   "end_index": 427,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 428,
#   "end_index": 429,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 430,
#   "end_index": 430,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 431,
#   "end_index": 431,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 432,
#   "end_index": 432,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 433,
#   "end_index": 433,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 434,
#   "end_index": 434,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 435,
#   "end_index": 435,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 436,
#   "end_index": 436,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 437,
#   "end_index": 437,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 438,
#   "end_index": 438,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 439,
#   "end_index": 439,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 440,
#   "end_index": 440,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 441,
#   "end_index": 441,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 442,
#   "end_index": 442,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 443,
#   "end_index": 443,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 444,
#   "end_index": 444,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 445,
#   "end_index": 445,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 446,
#   "end_index": 446,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 447,
#   "end_index": 447,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 448,
#   "end_index": 448,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 449,
#   "end_index": 449,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 450,
#   "end_index": 450,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 451,
#   "end_index": 451,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 452,
#   "end_index": 452,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 453,
#   "end_index": 453,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 454,
#   "end_index": 454,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 455,
#   "end_index": 455,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 456,
#   "end_index": 456,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 457,
#   "end_index": 457,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 458,
#   "end_index": 458,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 459,
#   "end_index": 459,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 460,
#   "end_index": 460,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 461,
#   "end_index": 461,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 462,
#   "end_index": 462,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 463,
#   "end_index": 463,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 464,
#   "end_index": 464,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 465,
#   "end_index": 465,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 466,
#   "end_index": 466,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 467,
#   "end_index": 467,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 468,
#   "end_index": 469,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 470,
#   "end_index": 470,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 471,
#   "end_index": 471,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 472,
#   "end_index": 472,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 473,
#   "end_index": 473,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 474,
#   "end_index": 474,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 475,
#   "end_index": 476,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 477,
#   "end_index": 477,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 478,
#   "end_index": 478,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 479,
#   "end_index": 479,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 480,
#   "end_index": 480,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 481,
#   "end_index": 481,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 482,
#   "end_index": 482,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 483,
#   "end_index": 483,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 484,
#   "end_index": 484,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 485,
#   "end_index": 486,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 487,
#   "end_index": 487,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 488,
#   "end_index": 488,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 489,
#   "end_index": 489,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 490,
#   "end_index": 490,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 491,
#   "end_index": 491,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 493,
#   "end_index": 494,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 495,
#   "end_index": 496,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 497,
#   "end_index": 497,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 498,
#   "end_index": 500,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 501,
#   "end_index": 501,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 502,
#   "end_index": 502,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 503,
#   "end_index": 503,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 504,
#   "end_index": 507,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 508,
#   "end_index": 508,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 509,
#   "end_index": 509,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 510,
#   "end_index": 510,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 511,
#   "end_index": 511,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 512,
#   "end_index": 512,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 513,
#   "end_index": 513,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 514,
#   "end_index": 514,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 515,
#   "end_index": 515,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 516,
#   "end_index": 516,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 517,
#   "end_index": 517,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 518,
#   "end_index": 519,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 520,
#   "end_index": 520,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 521,
#   "end_index": 521,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 522,
#   "end_index": 522,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 523,
#   "end_index": 523,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 524,
#   "end_index": 524,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 525,
#   "end_index": 525,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 526,
#   "end_index": 526,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 527,
#   "end_index": 527,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 528,
#   "end_index": 528,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 529,
#   "end_index": 530,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 531,
#   "end_index": 531,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 532,
#   "end_index": 532,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 533,
#   "end_index": 533,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 534,
#   "end_index": 534,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 535,
#   "end_index": 535,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 536,
#   "end_index": 536,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 537,
#   "end_index": 538,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 539,
#   "end_index": 539,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 540,
#   "end_index": 540,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 541,
#   "end_index": 541,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 542,
#   "end_index": 542,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 543,
#   "end_index": 543,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 544,
#   "end_index": 544,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 545,
#   "end_index": 545,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 546,
#   "end_index": 546,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 547,
#   "end_index": 547,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 548,
#   "end_index": 548,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 549,
#   "end_index": 549,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 550,
#   "end_index": 550,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 551,
#   "end_index": 552,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 553,
#   "end_index": 554,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 555,
#   "end_index": 555,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 556,
#   "end_index": 557,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 558,
#   "end_index": 558,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 559,
#   "end_index": 559,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 560,
#   "end_index": 560,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 561,
#   "end_index": 562,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 563,
#   "end_index": 563,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 564,
#   "end_index": 564,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 565,
#   "end_index": 565,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 566,
#   "end_index": 566,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 567,
#   "end_index": 567,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 568,
#   "end_index": 568,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 569,
#   "end_index": 569,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 570,
#   "end_index": 571,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 572,
#   "end_index": 572,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 573,
#   "end_index": 573,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 574,
#   "end_index": 574,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 575,
#   "end_index": 575,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 576,
#   "end_index": 576,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 577,
#   "end_index": 579,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 580,
#   "end_index": 580,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 581,
#   "end_index": 583,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 584,
#   "end_index": 584,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 585,
#   "end_index": 585,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 586,
#   "end_index": 586,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 587,
#   "end_index": 587,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 588,
#   "end_index": 588,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 589,
#   "end_index": 590,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 591,
#   "end_index": 591,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 592,
#   "end_index": 592,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 593,
#   "end_index": 594,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 595,
#   "end_index": 595,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 596,
#   "end_index": 598,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 599,
#   "end_index": 599,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 600,
#   "end_index": 605,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 606,
#   "end_index": 610,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 611,
#   "end_index": 611,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 612,
#   "end_index": 612,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 613,
#   "end_index": 614,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 615,
#   "end_index": 615,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 616,
#   "end_index": 616,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 617,
#   "end_index": 617,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 618,
#   "end_index": 619,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 620,
#   "end_index": 620,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 621,
#   "end_index": 621,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 622,
#   "end_index": 622,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 623,
#   "end_index": 623,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 624,
#   "end_index": 627,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 628,
#   "end_index": 628,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 629,
#   "end_index": 629,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 630,
#   "end_index": 630,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 631,
#   "end_index": 631,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 632,
#   "end_index": 632,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 633,
#   "end_index": 635,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 637,
#   "end_index": 638,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 639,
#   "end_index": 639,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 640,
#   "end_index": 640,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 641,
#   "end_index": 641,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 642,
#   "end_index": 642,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 643,
#   "end_index": 643,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 644,
#   "end_index": 644,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 645,
#   "end_index": 645,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 646,
#   "end_index": 646,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 647,
#   "end_index": 647,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 648,
#   "end_index": 648,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 649,
#   "end_index": 649,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 650,
#   "end_index": 650,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 651,
#   "end_index": 651,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 652,
#   "end_index": 652,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 653,
#   "end_index": 653,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 654,
#   "end_index": 654,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 655,
#   "end_index": 655,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 656,
#   "end_index": 659,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 660,
#   "end_index": 660,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 661,
#   "end_index": 661,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 662,
#   "end_index": 662,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 663,
#   "end_index": 663,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 664,
#   "end_index": 664,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 665,
#   "end_index": 665,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 666,
#   "end_index": 666,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 667,
#   "end_index": 667,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 668,
#   "end_index": 668,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 669,
#   "end_index": 669,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 670,
#   "end_index": 671,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 672,
#   "end_index": 672,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 673,
#   "end_index": 673,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 674,
#   "end_index": 674,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 675,
#   "end_index": 675,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 676,
#   "end_index": 676,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 677,
#   "end_index": 677,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 678,
#   "end_index": 678,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 679,
#   "end_index": 679,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 680,
#   "end_index": 680,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 681,
#   "end_index": 681,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 682,
#   "end_index": 683,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 684,
#   "end_index": 684,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 685,
#   "end_index": 685,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 686,
#   "end_index": 686,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 687,
#   "end_index": 687,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 688,
#   "end_index": 688,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 689,
#   "end_index": 689,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 690,
#   "end_index": 690,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 691,
#   "end_index": 692,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 693,
#   "end_index": 693,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 694,
#   "end_index": 694,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 695,
#   "end_index": 695,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 696,
#   "end_index": 696,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 697,
#   "end_index": 697,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 698,
#   "end_index": 698,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 699,
#   "end_index": 699,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 700,
#   "end_index": 700,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 701,
#   "end_index": 701,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 702,
#   "end_index": 702,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 703,
#   "end_index": 703,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 704,
#   "end_index": 704,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 705,
#   "end_index": 705,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 706,
#   "end_index": 706,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 707,
#   "end_index": 707,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 708,
#   "end_index": 708,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 709,
#   "end_index": 709,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 710,
#   "end_index": 710,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 711,
#   "end_index": 711,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 712,
#   "end_index": 712,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 713,
#   "end_index": 713,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 714,
#   "end_index": 714,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 715,
#   "end_index": 715,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 716,
#   "end_index": 716,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 717,
#   "end_index": 718,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 719,
#   "end_index": 719,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 720,
#   "end_index": 720,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 721,
#   "end_index": 724,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 725,
#   "end_index": 725,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 726,
#   "end_index": 726,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 727,
#   "end_index": 727,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 728,
#   "end_index": 728,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 729,
#   "end_index": 729,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 730,
#   "end_index": 730,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 731,
#   "end_index": 733,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 734,
#   "end_index": 734,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 735,
#   "end_index": 735,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 736,
#   "end_index": 736,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 737,
#   "end_index": 737,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 738,
#   "end_index": 738,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 739,
#   "end_index": 739,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 740,
#   "end_index": 740,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 741,
#   "end_index": 742,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 743,
#   "end_index": 743,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 744,
#   "end_index": 744,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 745,
#   "end_index": 745,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 746,
#   "end_index": 746,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 747,
#   "end_index": 747,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 748,
#   "end_index": 748,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 749,
#   "end_index": 749,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 750,
#   "end_index": 750,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 751,
#   "end_index": 752,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 753,
#   "end_index": 753,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 754,
#   "end_index": 754,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 755,
#   "end_index": 755,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 756,
#   "end_index": 756,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 757,
#   "end_index": 757,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 758,
#   "end_index": 760,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 761,
#   "end_index": 761,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 762,
#   "end_index": 762,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 763,
#   "end_index": 763,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 764,
#   "end_index": 764,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 765,
#   "end_index": 765,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 766,
#   "end_index": 766,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 767,
#   "end_index": 767,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 768,
#   "end_index": 768,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 769,
#   "end_index": 769,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 770,
#   "end_index": 770,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 771,
#   "end_index": 771,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 772,
#   "end_index": 772,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 773,
#   "end_index": 773,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 774,
#   "end_index": 774,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 775,
#   "end_index": 775,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 776,
#   "end_index": 776,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 777,
#   "end_index": 778,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 779,
#   "end_index": 779,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 780,
#   "end_index": 781,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 782,
#   "end_index": 783,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 784,
#   "end_index": 784,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 785,
#   "end_index": 785,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 786,
#   "end_index": 786,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 787,
#   "end_index": 787,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 788,
#   "end_index": 788,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 789,
#   "end_index": 789,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 790,
#   "end_index": 790,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 791,
#   "end_index": 791,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 792,
#   "end_index": 792,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 793,
#   "end_index": 793,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 794,
#   "end_index": 794,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 795,
#   "end_index": 795,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 796,
#   "end_index": 796,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 797,
#   "end_index": 797,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 798,
#   "end_index": 798,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 799,
#   "end_index": 799,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 800,
#   "end_index": 800,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 801,
#   "end_index": 801,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 802,
#   "end_index": 803,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 804,
#   "end_index": 804,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 805,
#   "end_index": 806,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 807,
#   "end_index": 807,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 808,
#   "end_index": 808,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 809,
#   "end_index": 810,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 811,
#   "end_index": 811,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 812,
#   "end_index": 812,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 813,
#   "end_index": 814,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 815,
#   "end_index": 815,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 816,
#   "end_index": 816,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 817,
#   "end_index": 817,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 818,
#   "end_index": 818,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 819,
#   "end_index": 819,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 820,
#   "end_index": 820,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 821,
#   "end_index": 821,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 822,
#   "end_index": 823,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 824,
#   "end_index": 824,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 825,
#   "end_index": 825,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 826,
#   "end_index": 826,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 827,
#   "end_index": 827,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 828,
#   "end_index": 828,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 829,
#   "end_index": 829,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 830,
#   "end_index": 830,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 831,
#   "end_index": 831,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 832,
#   "end_index": 832,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 834,
#   "end_index": 836,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 837,
#   "end_index": 840,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 841,
#   "end_index": 841,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 842,
#   "end_index": 842,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 843,
#   "end_index": 843,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 844,
#   "end_index": 844,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 845,
#   "end_index": 845,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 846,
#   "end_index": 846,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 847,
#   "end_index": 847,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 848,
#   "end_index": 848,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 849,
#   "end_index": 850,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 851,
#   "end_index": 851,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 852,
#   "end_index": 852,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 853,
#   "end_index": 854,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 855,
#   "end_index": 855,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 856,
#   "end_index": 856,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 857,
#   "end_index": 857,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 858,
#   "end_index": 858,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 859,
#   "end_index": 859,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 860,
#   "end_index": 862,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 863,
#   "end_index": 863,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 864,
#   "end_index": 864,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 865,
#   "end_index": 865,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 866,
#   "end_index": 867,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 868,
#   "end_index": 868,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 869,
#   "end_index": 869,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 870,
#   "end_index": 870,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 871,
#   "end_index": 871,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 872,
#   "end_index": 875,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 876,
#   "end_index": 876,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 877,
#   "end_index": 877,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 878,
#   "end_index": 878,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 879,
#   "end_index": 880,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 881,
#   "end_index": 881,
#   "id": "generate_later"
# }
# {
# ...
#   "begin_index": 2914,
#   "end_index": 2914,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2915,
#   "end_index": 2915,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2916,
#   "end_index": 2916,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2917,
#   "end_index": 2917,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2918,
#   "end_index": 2918,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2919,
#   "end_index": 2919,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2920,
#   "end_index": 2920,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2921,
#   "end_index": 2921,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2922,
#   "end_index": 2922,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2923,
#   "end_index": 2923,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2924,
#   "end_index": 2924,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2925,
#   "end_index": 2928,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2929,
#   "end_index": 2931,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2932,
#   "end_index": 2932,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2933,
#   "end_index": 2933,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2934,
#   "end_index": 2934,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2935,
#   "end_index": 2935,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2936,
#   "end_index": 2936,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2937,
#   "end_index": 2937,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2938,
#   "end_index": 2939,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2940,
#   "end_index": 2940,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2941,
#   "end_index": 2941,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2942,
#   "end_index": 2942,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2943,
#   "end_index": 2943,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2944,
#   "end_index": 2944,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2945,
#   "end_index": 2945,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2946,
#   "end_index": 2946,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2947,
#   "end_index": 2947,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2948,
#   "end_index": 2948,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2949,
#   "end_index": 2949,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2950,
#   "end_index": 2950,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2951,
#   "end_index": 2953,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2954,
#   "end_index": 2954,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2955,
#   "end_index": 2955,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2956,
#   "end_index": 2956,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2957,
#   "end_index": 2957,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2958,
#   "end_index": 2958,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2959,
#   "end_index": 2959,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2960,
#   "end_index": 2960,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2961,
#   "end_index": 2961,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2962,
#   "end_index": 2962,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2963,
#   "end_index": 2963,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2964,
#   "end_index": 2964,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2965,
#   "end_index": 2965,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2966,
#   "end_index": 2970,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2971,
#   "end_index": 2971,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2972,
#   "end_index": 2975,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2976,
#   "end_index": 2976,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2977,
#   "end_index": 2978,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2979,
#   "end_index": 2979,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2980,
#   "end_index": 2980,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2981,
#   "end_index": 2982,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2983,
#   "end_index": 2983,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2984,
#   "end_index": 2984,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2985,
#   "end_index": 2985,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2986,
#   "end_index": 2986,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2987,
#   "end_index": 2991,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2992,
#   "end_index": 2993,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2994,
#   "end_index": 2994,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2995,
#   "end_index": 2995,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2996,
#   "end_index": 2996,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2997,
#   "end_index": 2997,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 2998,
#   "end_index": 3001,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3002,
#   "end_index": 3002,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3003,
#   "end_index": 3003,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3004,
#   "end_index": 3004,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3005,
#   "end_index": 3005,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3006,
#   "end_index": 3006,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3007,
#   "end_index": 3007,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3008,
#   "end_index": 3008,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3009,
#   "end_index": 3009,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3010,
#   "end_index": 3010,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3011,
#   "end_index": 3011,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3012,
#   "end_index": 3012,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3013,
#   "end_index": 3014,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3015,
#   "end_index": 3017,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3018,
#   "end_index": 3022,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3023,
#   "end_index": 3023,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3024,
#   "end_index": 3024,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3025,
#   "end_index": 3025,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3026,
#   "end_index": 3026,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3027,
#   "end_index": 3027,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3028,
#   "end_index": 3028,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3029,
#   "end_index": 3029,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3030,
#   "end_index": 3030,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3031,
#   "end_index": 3031,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3032,
#   "end_index": 3032,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3033,
#   "end_index": 3033,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3034,
#   "end_index": 3034,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3035,
#   "end_index": 3035,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3036,
#   "end_index": 3036,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3037,
#   "end_index": 3037,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3038,
#   "end_index": 3038,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3039,
#   "end_index": 3041,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3042,
#   "end_index": 3042,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3043,
#   "end_index": 3043,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3044,
#   "end_index": 3044,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3045,
#   "end_index": 3046,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3047,
#   "end_index": 3047,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3048,
#   "end_index": 3049,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3050,
#   "end_index": 3050,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3051,
#   "end_index": 3051,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3052,
#   "end_index": 3052,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3053,
#   "end_index": 3053,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3054,
#   "end_index": 3054,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3055,
#   "end_index": 3055,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3056,
#   "end_index": 3056,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3057,
#   "end_index": 3057,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3058,
#   "end_index": 3058,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3059,
#   "end_index": 3059,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3060,
#   "end_index": 3060,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3061,
#   "end_index": 3061,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3062,
#   "end_index": 3062,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3063,
#   "end_index": 3063,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3064,
#   "end_index": 3064,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3065,
#   "end_index": 3065,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3066,
#   "end_index": 3069,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3070,
#   "end_index": 3070,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3071,
#   "end_index": 3071,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3072,
#   "end_index": 3072,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3073,
#   "end_index": 3073,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3074,
#   "end_index": 3074,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3075,
#   "end_index": 3075,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3076,
#   "end_index": 3076,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3077,
#   "end_index": 3077,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3078,
#   "end_index": 3078,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3079,
#   "end_index": 3079,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3080,
#   "end_index": 3080,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3081,
#   "end_index": 3081,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3082,
#   "end_index": 3082,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3083,
#   "end_index": 3083,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3084,
#   "end_index": 3089,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3090,
#   "end_index": 3090,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3091,
#   "end_index": 3091,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3092,
#   "end_index": 3092,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3093,
#   "end_index": 3093,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3094,
#   "end_index": 3094,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3095,
#   "end_index": 3095,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3096,
#   "end_index": 3096,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3097,
#   "end_index": 3097,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3098,
#   "end_index": 3098,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3099,
#   "end_index": 3099,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3100,
#   "end_index": 3100,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3101,
#   "end_index": 3101,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3102,
#   "end_index": 3102,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3103,
#   "end_index": 3104,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3105,
#   "end_index": 3110,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3111,
#   "end_index": 3111,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3112,
#   "end_index": 3112,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3113,
#   "end_index": 3113,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3114,
#   "end_index": 3114,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3115,
#   "end_index": 3115,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3116,
#   "end_index": 3116,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3117,
#   "end_index": 3117,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3118,
#   "end_index": 3118,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3119,
#   "end_index": 3119,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3120,
#   "end_index": 3120,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3121,
#   "end_index": 3121,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3122,
#   "end_index": 3122,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3123,
#   "end_index": 3123,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3124,
#   "end_index": 3124,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3125,
#   "end_index": 3126,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3127,
#   "end_index": 3127,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3128,
#   "end_index": 3128,
#   "id": "generate_later"
# }
# {
#   "label": "paragraph",
#   "begin_index": 3129,
#   "end_index": 3129,
#   "id": "generate_later"
# }
