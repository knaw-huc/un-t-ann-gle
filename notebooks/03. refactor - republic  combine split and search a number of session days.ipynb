# %% [markdown]
# Experiment, sheet 3:
# - Voeg extra image_coords toe en bijbehorende zoekvraag.
# - Scheiden generiek en case-specifiek in de code.
# - Verwijs naar een resolutie of named entity mbv een resolvable web annotation
# - indexeer naar MTAS

# %%
import json
import glob
import re

# read files

path = "../data/sessions/meeting-1705*"
session_file_names = [f for f in glob.glob(path)]

all_textlines=[]
all_annotations=[]

def traverse(node,node_label,text,annotations):
    # find the list that represents the children, each child is a dict, assume first list is the correct one
    children = []
    label_of_children = ''
    for key,val in node.items():
        if (type(val) == list):
            children = val
            label_of_children = key
            break 
    
    if 'coords' in node:
        coords = node['coords']
    else:
        coords = None
    
    begin_index = len(text)
    annotation_info = {'label' : node_label,'image_coords': coords,'begin_index' : begin_index}
    if len(children) == 0:        # if no children, do your 'leaf node thing'
        annotation_info['id'] = node['id']
        annotation_info['end_index'] = len(text)
        node_text = node['text']
        
        if node_text is None:
            node_text = '\n'

        text.append(node_text)
    else:                         # if non-leaf node, first visit children     
        for child in children:
            traverse(child,label_of_children,text,annotations)
        
        # ONDERSTAANDE IS SMERIG, hangt van onzekere aannames af
        for k in node['metadata'].keys():
            idkey = ''
            if k.endswith('id'):
                idkey = k
                break
        annotation_info['id'] = node['metadata'][idkey]
        
        end_index = len(text)-1
        annotation_info['end_index'] = end_index    # after child text segments are added
        
        # if node contains iiif_url, create extra annotation_info for 'scanpage'
        if 'iiif_url' in node['metadata']:
            scan_annot_info = {'label':'scanpage','iiif_url':node['metadata']['iiif_url'],\
                               'begin_index':begin_index,'end_index':end_index}
            scan_annot_info['scan_num'] = node['metadata']['scan_num']
            annotations.append(scan_annot_info)
        
    annotations.append(annotation_info)
    return

for sf_name in sorted(session_file_names):
    text_array = []
    annotation_array = []
    with open(sf_name, 'r') as myfile:
        session_file=myfile.read()
            
    session_data = json.loads(session_file)      
    source_data = session_data['_source']
        
    traverse(source_data,'sessions',text_array,annotation_array)
        
    # use a generator to create a list of only scanpage annotation_info dicts
    scan_page_annots = [ann_info for ann_info in annotation_array if ann_info['label'] == 'scanpage']
        
    # use groupBy on a list of dicts (zie Python cookbook 1.15)
    from operator import itemgetter
    from itertools import groupby

    # first sort on scan_num
    scan_page_annots.sort(key=itemgetter('scan_num'))

    # iterate in groups
    aggregated_scan_annots = []

    for scan_num, items in groupby(scan_page_annots, key=itemgetter('scan_num')):
        # first, convert the 'items' iterator to a list, to able to use it twice (iterators can be used once)
        itemlist = list(items)
    
        # copy the item with the lowest begin_index
        aggr_scan_annot = min(itemlist, key=itemgetter('begin_index')).copy()
    
        # replace 'end_index' with the highest end_index in the group
        max_end_index = max(itemlist, key=itemgetter('end_index'))['end_index']
        aggr_scan_annot['end_index'] = max_end_index
        
        # add to result
        aggregated_scan_annots.append(aggr_scan_annot)

    for scan_ann in aggregated_scan_annots:
        scan_ann['iiif_url'] = re.sub(r'(\d+),(\d+),(\d+),(\d+)/(full)', r'\5/,\4', scan_ann['iiif_url'])
            
    annotation_array = [ann for ann in annotation_array if ann not in scan_page_annots]
    annotation_array.extend(aggregated_scan_annots)
        
    page_data = session_data['_source']['page_versions']
        
    # generator
    page_identifiers = (pg['page_id'] for pg in page_data)
    page_annots = [{'label' : 'pages','id' : page_id} for page_id in page_identifiers]
        
    for pa in page_annots:
        scan_num = int(re.search(r'(\d+)-page-', pa['id']).group(1))
        scanpage_for_scan_num = [ai for ai in annotation_array if 'scan_num' in ai.keys() and ai['scan_num'] == \
                                 scan_num]
        pa['begin_index'] = scanpage_for_scan_num[0]['begin_index']
        pa['end_index'] = scanpage_for_scan_num[0]['end_index']
        pa['indexesByContainment'] = True
     
    annotation_array.extend(page_annots)
    
    # properly concatenate annotation info taking ongoing line indexes into account
    for ai in annotation_array:
        ai['begin_index'] += len(all_textlines)
        ai['end_index'] += len(all_textlines)
    
    all_textlines.extend(text_array)       
    all_annotations.extend(annotation_array)

# %%
all_annotations[-20:]
# Out:
# [{'label': 'lines',
#   'image_coords': {'left': 2591,
#    'right': 3313,
#    'top': 2226,
#    'bottom': 2302,
#    'height': 76,
#    'width': 722},
#   'begin_index': 4670,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-2',
#   'end_index': 4670},
#  {'label': 'lines',
#   'image_coords': {'left': 2586,
#    'right': 3416,
#    'top': 2274,
#    'bottom': 2351,
#    'height': 77,
#    'width': 830},
#   'begin_index': 4671,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-3',
#   'end_index': 4671},
#  {'label': 'lines',
#   'image_coords': {'left': 2636,
#    'right': 3247,
#    'top': 2324,
#    'bottom': 2396,
#    'height': 72,
#    'width': 611},
#   'begin_index': 4672,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-4',
#   'end_index': 4672},
#  {'label': 'lines',
#   'image_coords': {'left': 2590,
#    'right': 3417,
#    'top': 2371,
#    'bottom': 2449,
#    'height': 78,
#    'width': 827},
#   'begin_index': 4673,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-5',
#   'end_index': 4673},
#  {'label': 'lines',
#   'image_coords': {'left': 2637,
#    'right': 2886,
#    'top': 2422,
#    'bottom': 2481,
#    'height': 59,
#    'width': 249},
#   'begin_index': 4674,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-6',
#   'end_index': 4674},
#  {'label': 'lines',
#   'image_coords': {'left': 2591,
#    'right': 3017,
#    'top': 2468,
#    'bottom': 2531,
#    'height': 63,
#    'width': 426},
#   'begin_index': 4675,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-7',
#   'end_index': 4675},
#  {'label': 'lines',
#   'image_coords': {'left': 2594,
#    'right': 2759,
#    'top': 2515,
#    'bottom': 2572,
#    'height': 57,
#    'width': 165},
#   'begin_index': 4676,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-8',
#   'end_index': 4676},
#  {'label': 'lines',
#   'image_coords': {'left': 3361,
#    'right': 3389,
#    'top': 2543,
#    'bottom': 2599,
#    'height': 56,
#    'width': 28},
#   'begin_index': 4677,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-9',
#   'end_index': 4677},
#  {'label': 'lines',
#   'image_coords': {'left': 3326,
#    'right': 3343,
#    'top': 2547,
#    'bottom': 2603,
#    'height': 56,
#    'width': 17},
#   'begin_index': 4678,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-10',
#   'end_index': 4678},
#  {'label': 'lines',
#   'image_coords': {'left': 2592,
#    'right': 2953,
#    'top': 2563,
#    'bottom': 2626,
#    'height': 63,
#    'width': 361},
#   'begin_index': 4679,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-11',
#   'end_index': 4679},
#  {'label': 'lines',
#   'image_coords': {'left': 3313,
#    'right': 3395,
#    'top': 2591,
#    'bottom': 2647,
#    'height': 56,
#    'width': 82},
#   'begin_index': 4680,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-12',
#   'end_index': 4680},
#  {'label': 'lines',
#   'image_coords': {'left': 2853,
#    'right': 2888,
#    'top': 2625,
#    'bottom': 2680,
#    'height': 55,
#    'width': 35},
#   'begin_index': 4681,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-13',
#   'end_index': 4681},
#  {'label': 'lines',
#   'image_coords': {'left': 3020,
#    'right': 3187,
#    'top': 2629,
#    'bottom': 2688,
#    'height': 59,
#    'width': 167},
#   'begin_index': 4682,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-14',
#   'end_index': 4682},
#  {'label': 'lines',
#   'image_coords': {'left': 3349,
#    'right': 3390,
#    'top': 2634,
#    'bottom': 2689,
#    'height': 55,
#    'width': 41},
#   'begin_index': 4683,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-15',
#   'end_index': 4683},
#  {'label': 'lines',
#   'image_coords': {'left': 2648,
#    'right': 3423,
#    'top': 2660,
#    'bottom': 2736,
#    'height': 76,
#    'width': 775},
#   'begin_index': 4684,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3-line-16',
#   'end_index': 4684},
#  {'label': 'textregions',
#   'image_coords': {'left': 2585,
#    'right': 3423,
#    'top': 2130,
#    'bottom': 2736,
#    'height': 606,
#    'width': 838},
#   'begin_index': 4668,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0-tr-3',
#   'end_index': 4684},
#  {'label': 'columns',
#   'image_coords': {'left': 2534,
#    'right': 3423,
#    'top': 1890,
#    'bottom': 2736,
#    'height': 846,
#    'width': 889},
#   'begin_index': 4655,
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63-col-0',
#   'end_index': 4684},
#  {'label': 'sessions',
#   'image_coords': None,
#   'begin_index': 4655,
#   'id': 'meeting-1705-01-11-session-1',
#   'end_index': 4684},
#  {'label': 'scanpage',
#   'iiif_url': 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0032.jpg/full/,1582/0/default.jpg',
#   'begin_index': 4655,
#   'end_index': 4684,
#   'scan_num': 32},
#  {'label': 'pages',
#   'id': 'NL-HaNA_1.01.02_3760_0032-page-63',
#   'begin_index': 4655,
#   'end_index': 4684,
#   'indexesByContainment': True}]

# %% [markdown]
# Localiseer een resolutietekst, liefst over kolom en/of paginagrenzen heen, en representeer die als annotation.

# %%
for i in range(len(all_textlines)):
    print(f"{i}: {all_textlines[i]}")
# Out:
# 0: Jovis den 1. Januari 1705.
# 1: Nihil actum est.
# 2:
#
# 3: 7 61
# 4: Veneris den 2. Januarii 1705.
# 5: 1951
# 6: P R ES I D E,
# 7: vooila
# 8: 7 In:
# 9: 5
# 10: De Heer van Gent.
# 11: P R AE S E.N T I B U S,
# 12: De Heeren Ham.
# 13: V. anden Honert ‚ Heemskerck, Meerens , Raedt-
# 14: Pensionaris Heynsius,
# 15: Becker , met een extraordinaris Gedeputeerde uyt
# 16: de Provincie van Zeelandt.
# 17: Wellandt, Renswoude , Velthuysen, met een ex-
# 18: traordinaris Gedeputeerde uy de Provincie van
# 19: Utrecht.
# 20: Dau Tour.
# 21: Wichers, Gockinga.
# 22: ai
# 23: a
# 24: Rinm gE Resolutien eergisteren genomen
# 25: jp En geleen en geresumeert , ge-
# 26: |
# 27: A He steert zyn de Depesches daer uyt re-
# 28: a ) sulterende.
# 29: Ontfangen een Missive van den Resident Bil-
# 30: derbeeck, geschreven tot Keulen den dertigsten
# 31: der voorlede maendt ‚ houdende advertentie :
# 32: Waer op geen resolutie is gevallen.
# 33: Ontfangen een Missive van haer Hoogh Mo-
# 34: gende Gecommitteerde Hulft i geschreven
# 35:
#
# 36: 120 D noen A
# 37: 9
# 38: tot Keulen den dertighsten der voorlede maendt,
# 39: houdende advertentie: Waer op geen resolutie
# 40: Is gevallen.
# 41: Ontfangen een Missive van den Secretaris
# 42: Mortaigne, geschreven tot Berlyn den seven en
# 43: twintighsten der voorlede maendt . houdende ad-
# 44: vertentie . Waer op geen resolutie is geval-
# 45: len
# 46: in
# 47: Ontfangeen een Missive van den Heere Ha-
# 48: mel Bruyninx, haer Hoogh Mogende extraordi-
# 49: naris Envoy aen het Hof van den Keyser, ge-
# 50: schreven tot Weenen den twintighsten der voor-
# 51: lede maendt houdende advertentie Waer op
# 52: geen resolutie is gevallen.
# 53: Ontfangen een Missive van den Commissaris
# 54: Domburgh x geschreven tot Dantzich den. ne i
# 55: houdende advertentie: Waer op geen resolutie is
# 56: gevallen.
# 57: Ontfangen een Missive van den Resident Spi-
# 58: na, geschreven tot Franckfurt den aght en twin-
# 59: tighsten der voorlede maendt ‚ ende daer nevens
# 60: een Bylage , houdende advertentie : Waer op
# 61: geen resolutie is gevallen.
# 62: Ontfangen een Missive van den Secretaris
# 63: Runkel, geschreven tot Schafhausen den vyf en
# 64: twintighsten der voorlede maendt , houdende ad-
# 65: vertentie : Waer op geen resolutie is geval-
# 66: len.
# 67: ii
# 68: Ontfangen een Missive van den Heere Coljer 5,
# 69:
#
# 70: or 51
# 71: 7 00 mel
# 72: loy 4955
# 73: 1397
# 74: Jood ob 0953
# 75: om 21 96 I SE En
# 76: 19839 ebde
# 77: + eb ee 17961
# 78: he mol 45
# 79: il 2.5 seb
# 80:
#
# 81: 4 52
# 82: 157
# 83: he 12h Mogende Ambassadeur aen het Hof
# 84: 1 Twe schen Keyser, geschreven tot
# 85: a olen den wintiesten Augusti laetst-
# 86: 1 De donde advertentie. Waer op geen te
# 87: solutie is gevallen.
# 88: on deter Vergaderinge getoont ende geëxHi-
# 89: er 4e Declaratie van A driaen Groenen Le.
# 90: vern er van de Koersen t Is na voorgaende de-
# 91: ava ooetoevonden en verstaen, ‚dat de voor-
# 92: schreve Declaratie gesonden sal werden aen den
# 93: Rode van State ende des Generaliteyts Reken:
# 94: kamer om te visiteren , examineren, en liqui-
# 95: een voloens ende in conformité van de ordres
# 96: van het Landt.
# 97: Is er Vergaderinge gelesen de Requeste van
# 98: Hendrick Makreel, Koopman tot Amsterdam,
# 99: houdende, dat hy Suppliant met een Smalschir
# 100: vene langs de Zeeuwsche Stroomen na Oosten-
# 101: Ie sonde uy voeren Potas, Weedas, en andere
# 102: Oebelmetteerde Koopmanschappen . en van daer
# 103: dese Landen te mogen invoeren Wynen ende
# 104: andere venermitteerde Koopmanschappen ; ver-
# 105: soeckende dat haer Hoogh Mogende geliefden
# 106: aen hem Suppliant ten ine voorschteven te accor-
# 107: deren der elver permissie en Pasport. Waer op
# 108: gedelibereert zynde is goetgevonden en verstaen,
# 109: dat ten behoeve van den Supplsant een Pasport sal
# 110: werden ge. depescheert om het voorschreve Schip
# 111: met Potas. Weedas, en andere gepermitteerde
# 112: Waren na Oostende te doen navigeren ‚ en het
# 113: selve met Wynen ende andere gepermitteerde
# 114: Koenmanschsppen (Brandewynen uyteesondert
# 115: in dese Landen te doen retourneren. Endesal
# 116: Extract van dese haer Hoogh Mogende Resolutie
# 117: eesonden werden den het Collegie ter A dmirali
# 118: tevtin Zeelandt, ende het selve daer nevens aen.
# 119: oeschreven soodanive ordre testellen, ende die
# 120: voorsieninge te doen dat het voorschreve Schip
# 121: en Ladinge langhs de Zeeuwsche Stroomen sal
# 122: mogen passeren. De Heeren Gedeputeerden
# 123: van de Provintie van Zeelandt hebben de voor.
# 124: schreve Requeste overgenomen ‚ ende de con-
# 125: 95 9099 W 07 17 od51
# 126: clusie gecontradieeert.
# 127: 0, de Requeste van Paulus de Noter ‚ Schip-
# 128: per, woonende tot Brussel, is na voorgdende de-
# 129: liberatie goetgevofiden en verstaer, dat ten be-
# 130: hoeve van den Suppliant een Pasport sal werden
# 131: oedepescheert, om met sijn Schip direct en son-
# 132: der overschepinge van Brussel uyt dese Landen te
# 133: mogen afhalen 1000 sacken wit gerafineert Zout,
# 134: ende de selve na Brussel te mogen uytvoeren,
# 135: mits betalende ’sLandts gerechtieheyt, mitsga-
# 136: ders de Spaensche rechten van het PortSt. Maria
# 137: aen den Ontfanger Flinck. Endesal Exeract van
# 138: dese haer Hoogh Mogende Resolutie gesonden
# 139: werden aen het Cellegie ter A dmiralieeye in Zee-
# 140: lande, en het selve aengeschreven soodanige or-
# 141: dre te stellen , en die voorsseninge te doen dat
# 142: de voorschreve quantiteyt Zout onverhindert en
# 143: sonder eenige molestatie op der elver Comptoi-
# 144: ren mogen passeren. De Heeren Gedeputeera
# 145: den van de Provincie van Zeelande hebben de
# 146: voorschreve Reqneste overgenomen, en de con-
# 147: clusse gecontradiceert.
# 148:
#
# 149: Op de Requeste van Govert van Wesel, Koop-
# 150: man tot Dordrecht, is na voorgaende deliberatie
# 151: goetgevonden en verstaen . dat ten behoeve van
# 152: den Suppliant een Pasport sal werden gedepe-
# 153: scheert ‚ om seven Schepen met Assche ende
# 154: Noordesche Deelen direct ende sonder oversche-
# 155: pinge na Brabant temogen uytvoeren, mits be-
# 156: talende ’s Landts gerechtigheyt , mitsgaders de
# 157: Spaensche rechten van het Fort Ste. Maria aen
# 158: den Ontfanger Flinck : Ende sal Extract van dese
# 159: haer Hoogh Mogende Resolutie gesonden wer-
# 160: den aen het Collegie ter A dmiraliteyt in Zee-
# 161: landt ‚ ende het selve gengeschreven oodanige
# 162: ordre testellen, ende die voorsieninge te doen,
# 163: dat de voorschreve Schepen onverhindert en son-
# 164: der eenige molestatie op der selver Comptoiren
# 165: mogen passeren. De Heeren Gedeputeerden van
# 166: de Provincie van Zeelandt hebben de voorschreve
# 167: Requeste overgenomen, en de conclusie gecon-
# 168: uadieeers. .
# 169: Is ter Vergaderinge gelesen de Requeste van
# 170: Ary Gerrits, Schipper, woonende tot Rotter-
# 171: dam, houdende, dat hy Suppliant met het Schip
# 172: genaemt de Elisabeth 5 groot tachtigh vat, gaer-
# 173: ne na Vranckrijck soude uytvoeren gepermitteer-
# 174: de Koopmanschappen ‚ en van daer na dese Lan-
# 175: den te mogen invoeren Wynen en andere geper-
# 176: mitteerde Koopmanschappen versoeckende dat
# 177: haer Hoogh Mogende geliefden aen hem Sup-
# 178: pliant ten fine voorschreven te accorderen der
# 179: selver permissie en Pasport. Waer op gedelibe-
# 180: reert zynde is voetgevonden en verstaen dat ten
# 181: behoeve van den Suppliant een Pasport sal werden
# 182: gedepescheest ‚ om het voorschreve Schip met
# 183: gepermitteerde Waren na Vranckrijck te mogen
# 184: doen navigeren, en het selve met Wynen en an-
# 185: dere gepermitteerde Koopmanschappen (Bran-
# 186: dewynen uytgesondert) in dese Landen te doen
# 187: retourneren. - De Heeren Gedeputeerden van de
# 188: Provincie van Zeelandt hebben de voorschreve
# 189: Requeste overgenomen, en de conclusie gecon-
# 190: tradiceert.
# 191: Is ter Vergaderinge gelesen de Requeste van
# 192: Pieter Verbeeck ‚ Koopman tot Rotterdam, hou-
# 193: dende, dat hy Suppliant met het Schip genaemt
# 194: de twee Gebroeders ‚Schipper Thomas Innes,
# 195: en met het Schip John Gabey, schi pper Jacob In-
# 196: nes, gaerne na Vranckrijck soude uytvoeren ge-
# 197: permitteerde Koopmanschappen ‚ en van daer na
# 198: dese Landen te mogen invoeren Wynen en an-
# 199: dere gepermitreerde Koopmanschappen ; Ver-
# 200: soeckende dat haer Hoooh Mogende geliefden
# 201: aen hem Suppliant ten sine voorschreven te ac-
# 202: corderen der selver permissie en Pasport. Waer
# 203: op gedelibereert zynde is goetgevonden e n de ver-
# 204: staen , dat ten behoeve van den Suppliant een
# 205: Pasport sal werden gedepescheert, om de voor.
# 206: schreve Schepen met gepermitteerde Waren na
# 207: Vranckrijck te mogen doen navigeren, ende de
# 208: selve met Wynen ende andere gepermitteerde
# 209: Koopmanschappen (Brandewynen uytgesondert‚
# 210: in dese Landen te doen retourneren. De Heeren
# 211: Gedeputeerden van de Provincie van Zeelandt
# 212: hebben de voorschreve Requeste overgenomen,
# 213: en de conclusie gecontradiceert.
# 214: id 4555 7
# 215: Is ter Vergaderinge gelesen de Requeste van
# 216: Adriaen de Ruyter, Koopman tot Rotterdam,
# 217: houdende, dat hy Suppliant met het Schip ge-
# 218: naemt de jonge Hendrick, Schipper Sander Ja-
# 219: cobsa , gaerne na Vranckrijck soude uytvoeren
# 220: gepermitteerde Koopmanschappen , en van daer
# 221: na dese Landen te mogen invoeren Wynen ende
# 222: andere gepermiteerde Koopmanschappen ; vere
# 223: soeckende dat haer Hoogh Mogende geliefden
# 224: 2en hem Suppliant ten fine voorschreven te 20-
# 225: corderen der selver permissie en Pasport. Waer
# 226: op gedelibereert zynde ‚ is goetgevonderi en ver-
# 227: staen , dat ten behoeve van den Suppliant een
# 228: Pasport sal werden gedepescheert , om het voor-
# 229: schreve Schip met gepermiteerde Waren na
# 230: Vranckrijck te mogen doen navigeren e ende het
# 231: selve met Wynen ende andere gepermitteerde
# 232: Koopmanschappen (Brandewynen uytgesondert)
# 233: in dese Landen te doen retourneren. De Heeren
# 234: Gedeputeerden van de Provincie van Zeelandt
# 235: hebben de voorschreve Requeste overgenomen ;
# 236: en de conclusie gecontradiceert.
# 237: Is ter Vergaderinge gelesen de Requeste van
# 238: Jacob Alewynse Koningh , Koopman tot Rot.
# 239: terdam ‚ houdende ‚ dat hy Suppliant met de
# 240: Schepen de Postilion, Schipper Hendrick Gel-
# 241: smeer ‚en Margrieta, Schipper Arent Maerten.
# 242: se, gaerne na Vranckrijck soude uytvoeren ge-
# 243: permitteerde Koopmanschappen en van daer na
# 244: dese Landen te mogen invoeren Wynen eh an.
# 245: dere gepermitteerde Koopmanschappen : ver
# 246: soeckende dat haer Hoogh Mogende geliefden
# 247: aen hem Suppliant ten fine voorschreven te ac.
# 248: corderen der selver permissie en Pasport. Waes
# 249: op. gedelibereert zynde is goetgevonden en ver
# 250: staen , dat ten behoeve van den Suppliant een
# 251: Pasport sal werden gedepescheert, om sde voor.
# 252: schreve Schepen met gepermitteerde Waren na
# 253: Vranckrijck te mogen doen navigeren, ende de
# 254: selve met Wynen ende andere gepermitteerde
# 255: Koopmanschappen (Brandewynen uytgesondert
# 256: in dese Landen te doen retourneren. De Heeren
# 257: Gedeputeerden van de Provincie van Zeelandt
# 258: hebben de voorschreve Requeste overgenomen ,
# 259: en de conclusie gecontradiceert.
# 260: ls ter Vergaderinge gelesen de Requeste van
# 261: Johannes Hermanides, ie Koopman ot Rotter-
# 262: dam, houdende ‚ dat hy Suppliant met de Sche.
# 263: pen de Appolonia, Schipper Ary Cornelisse den
# 264: Boet groot vyftigh vat, ende de Providence,
# 265: Schipper Daniel Danen , groot seventigh vat,
# 266: gaerne na Vranckrijchk soude uytvoeren geper-
# 267: mitteerde Koopmanschappen 5; ende van daer na
# 268: dese Landen te mogen invoeren Wynen ende an-
# 269: dere gepermitteerde Koopmanschappen ; ver.
# 270: fe oe ck en de dat haer Hoogh Mogende geliefden
# 271: aen hem S uppliant ten sine voorschreven te accor-
# 272: deren der selver permissie en Pasport. Waer op
# 273: gedelibereert zynde is goetgevonden en verstaen ,
# 274: dat ten behoeve van den Suppliant een Pasport sal
# 275: werden gedepescheert , om de veorschreve Sche.
# 276: pen met gepermitteerde Waren na Vranckrijck te
# 277: mogen doen navigeren 1 en de selve met Wynen
# 278:
#
# 279: ( Brandewynen uytgesondert ) in dese Landen te
# 280: doen retourneren. rx De Heeren Gedeputeerden
# 281: van de Provincie van Zeelandt hebben de voor.
# 282: schreve Requeste overgenomen i ende conclusie
# 283: gecontradiceert.
# 284: Is ter Vergaderinge gelesen de Requeste van
# 285: Pieter Ia Modt , houdende, dat hy Suppliant met
# 286: hetS chip genaemt de Vreede groot hondert en
# 287: dertigh vat gaerne na Vrancktijck soude uyt-
# 288: voer en geper mitteerde Koopmanschappen ende
# 289:
#
# 290: Wynen ende andere gepermitteerde Koopman.
# 291: schappen 5 versoeckende dat haer Hoogh Mo-
# 292: gende geliefden aen hem Suppliant ten fine voor.
# 293: schreven te accorderen der selver Permissie ende
# 294: Pasport. Waer op gedelibereert zynde is goet.
# 295: gevonden en verstaen, dat ten behoeve van den
# 296: Suppliant een Pasport sal werden gedepescheert,
# 297: om het voorschreve Schip met gepermitteerde
# 298: Waren na Vranckrijck te mogen doen navigeren i
# 299: ende het selve met Wynen en andere gepermjt-
# 300: teerde Koopmanschappen ( Brandewynen uytge-
# 301: sondert) in dese Landen te doen retourneren,
# 302: De Heeren Gedeputeerden van del Provincie van
# 303: Zeelandt hebben de voorschreve Requeste over-
# 304: genomen , ende de conclusie gecontradi-
# 305: eer t.
# 306: Is ter Vergaderinge gelesen de Requeste van
# 307: Jacob Kreynen Groen ‚ Schipper van het Schip
# 308: de Amilia, groot sestigh vat . houdende, dat
# 309: hy Suppliant met het voorschreve Schip gaerne na
# 310: Vranckrijck soude uytvoeren gepermitteerde
# 311: Koopmanschappen 5 versoeckende, dat haer Hoog
# 312: Mogende geliefden aen hem Suppliant ten fine
# 313: voorschreven te accorderen der selver permissie
# 314: en Pasport, Waer op gedelibereert zynde is goet-
# 315: gevonden en verstaen; dat ten behoeve van den
# 316: Suppliant een Pasport sal werden gedepescheert,
# 317: om het voorschreve Schip met gepermitteerde
# 318: Waren na Vranckrijck te mogen doen navigeren,
# 319: ende het selve met Wynen en andere gepermit-
# 320: teerde K oopmanschappen (Brandewynen uytge-
# 321: sondert ) in dese Landen te doen retourneren.
# 322: De Heeren Gedeputeerden van de Provincie
# 323: van Zeelandt hebben de voorschreve Requeste
# 324: overgenomen , ende de conclusie gecontradi-
# 325: Ont angen een Missive van den Heere van AI-
# 326: melo haer Hoogh Mogende extraordinaris En-
# 327: vove aen verscheyde Hoven in Duytschlandt ‚ ge-
# 328: schreven tot Trier den ses en twintighsten der
# 329: erlede maendt December , houdende adver-
# 330: 1 10 en onder anderen, dat vermits de bele-
# 331: verinee van Traerbach eerder geëyndight was als
# 332: 7e de ver moed. en oversulcks de duysent
# 333: wi edaelders in specie (daer van hy Heere van
# 334: A elo een Wissel-brief hadde gegeven aen den
# 335: ere Ef Prins van Hessen tot voortsettinge
# 336: a devoornoemde belegeringe op den Banquier
# 337: Beal tot Frankfurt X- noch niet aengekomen
# 338: 710 Dei Heere van Almelo ‚ tot verval van de
# 339: Juel sche onkosten van den Heere Grave van
# 340: 0 Vrieslandt daer hadde moeten leenen hon-
# 341: sert uistolen. dewelcke hy tot Trier aen den sel-
# 342: ven wederom hadde doen betalen door Martin
# 343: C not. Banquier tot Trier voornoemt, en
# 344: ven den elven een Wissel-brief gegeven ter voor-
# 345: eve ne. tot laste van haer Hoogh Mogen-
# 346: de verboeckende derhalven , dat haer Hoogh
# 347: Movende veliefden de voornoemde penningen
# 348: te ee voldoen ende dat alsoo
# 349: ee ornoende penningen de onkosten
# 350: 7 vallen de bovenstaende duysent rijcks-
# 351: er. dien getrocken waren 7 weder-
# 352: do den Heere Erf-Prins moesten werden
# 353: ae ou eert. daer omtrent hy Heere van AI-
# 354: P 1 de noodiee soroe soude dragen , dat de voor-
# 355: ene somme tot profijt van den Staet wierde
# 356: ebraolit. Woaer op vedelibereert zynde is goet-
# 357: bevonden en verstaen, dat Copye van de voor-
# 358: fe hreve Missive gesonden sal werden aen den
# 359: R edt an State - rm tot betalinge van den voor-
# 360: schreven’ Wijssel-brief van een hondert pistolen de
# 361: noodige ordre te stellen.
# 362: Ontfanoen een Missive van den Commandeur
# 363: Planten veschreven in de Clundert den dertigh-
# 364: sten der voorlede maendt December 5 houdende d
# 365: dat hv over veertien dagen geleden stricte ordres
# 366: van de Heeren Gecommitteerde Raeden van de
# 367: Staten van Hollandt en West-Vrieslandt hadde
# 368: ontfanven om in dat District devoiren aen te
# 369: wenden om den uytvoer van Paerden na den
# 370: Vvandt te beletten , ende dat hy bevondt, door
# 371: nauwkeurieh ondersoeck, dat hy daer op hadde
# 372: gedaen . dat de meeste fraudes wierden toege-
# 373: saten ende gevoveert door dat de Commisen ten
# 374: platten Lande, dewelcke voor geldt de Menschen
# 375: die Paerden na den Vyandt braghten een Pasport
# 376: of wel een Bewvs vergunden, en seyden in dese
# 377: hare Bewysen, dat die Paerden op hare Boecken
# 378: stonden aenveteyckent daer nochtans die Paer-
# 379: ( len on haer Boeck niet bekendt waren, het wele-
# 380: ke heel moevelijck te aghterhalen was , ten zy
# 381: haer Hoogh Mogende oeliefden hem Comman-
# 382: deur of vemandt anders te ordonneren om in
# 383: Prinslands t Gestel, Oudenbosch , Hoeven, Et-
# 384: ten, de Leur (dewelcke alle Dorpen waren die
# 385: onder de Generaliteyt gehoorden ) alle de Stallen
# 386: te visiteren, ende alle de Boeren of andere Men-
# 387: schen haer Paerden aen te halen die geen bewys
# 388: konden toonen, dat hare Paerden op den Com-
# 389: mis sijn Boeck stonden aengeteyckent ‚ onder
# 390: wiens jurisdictie sy behoorden ; dat hy Comman-
# 391: deur niet wilde twyffelen, of die geene die haer
# 392: Hoogh Mogende souden gelieven die commissie
# 393: te geven veele fraudes van de Boeren ende andere
# 394: Menschen, en; veele vuyligheden van de Com-
# 395: misen soude ontdecken 5 want dagelijcks veele
# 396: Paerden door die vuyligheden na den Vyandt
# 397: wierden toegebraght, het welcke de Officieren
# 398: van desen Staet door hare Partyen niet konden be-
# 399: letten , nademael de Boeren (soo ras als’er een
# 400: Partye van den Staet sich ten platten Lande liet
# 401: sien ) dagelijcks malkanderen waerschouwden ,
# 402: soo dat de Officieren van desen Staet ( hoe dick-
# 403: wils dat sy oock Partyen uytsonden ) e noyt yets
# 404: konden attrapperen ; versoeckende hy Comman-
# 405: deur op het geene voorschreven haer Hoogh Mo-
# 406: gende nadere ordres te mogen weten. Waer op
# 407: gedelibereert zynde is goetgevonden ende ver-
# 408: staen, dat Copye van de voorschreve Missive ge-
# 409: sonden sal werden aen het Collegie ter Admirali-
# 410: teyt op de Maze, ende het selve aengeschreven,
# 411: op de fraudes van hare Bedienden daer in ver-
# 412: meldt behoorlijck ondersoeck te laten doen, te-
# 413: ven de schuldigen te procederen ‚ en tot weerin-
# 414: ve van den uytvoer van Paerden de noodige or-
# 415: dres te stellen volgens de Placaten van den
# 416: Lande.
# 417: Is ter Vergadering gelesen de Requeste van
# 418: Nicolaes Hollaert Burger ende Koopman tot
# 419: Zirckzee, als Reeder en Eygenaer van het Buys-
# 420: schip de Vreede, Schipper Lieve Kreynse, mits-
# 421: paders Philips van Lieuwen, Burger en Koop-
# 422: mae tot Rotterdam, als Eygenaer van de Ladin-
# 423: ge van het voorschreve Schip ‚ houdende, dat
# 424: vermits den eersten Tunii des voorleden jaers het
# 425: verbodt van Commercie en Correspondentie met
# 426: de Franschen zynde komen te cesseren, den eer-
# 427: sten Suppliant ‘het voorschreve Schip hadde doen
# 428: navigeren na Bourdeaux, alwaer het selve voor
# 429: rekeninge van den tweeden Suppliant was gela-
# 430: den met ses en veertigh vat Stadts Wyn 3 dat daer
# 431: mede van daer zynde vertrocken na Rotterdam ,
# 432: het voorgevallen was, dat het selve Schip op de
# 433: voorschreve sijne reyse door een Engelsche Arma-
# 434: teur was genomen , en aldaer opgebraght ; ver-
# 435: soeckende doordien desen Staet met Engelandt
# 436: was in alliantie en vrundtschap, en oversulcks der
# 437: selver Onderdanen niet vermoghten de vaert en
# 438: navigatie van de Ingezetenen van desen Staet te
# 439: troubleren en verhinderen , ja selfs niet op Vrank-
# 440: rijck ‚ nademael daer toe na den eersten Junii
# 441: veen de minste redenen wierden gevonden, dat
# 442: haer Hoogh Mogende geliefden den Heere van
# 443: Vrybergen , der elver extraordinaris Envoye
# 444: aen het Hof van hare Majesteyt de Koninginne
# 445: van Groot Brittannien , aen te schryven van alle
# 446: meest krachtige devoiren daer sulcks van vrucht
# 447: konde wesen aen te wenden , ten eynde der Suy.
# 448: plianten voorschreve Schip en Ladinge kost. en
# 449: fchadeloos moghte werden ontslagen. Waer op
# 450: gedelibereert ynde is goetgevonden en verstaen,
# 451: dat Copye van de voorschreve Requeste geson.
# 452: den sal werden aen den gemelden Heere van Vry.
# 453: bergen > om sulcks, ende daer het van vrucht fal
# 454: konnen wesen ‚ devoiren aen te wenden , ten
# 455: eynde der Supplianten Schip en Ladinge ontsla.
# 456: gen ; ende aen haer gerestieueere moge wer.
# 457: den.
# 458: ve
# 459: Ontfangen een Missive van den Generael MaL
# 460: jor Tcharner, geschreven tot Bergen op Soorm
# 461: den een en dertighsten der voorlede maende, ge.
# 462: addresseert aen den Grisfier Fagel, versoeckende
# 463: temogen weten wathy doen sal met de Personen
# 464: van Bidarden Girauld, door den Commandeur
# 465: Loncque d’Oofterlandt derwaerts gesonden.
# 466: Waer op gedelibereert ynde is goetgevonden en
# 467: verftaen , dat Copye van de voorschreve Missive
# 468: gestelt al werden in handen van de Heeren Ham,
# 469: en andere haer Hoogh Mogende Gedeputeerden
# 470: corde Militaire f aken 6 om te visiteren, ex eni
# 471: heren en van alles alhier ter Vergaderinge ap.
# 472: 5 a 7
# 473: port te doen.
# 474: De Heeren Gedeputeerden van de Provincie
# 475: van Zeelandt hebben ter Vergaderinge voorge.
# 476: dragen, dat Jacques de Salvé, Lieutenant van de
# 477: Compagnie vanden Major Jongbloet aen de Hee.
# 478: ren Staten van de hoogh gemelde Provincie had.
# 479: de te kennen gegeven , dat des selfs Broeder Pier.
# 480: qd e Saly 6 7 ra n seh P redikant tot Aerdenb ergh,
# 481: ten jare 1689. op het versoeck van de Fransche
# 482: Synode, alsdoen tot Rotterdam vergadert, ende
# 483: met approbatie van den Raedt van State sich had.
# 484: de begeven na Vranckrijck , om aldaer den dienst
# 485: Godts waer te nemen , en het Woordt heymelijck
# 486: en als onder het kruys te verkondigen; dat hy nau-
# 487: welijcks aldaer gearriveert zynde het ongeluch
# 488: hadde gehadt van ontdeckt, en aenstonde door
# 489: bevel des Koninghs in gevangenisse gesteld te
# 490: worden , werdende van de een tot de andere
# 491: Plaets vervoert , tof dat eyndelijck gebraght a
# 492: op het Kasteel van Pierre Encise te Lions, slwaer
# 493: noch gedetineert wierde; dat in Engelandt een
# 494: Roontsch Bisschop, eenige Priesters en Geeste.
# 495: lijeke synde opgebraght, komende van de Fran.
# 496: sche West-Indien ‚ hy Suppliant geinformeere
# 497: was dat hare Majesteye van Groot Brittannien ge-
# 498: reresolveert hadde de selve niet te laten lossen ,
# 499: dan voor die van de Religie op de Caleyen sit.
# 500: tende, ofte in eenige Gevangen huysen gecon.
# 501: demneert, waer door een middel oude konnen
# 502: Wesen waer door den gemelden Pierre de Salyé
# 503: uyt sijne langhduyrige gevangenisse soude kon.
# 504: nen werden verlost ; versoeckende dat daer te
# 505: devoiren by hooghit gedachte hare Majesteyt
# 506: moghten werden aengewendt , ofte wel indien
# 507: 5
# 508: (
# 509: )
# 510: Den 2. Januarii
# 511: B
# 512: van
# 513: sulcks niet vallen konde ‚ dat die verlossinge
# 514: moghte geschieden tegen eenige Officieren by
# 515: Hochstet gevangen ; dat sy Heeren Gedeputee,.
# 516:
#
# 517: haet Hoogh Mogende voor te dragen, en te ver.
# 518: foecken dat alle deb ste u e gen ende ie idd elen
# 519: mogen werden in het werck gesteldt om den ge.
# 520: amtlden Peer € de 5 alvé te verh 0 sen. Waer
# 521:
#
# 522: i ii van het voorsch re ve geproponeerde k e nnisse
# 523: sal werden gegeven aen den Heere van Vryber.
# 524: gen, haer Hoogh Mogende extraordinaris En.
# 525:
#
# 526: ginne van Groot Brittannien, om daer het van
# 527: dienst al konnen wesen devoiren aen te wenden,
# 528: ten eynde den gemelden Pierre de Satvé tegen een
# 529: van gemelde Roomsche Priesters moge werden
# 530: uytgewisselt ; en dat dien onvermindert Copy.
# 531: vais het 190 esch ir eve 8 eproponeer de gestelde sal
# 532: werden in handen van de Heeren Hain, en an.
# 533: dere haer Hoogh Mog ende Gedeputeerden tot de
# 534: Misicaire saken, om te visiteren, examineren
# 535: eiide van alles alhier ter Vergaderinge rapport te
# 536: doen.
# 537: Is gehoort het rapport van de Heeren Ham,
# 538: ende andere haer Hoogh Mogende Gedeputeer.
# 539: den tot de Misitaire saecken hebbende, in ge.
# 540: volge en tot voldoeninge van der selver Resolstie
# 541: 6 ommissori ael van den j sesden der voorlede
# 542: tmzende Er met en nevens eenig e Heeren Gecom-
# 543: mitteerden uyt den Raedt van State, geëxami.
# 544: neert het geproponeerde van de Heeren Gedeyu.
# 545: eerden van de Provincie van Utrecht, tenderen.
# 546: de ten eynde door haer Hoogh Mogende inte.
# 547: celie de Fransche Gereformeerden , die op de
# 548: Caleyen ge k omen zyn ei tege ns gev angen Evan.
# 549: sche Officieren en Soldaten mogen werden uytge-
# 550: wisselt. Waer op gedelibereert ynde is goet
# 551: gevonden en verstaen, dat den Heere van Vry.
# 552:
#
# 553: Envoyé aen het Hof van hare Majesteyt de Ko.
# 554: ninginne van Groot Brittannien , sal werden
# 555: tengeschreven , dat haer Hoogh Mogende wel
# 556: gehege eq yn om in soodanige’ uyewifs ei nge te
# 557: consenteren, en die te helpen bevorderen wan.
# 558: neer die uytgewerckt kan worden ; dat hy dethal.
# 559: ven sal innemen de gedachten die mena Enge.
# 560: landt heeft’, of en door wat middel soodanige
# 561: wisseling werckstessigh gemaeckt sal kunnen
# 562: werden , dewyle hooghst gedachte hare Maje-
# 563: steyt haer albefeydts mede daer toe genegen ge.
# 564: toont heeft.
# 565: Is gehoort het rapport van de Heeren Hams,
# 566: ende andere haer Hoogh Mogende Gedepnteer.
# 567: den tot de Militaire saken , hebbende, in ge
# 568:
#
# 569: ie mms m i sf ori ae I van dense ven en twintighsten der
# 570: voor led em ac nm de, 5 met e n ne vens eenige Hee ven
# 571: Gecommitteerden uyt den Raedt van State, ge-
# 572: examineert de Missive van den Generael Grave
# 573: nr lo oeltireven tot Trier den. negen-
# 574: goden daer te vooren , kenniffe gevende hoe
# 575: Te cen Porrifan van den Koningh van Pruyflen
# 576: ooatmeaneert en gechargeert hadde een Parti{an
# 577: Dr aunes van. den Staet „ ‘die, veertigh
# 578: Bte omtrent twee uvren van Metz hadde op-
# 579: coel {accende dat het hem niet toeguam
# 580: Pat nde vo Meffn onder contributie te ftel-
# 581: en budi actie verlooren. hadden twin-
# 582: PD * onde den Parti{an die gevangen
# 583: 29 Aat hv Generael de Pruyflifche Partye hadde
# 584: A vohecrhalen. en te Trier brengen , ende
# 585: A dear fan {oude houden tót nader ordre van
# 586: Tc Heaoh Mooende. … Waer „op. gedelibereert
# 587: IE Dn cn den: enverkaen dafaen ge
# 588: el Grave van Noyelle: {al werden
# 589: beer dat haer Hoogh ‘Mogende haer
# 590: De ellen het geene: by..hem in defen is
# 591: en Ado dat hv den gemelden Partifan {al
# 592: DE der otdre van haer Hoogh Mogen-
# 593: A Aavaarte alvoorens. hier omtrent verder. te
# 594: neren fl werden afgewacht het antwoordt
# 595: tt Oarmiffaris Hape, aen wien den Ont-
# 596: toer Peters over dit voorval gefchreven heeft,
# 597: fd oodsy
# 598: fal komen te geven:y 751
# 599: Te ver Verzaderinge zelefen de Memorie van
# 600: A Heere Palmauilt „ extraordinaris. Envoyé
# 601: van fine Maiefteyt den Koningh van Sweden
# 602: Londerde klohten over de licentie-der -Couran-
# 603: oe en Nouvelb{ten in het debiteren, van faken
# 604: tar nadeel van fine Majefteyt den Koningh van
# 605: eueden volgende de voorfz Memorie hierna
# 606: 3%
# 607: 6
# 608: geinfereert.
# 609: 9b
# 610: Bnr:
# 611: sbnys no nb
# 612: ol: 10:
# 613: “193
# 614: Me:
# 615: Colac Prebotentes Domin.
# 616: tod
# 617: dea Rovi Maiehas Suecia dum federa fanéte
# 618: Ve itizaue lees cumulate adim-
# 619: lend Cote veliio (imo animo fatisfacit  4ijk
# 620: am Ce (e (entiat > exoptatmm interer-
# 621: me fd: vermin con(ecutam enn putabit. Cu-
# 622: Gus Zu bnc ulaue. diem confantis <7 inviolate
# 623: en nea adterri olet documenta. … 4aum, ta
# 624: mad arie (uciat . In Cxteris €09 MATIs C9M-
# 625: Bim aus zulle leve > nullo pafto debitam pro-
# 626: ls Un amor tn Lederatos, uoluntett, UHICe A6
# 627: ortum vel; debeat » : Maderatienem. (cilicet l-
# 628: ie Se ouda. ue ditionen Beftiemzin-
# 629: Sion belli Lrtem ac Lomitem intactam velin=
# 630: jure zun Ture Tao erin O0dEMGUE
# 631: Aimo ols disadentibus ; nti. :; IHujus tam
# 632: pearlort movie oloriam … auam laud:bus condignis
# 633: tol eauum erat … maultis e contrario modis ma-
# 634: Lone carb ze imnminui< aon hae acro anni {en[ù
# 635: zSllieit  auod conlalte fecit… 1d; coafum, fecijje
# 636: malen contendant ‚Ia novi(lina: expeditione ad
# 637: Zilefe hnes cladem copiarsm Suecicarum. fngunt ;
# 638: acuba deniaue in bunt fenlam alia iaant gu
# 639: vam omnium falen ,qwia uaa hofium conftans
# 640: voidentiime aronit, nilil ef guod ei probanda inr
# 641: oremur. Sed cum hi, aliigue ejnfderù farihà 11=
# 642: mores in bis maxime Provinciis crebri fint a6 fre-
# 643: auentes, uide illi oriantur , 3 a gibus preeipuê
# 644: Foveantur , opera pretium erit inqutrere.” Origo
# 645: (ane nom aliis ‚ guam (acre Regia Majeflatis 4n-
# 646: micis € invidis ad(cribenda. videtur. - Qaa vere
# 647: via in valens (bargantur ‚ narrationes Terum Hova-
# 648: rum publica dubitare aon finunt ; [ant enim he in
# 649: (acram Reciam Majeftatem adeó nique , ut ple-
# 650: rumoue tuba hoftilis ‚ (ape lbelli famofi referant
# 651: (beciem. _ Chjus rei cum innumera extent, 46 fere
# 652: auotidiana exempla, uaum duntaxat ex recentiort-
# 653: bus bic adnexum allegare libet. In quo nimirum
# 654: (acra Revia Majeflas rerum \odiofif]imaruêe fupi-
# 655: cionibus indigno prorfus modo con{pergiur: >
# 656: Hac talia ficati a privatis profetta vette, con-
# 657: temnuntur ita autoritate publaca , {ub oculis Celf:
# 658: ac Prep. Domin, Veftr. evulgata ac tolerata ‚quam
# 659: aoxia (int ac venenijera, cum ratio docet , tum.ex-
# 660: perientia.  Ouicquid enim [pirant eju[modi [cripta,
# 661: id vulens inperitum , non ut privatorum. [ed Ht
# 662: Mariam eorumaue gui ad Gubernacula [er
# 663: dent Reivublice… (en(u arripit ac probat. Et qmd-
# 664: zi cum [ub horum umbra Apis n[petantious 3
# 665: in lucem örodeant. . Hinc invidia , odin 5 male-
# 666: volentia tn Sueciam : Hinc favor in Suecia, hoftes,
# 667: vel in vota pro horum pro[peritate armorum aperte
# 668: brorumpens.  Negue vero intra plebera hoe confi-
# 669: Gt mali. Servit contaiofum ad primores ; eos [al-
# 670: erm oui animo minus Guam nomine a multitudine,
# 671: rerunur Hinc in deliberationes u(gue srrepit. pu=
# 672: bea: ubi mentes calämniis ac’ perver[a rerum n0-
# 673: ta inbe — ualia in (acram Reziam MMajeftaz
# 674: tem [uvoerant confilia explicatione non eget.
# 675: ob
# 676: Cum itaaue borum (criptorum licentiam . quan
# 677: maxime interfit coërceri ‚ adeo ut 1n omni, bene
# 678: Coniktite Republica iis cofivandis etiam cen[ores
# 679: avon (oleant  (acra Reuia LMaj. tnfrafcriptus Ab=
# 680: leratus extraordinarins ex (peciali mandato , eam a
# 681: CC. ac PP. D. D. V.V. decenter requirit curam,
# 682: ama búc etiam in varte amicitia colende volnntas
# 683: um orbi umer … tum barum prelertim Provin-
# 684: ciarum incolis tonfet per(bicaa. C° indubitata ; Fo-
# 685: vebitur bot bafto animorum utrique conjunétio , ad
# 686: mutua commoda promovenda utilis ac necef[aria z
# 687: £, (ers Rovie Maiehati, prater eam qua praftitt
# 688: es oo tiam comitatur voluptatem ‚ novus ad
# 689: onefciendum úecedet fimulus „ ubi grata Je fa-
# 690: ore igrellicir. … Hace-Comitis die 31. Decembris:
# 691: L704-
# 692: ft od:
# 693: aise 107
# 694: wi
# 695: ied ae
# 696: et A10
# 697: JT. Palmguiit..
# 698: scion ost
# 699: Evere ie ei be
# 700: Waer ob ordelibereert zynde is goetgevonden, en.
# 701: veritaen dát Conve van de voorfchreve Memo-
# 702: Ge oeftcldt {al werden in banden van de Heeren
# 703: ir Cent -en-andere haer Hoogh Mogende Ge-
# 704: Jenutcerden tot de Buytenlandtíche {aken, om.
# 705: (te ifiteren. examineren. emvan alles;alluer.ter,
# 706: 7 Is ter Vergaderinge gelefen de Memorie van
# 707: den Heere van Stocken, extraordinaris Envoyé
# 708: van fijne Majefteyt den Koningh van Denemáfc.
# 709: ken , verfoeckende ont{laginge van Hillebrand
# 710: Omflen , te Sluys gearrelteert ‚ komende van
# 711: Duynkercken, volgende de voorfz Memorie hier
# 712: na geinfereert.
# 713: (Omme un certain Marchand de Bergen en
# 714: 4 Norvegue ‚ nommé Hillebrand Omen a [or
# 715: retour de Dunquerque, ou il avoit efté pour
# 716: les affaires a efté arrefte a DEclufe en Flandres
# 717: de foufligné Envoyé extraordinaire de (a Majefté le
# 718: Roy de Danemarc, CC. ne peut pas sempecher de
# 719: Stnterefer pour un [njet du Roy fon Maiftre , € de
# 720: prier Vos Hautes Puifunces de vonloir avoir Ia
# 721: bonté d’accorder un Pafzport pour ledit Hille.
# 722: brand Omen, que afin qwil puiffe eftre mis en li
# 723: berté an plùtof , <7 venir dans ce Pays cy. A
# 724: Ja Haye Ce 2. Janvier 1705.
# 725: ob
# 726: Ist
# 727: Waer op gedelibereert zynde is goetgevonden en
# 728: verltaen, dat Copye van de voorfchreve Memo
# 729: tie gefonden {al wêrden aen den commanderen-
# 730: den Officier tot Sluys, om des {elfs bericht daer
# 731: op aen haer Hoogh Mogende te laten toeko-
# 732: men.
# 733: Ister Vergadering gelefen de nadere Memo.
# 734: rie van den Gedeputeerde van het Hertoghdom
# 735: Limburgh Limpen ‚ wegens de pretenfie door
# 736: lijne Majefteyt den Koningh van Pruyflen tot lafte
# 737: van het gemelde Hertoghdom gemaeckt , vol
# 738: gende de voorfchreve Memorie hier na geïnfe-
# 739: reert,
# 740: sbr
# 741: rh;
# 742: YW
# 743: E [ou{Jigné Deputé des Efats du Duché de Lim
# 744: Li bourg , © autres Pays outre Menfe , a en
# 745: P honneur de teprefenter a Vos Hautes Puiflun-
# 746: Ces par fes Memoijes da trente urième dOGobre
# 747: © neufémie Dée. dernier, que fa Maj. Prufienne
# 748: %e Pouvoit par ucun titre legitime du droit vecher.
# 749: eher les Efats, ij les jets de la mefme Province
# 750: pour une’ dette tontraftée de Ia part dé fa Majeft
# 751: Catholique Chafle fecond , de glorienf tmemiict
# 752: ens interventijn ôu Confentement , beaucoup moin;
# 753: envoyer enlever armata manu Ìs Griffer de P Efa
# 754: Ecclefaftigie & Noble de ladite Province, © Ie
# 755: tenir en arteft dans la Ville dé Wefel jufgues a pre.
# 756: (eat attendi te la dette en gueftion of} virement
# 757: Perfonellé , C> né peut conftcutivement eftre recher.
# 758: bte, qa charge des Heritiers € Succefeurs de
# 759: fdite Majefié Catholique ‚ © Aullèement à charge
# 760: des Efats ou Sijets de Ta Province [ufdite, come
# 761: € paroit par 1d joyenft entrée © autres privil:ves
# 762: € libertés des Provinces de Brabänt & Einsbourg,
# 763: que [a Majefté fiefdite avoir juré d ob[orver invig-
# 764: lablement a P exemple de tons [ès Predecéfeuri, os
# 765: Hautes PuiJunces ont bien vonlu appointer fer Ie
# 766: Memoire du neufiëme Decembre dernier, gil [g-
# 767: roit mis entre les mains de Monfieur de Effen ©
# 768: autres Seigmeurs commis aux affaires eftrangert ,
# 769: afin de Pexaminer , ‘entrer la deffus en conference
# 770: avec Monfr. le Baron de Schmetteau, Plenipoten-
# 771: taire de Ja Majefté Prufienne , © enfutte faite rap-
# 772: port a Vos Hautes Duiffances, © Comme dé depuis
# 773: affaire oft en amant changé de fate , due Mon[”.
# 774: de Happe ‚ Confeiler & Commifaire de fa Maje.
# 775: 1é Pruffienne a fait entendré aax Eftats de la Pro-
# 776: vince de Limbourg , qie le Roy [on Maiftte [$ con:
# 777: tenteroit d'une [omme de vingt © deux mille teus
# 778: pour toute redevance de la dette en gueftion, pour
# 779: ven, que les Eftats de ladite Province Poblitergient
# 780: 4 payer cette (Omme en trois années confecutives par
# 781: etales portions hors les aides > fubfides , a aceor-
# 782: der a fa Majefté Cùtholique ‚ Te Zui ne ft pourra
# 783: faire [ans le'confentement de Pos Hautes Puiftnces
# 784: dux gu elles lefdites aides @ [ubfides [ont affignees
# 785: per Ja Majefté Catholique Charle troifiëme. “Rai:
# 786: [on pourquy que le [ouf]igné {2 retiré derechef en-
# 787: vers Vos Hautes Pui unces, les Snppliant trèrhum-
# 788: blemen que leur bon plaifir [vit de donner teur
# 789: con[entement a ce que deffus , afin que les Eftats' de la-
# 790: dite Province puifent par ce moyen contenter fa Ma
# 791: jehé Prujfienne ‚ © retirer ler Prifonnier ‚ en
# 792: qroy Vos Hautes Puifances ne perdront , ue Pat
# 793: tante parce qu'a4 bout de ces trois anntes ellés rentre_
# 794: ront dans Dentitrte perception de la ufdite affigna-
# 795: tion jufgues a ce qu'elles [oyent [atisfaites des zvan-
# 796: Ces qelles peuvent avoir fuites pour [a Majefté Ca-
# 797: tholique ‚ ou fi contre toute attente Vos Hates Puif:-
# 798: fences ne trouvent pas a propos dy confentit , que dá
# 799: moins en ce cas elles [oyent [ervies de prendre une
# 800: vigouren[2 refolution a protcer lefdits Eflats "contre
# 801: les pretenfions de fadite Majefit Pruffeiné ‚ plifgae ve
# 802: feroit la derniere injufice de les obliger a payer les
# 803: tefmmes aides G> [ubfides en deux endroits , ontre que
# 804: Ce leur et abfolument impoffible, parce que te Pas
# 805: ef} entietement uint par les querres Contintelles €
# 806: les contributions qwil ft encor oblicé de paer.
# 807: Hauts S° Puifants Seignears il ya deus mois ; “gie le
# 808: fouffigné eft ici a foliciter la protedion de cette it
# 809: luftre Republique' pas fans orands fraix di patvre
# 810: Peuple de ladite Province ‚ € leur Prifvinier ef
# 811: detenn a Wefel dépuis 16 mois d Aonft dirnier'4 des
# 812: plus grands fait , ain[j Ie [ouffiené prie tret in-
# 813: Famment Vos Hautes Puijances dincliner frvord-
# 814: blement a [u demande ‚ € dé prendre une cotrte
# 815: > bonne vefolution pour le foularement di’ parore
# 816: Peuple ‚ quoy faifens , cc.
# 817: 2gnils
# 818: )
# 819: Limpens:
# 820: zi bays fomsditsbog goe W 60 90
# 821: Waer op gedelibereert zynde is oöetgevonden en
# 822: verftaen, dat Copye van de vóor{chreve Memo-
# 823: rie oesteldt sal werden in handen van de Heeren
# 824: van Gent, en andere haer Hoogh Mogende Ge-
# 825: deputeerden tot de Buytenlandtsche saken, om
# 826: over het voorschreve subject te spreken met den
# 827: Heere Baron van Schmetteau , Plenipotentiaris
# 828: van sijne Majesteyt den Koningh van Pruyssen,
# 829: ende van alles alhier ter Vergaderinge rapport te
# 830: doen.
# 831: Ontfangen een Missive van de Heeren Gede-
# 832: puteerde Staten des Nymeeghschen Quartiers
# 833: geschreven tot Nymegen den een en dertighsten
# 834: der voorlede maendt, houdende, der selver re-
# 835: scriptie op haer Hoogh Mogende Missive van den
# 836: negen en twintiehsten daer te vooren, daer by
# 837: haer Hoogh Mogende de gemelde Heeren Gede-
# 838: puteerde Staten hadden versocht die voorsienin-
# 839: ge te willen doen, dat de ses Compagnien van
# 840: het Regiment van Schratenbach , in de Stadt
# 841: Grave guarnisoen houdende , ten spoedighsten
# 842: na Roermont moghten gaen: Waer op geen re-
# 843: solutie is gevallen.
# 844: Is ter Vergaderinge gelesen de Requeste van
# 845: Tacob Alewynse Koningh , Koopman tot Rot-
# 846: terdam , houdende , dat hy Suppliant op den
# 847: derden October 1703. van haer Hoogh Mogende
# 848: hadde geobtineert Pasport voor het Schip de Ste,
# 849: Clara ‚ Schipper Ary Danielsz, om van hier met
# 850: Kaes ‚Meekrappen 2. Peper en Granen na Vrank-
# 851: rijck te mogen varen, en van daer wederom in-
# 852: brengen Pruymen; versoeckende, doordien hy
# 853: Suppliant in het voorschreve Schip geerne oock
# 854: soude doen laden Won en andere gepermitteerde
# 855: Waren, dat haer Hoogh Mogende geliefden daer
# 856: toe aen hem Suppliant te verleenen der selver na-
# 857: der permissie en Pasport. Waer op gedelibereert
# 858: zynde is goetgevonden en verstaen, dat ten be-
# 859: hoeve van den Suppliant een Pasport sal werden
# 860: gedepescheert ‚ om met het voorschreve Schip
# 861: Wynen ende andere gepermitteerde Waren in
# 862: dese Landen te mogen inbrengen (Brandewynen
# 863: uytgesondert )- De Heeren Gedeputeerden van
# 864: de Provincie van Zeelandt hebben de voorschreve
# 865: Requeste copyelijck overgenomen, en de con-
# 866: clusie gecontradiceert.
# 867: Is ter Vergaderinge gelesen de Requeste van
# 868: de Kercken-raedt van Dieten , gelegen in het
# 869: Ampt tusschen Maes en Wael ; versoeckende,
# 870: om redenen in de voorschreve Requeste geëxpri.
# 871: meert, dat haer Hoogh Mogende geliefden aen
# 872: de Supplianten te accorderen der selver Pasport
# 873: om van Luyck na Dieten, de Maes af, ses hon-
# 874: dert hoet Kalck ‚ drie hondert voeder Gruys ‚drie
# 875: duysent waegh Koolen, en twee hondert duysent
# 876: Leyen te mogen laten brengen ‚ vry ende sonder
# 877: betalinge van eenigh recht, tot het weder in staet
# 878: brengen van hare ten eenemael vervallen Kerck
# 879: ende Toorn. Waer op gedelibereert zynde is
# 880: goetgevonden en verstaen . dat ten behoeve van
# 881: de Supplianten een Pasport in behoorlijcke forma
# 882: sal werden gedepescheert ‚ om de voorschreve
# 883: Materialen van Luyck na Dieten te mogen af-
# 884: brengen ‚ vry en sonder betalinge van ’s Landts
# 885: gerechtigheyt.
# 886: Is ter Vergaderinge gelesen de Requeste van
# 887: Ernst Fredrick 7 Prince van Saxen-Heylburgh 7
# 888: Brigadier en Colonel te paerdt ten dienste deser
# 889: Landen 5 versoeckende ‚ om redenen in de voor-
# 890: schreve Requeste geëxprimeert 7 dat haer Hoogh
# 891: Mogende geliefden hem Suppliant te eleveren
# 892: tot de digniteyt en charge van Generael Major te
# 893: paerdt. Waer op gedelibereert zynde is goetge-
# 894: vonden en verstaen , dat Copye van de voorschre-
# 895: ve Requeste gesteldt sal werden in handen van de
# 896: Heeren Ham, en andere haer Hoogh Mogende
# 897: Gedeputeerden tot de Militaire saken, om te vi-
# 898: siteren ‚ examineren, en van alles alhier ter Ver-
# 899: 7
# 900: gaderinge rapport te doen.
# 901: Is ter Vergaderinge gelesen de Requeste van
# 902: Margrieta de Baet ‚ mitsgaders haer Broeder ,
# 903: houdende ‚ dat haer Hoogh Mogende hadden
# 904: gelieven uyt consideratie van der Supplianten
# 905: overgroote diensten ‚ by de eerste Suppliante 2
# 906: ende haer Schoon broeder Philips Jamart, en de
# 907: verdere Familie, den Lande gedaen ‚ op der sel-
# 908: ver overgeleverde Requeste te resolveren, goet
# 909: te vinden en te verstaen , dat den Lieutenant Ge-
# 910: nerael Grave van Noyelle ‚ commanderende
# 911: langhs de Maze , sal werden aengeschreven de
# 912: Goederen van de Supplianten gaende en komen-
# 913: de na en van de Commase 5 reforterende onder
# 914: de vrye Baronnye van Herstal ‚ te laten passeren
# 915: ende repasseren , als voor desen , sonder beta-
# 916: linge van rechten ‚ ten ware hy redenen hadde
# 917: ter contrarie 7 alles breeder blijckende by der
# 918: Supplianten Request ende haer Hoogh Mogen-
# 919: de Resolutie van den
# 920: Januarii,
# 921: nevens de voorschreve Requeste gevoeght; ver.
# 922: soeckende, om redenen in de voorschreve Re-
# 923: queste geëxprimeert, dat haer Hoogh Mogende
# 924: geliefden de respective Ontfangers van de rech-
# 925: ten, of wel den Ontfanger Generael te gelasten
# 926: om aen de Supplianten de penningen uyt hoofde
# 927: voorschreven tegen den inhoudt van haer Hoogh
# 928: Mogende gemelde Resolutie de Supplianten af-
# 929: gevordert en gedaen betalen, wederom te resti-
# 930: tueren , en voorts van de voorschreve exemptie
# 931: i n het toekomende paisibelijck te laten jouisseren,
# 932: doch indien haer Hoogh Mogende in bedencken
# 933: moghten hebben genomen - dat de voorschreve
# 934: exemptie eenigh hinder of nadeel moghte toe-
# 935: brengen ’aen de Commercie deser Landen 9 dat
# 936: alsdan haer Hoogh Mogende geliefden de Sup-
# 937: plianten in plaetse van dien toe te leggen een pen-
# 938: ioen eenighsints geproportioneert na de diensten
# 939: by de Supplianten den Lande gedaen. Waer op
# 940: gedelibereert zynde Is goetgevonden en verstaen ,
# 941: dat Copye van de voorschreve Requeste gesteldt
# 942: sal werden in handen van de Heeren Ham, ende
# 943: andere haer Hoogh Mogende Gedeputeerden tot
# 944: de Militaire saken, om te visiteren , examine-
# 945: te doen.
# 946: Is ter Vergaderinge gelesen de Requeste van
# 947: Christoffel van Weerdenburgh , Contrerolleur
# 948: van de Posten ende Bodens van de Generaliteyt ,
# 949: versoeckende dat haer Hoog Mogende hem Sup.
# 950: pliant als in het voorleden jaer 2 ter sike van sijne
# 951: extraordinaris diensten wederom met twee Hon-
# 952: dert guldens geliefden te beneficeren. Waer op
# 953: gedelibereert zynde is goetgevonden en verstaen ,
# 954: mits desen te consenteren In het voorschreve ver.
# 955: soeck ‚ en werdt dienvolgende den Suppliant we.
# 956: derom toegeleght de somme van twee honderdt
# 957: guldens eens 7 daer van hem Ordonnantie sal wer.
# 958: den gedepescheert.
# 959: Is gehoort het rapport van de Heeren Ham
# 960: ende andere haer Hoogh Mogende Gedeputeer.
# 961: den tot de Militaire saken . hebbende. ‚ in gevol.
# 962: ge ende tot voldoeninge van der selver Resolutie
# 963: commisforiacl van den negen en twintighsten der
# 964: voorlede maendt ‚ met en nevens eenige Hee
# 965: ren Gecommitteerde uyt den Raedt van State,
# 966: ingenomen de consideratien van den Heere van
# 967: Ouwerkerck, Veldt Marschalck, over het mid.
# 968: del waer door bequaemst seven hondert man Re-
# 969: erutes gevonden sullen konnen werden, als mede
# 970: over den inkoop van Paerden in Engelandt te
# 971: doen voor de Ruyters en Dragonders in Portugal.
# 972:
#
# 973:
#
# 974:
#
# 975: gende Gee deputeerden, om me ten neverts eni.
# 976: ge Heeren Gecommitteerden uyt den Raede van
# 977: State die saecke nader te examineren , ende
# 978: van alles alhier ter Vergaderinge rapport te
# 979: doen.
# 980: De Heeren Ham, ende andere haer Hoogh
# 981: M 0 5 st de Ge deputeer de e n et de e M ilieai r ke
# 982: hebbende, in gevolge ende tot voldoeninge van
# 983: der selver Resolutie commissoriael van den
# 984: der voorlede maendt, met ende nevens eenige
# 985: Heeren Gecommitteerden uyt den Raede ven
# 986:
#
# 987: Heeren Staten van Zeelandt, rakende de bekom-
# 988: ineringe over het Eylande Tholen, ende het op.
# 989: houden van het Regiment van Beleastel in Vlaen.
# 990: deren, hebben ter Vergaderinge gerapporteert,
# 991: dat fy Heeren Gedeputeerden van advise souden
# 992: zyn, nademael beeydts ordre is gestelde om de
# 993: Regimenten, tot versterckinge van het Cuarni
# 994: foen van Bergen op Soom gedestineert, te doen
# 995: marcheren, en daer door het Eylande Tholen by
# 996: nieuwe vorst in meerder seeuriteyt al wesen, dat
# 997:
#
# 998: Cenerael Tscharmer aengeschreven behoort te
# 999: werden, de securiteyt van het voorschteve Ey.
# 1000: hadt oo veel mogelijck te helpen besorgen, vn
# 1001: cat aen den General in Vlaenderen commande
# 1002: rende ordre behoort te werden gesonden om he.
# 1003: Regiment van Bescastel na Zeelande te senden
# 1004: volgens haer Hoogh Mogende Patent, soo haes
# 1005: de Regimenten voor de Winter in Vlaenderen
# 1006: aldaer sullen wesen aengekomen. Waer op ge.
# 1007: delibereert aynde is goergevonden en verstaen
# 1008: mits desen te versoecken en te committeren de
# 1009: gemelde Heeren Ham, ende andere haer Hoogh,
# 1010: Mogende Gedeputeerden tot de Militaire saken
# 1011: meten nevens eenige Heeren Gecommitteer den
# 1012: uyt den Raedt van State, by haer E. sels ten.
# 1013: mineren, het gunt voorschreven is naderte exa.
# 1014: nine en , ende van alles alhier ter Vergadering
# 1015: rapport te doen;
# 1016: Op het gerapporteerde van de Heeren Ham,
# 1017: ende andere haer Hoogh Mogende Gedeputeer
# 1018: den tot de Militaire saecken, in conferentie pe.
# 1019: weest zynde met eenige Heeren Gecommitteer.
# 1020:
#
# 1021: deliberatie goetgevonden ende verstaen, dat de
# 1022: eerste Generaels van de Troupes van den Konin,
# 1023: van Denemarcken , ende van den Heere Lande
# 1024: grave van Hessen Cassel, ende specialijck van de
# 1025: ses duysendt man in dienst en soldye van Enge.
# 1026: landt en den Staet, sal werden aengeschreven ,
# 1027: dat haer Hoogh Mogende den Generael Grave
# 1028: van Noyelle gesonden hebben na Trier, om ge-
# 1029: duyrende de Winter de Troupes aen de Moesel
# 1030: en in de Pofteringe tusschen de Moesel ende den
# 1031: Rhyn te commanderen , ende dat den selven der.
# 1032: halven sullen obedieren, en soodanige voorsie.
# 1033: ninge doen ‚ dat de voorschreve Troupes obedie.
# 1034: ren aen de ordres van gemelden Grave van No.
# 1035: yelle ; dat den Heere Landtgrave van Hessen.
# 1036: Cassel by Missive sal werden versocht soodanige
# ...
# 4338: lacob Kempe, Schipper, houdende, dat haer
# 4339: Hoogh Mogende op den een en dertighsten De-
# 4340: cember laetstleden aen hem Suppliant hadde ge-
# 4341: lieven te verleenen der selver Pasport, om een
# 4342: Scheeps Ladinge met gepermitteerde Koopman-
# 4343: schappen uyt dese Landen by overschepinge te
# 4344: voeren na Brugee ende wederom van daer ge-
# 4345: permitteerde Koopmanschappen inbrengen; ver-
# 4346: soeckende ‚ dewyle de voorschreve Goederen
# 4347: aen den Dam by St. Donaes moeste voeren, ende
# 4348: sonder de welcke de voorschreve Goederen ter
# 4349: oedestineerde Plaets niet konde werden gebraght,
# 4350: dat haer Hooeh Mogende geliefden by nadere
# 4351: elueidatie van der selver Resolutie van den een en
# 4352: dertiohsten December laetstleden te verstaen , dat
# 4353: alle soodanige kleyne Vaertuygen ofte binnen-
# 4354: Schuvten. met die geene , welcke de overge-
# 4355: scheepte Goederen over en weder soude voeren,
# 4356: onder haer Hoogh Mogende verleende permissie
# 4357: en Pasporten waren begrepen, met last aen een
# 4358: veder dien het aengaen moghte sigh daer na te re-
# 4359: uleren. Waer op gedelibereerdt zynde, is
# 4360: voedtgevonden en verstaen , midts desen te con-
# 4361: senteren in het voorschreve versoeck , ende
# 4362: dien-volgende te verklaren, dat alle soodanige
# 4363: kleyne Vaertuygen ofte binnen-Schuyten met
# 4364: de Persoonen die de overgescheepte Goederen
# 4365: over en weder sullen voeren ‚ onder haer Hoogh
# 4366: Moveende pefmisfie en Pasport sullen wesen be-
# 4367: orehen midte dat de selve sullen moeten obser-
# 4368: veren de ordres by overschepinge gebruyckelijck,
# 4369: ende dat de voorsz Vaertuygen ende Schuyten,
# 4370: en die geene die de selve voeren , gehoorende
# 4371: aen ofte onder de Vyanden, daer en boven voor.
# 4372: fien sfullen moeten wesen van behoorlijke Pas.
# 4373: porten van Oorlogh, gelijck voor alle Wagens,
# 4374: Karren ende Schuyten op ’s Vyandts Bodem,
# 4375: verden vereyst 7 werdende een veder die het
# 4376: aengaet gelast hem hier naer Ve tegule.
# 4377: ren. De Heeren Gedeputeerden van de Pro.
# 4378: Y ine cie van Zeelande hebben de voorschreve Re
# 4379: queste overgenomen, en de conclusie gecontra.
# 4380: diceert.
# 4381: Is ter Vergaderinge gelesen de Requeste van
# 4382: de gefamen dij cke Gei ntresseerdens ‚ dewelcke
# 4383:
#
# 4384: Kroon van Engelandt noch onbetacle waren
# 4385: houdende, dat sy Supplianten hadden geresol
# 4386: veert yemandt te resofveren, ende te deputeren
# 4387: om naer Engelandt over te gaen, en de beta.
# 4388:
#
# 4389: krachtighste besolsiciteren , dat sy Supplianten
# 4390: daer toe ten hooghsten van noden hadden een
# 4391: Copie authenticq van de Extract van Rekenin-
# 4392: gen dewelcke Mr. Jacob vander Esch aen haer
# 4393: Hoogh Mogende dienaengaende badde ovetge.
# 4394: levert, en in de volle Vergaderinge van ee
# 4395: Hoogh Mogende met solemnelen eede bevestigt,
# 4396: versoeckende derhalven dat haer Hoogh Mo.
# 4397: gende geliefden aen de Supplianten te laten
# 4398: extraderen Copie authenticq der voornoemde
# 4399: Reeckeninge , van den voornoemden Me. Jacob
# 4400: vander Esch, met den solemnclen eede daer op
# 4401: gestelt, en voor haer Hoogh Mogende door den
# 4402: gemelden vander Esch afgeleght, om sich daer
# 4403: van des noots zijnde, te konnen bedienen; ven.
# 4404: foeckende verders dat haer Hoogh Mogende ge.
# 4405: liefden den Heere van Vrybergen , der selyer
# 4406: estraordinaris Envoyé aen het Hof van hare
# 4407: Majesteyt de Koninginne van Groot Baietannien,
# 4408: ij gel aft dat hy in 5 den naer van haer Hoogh
# 4409: Mogende niet alien de rechtvaerdige pretense
# 4410: der Supplianten by hooghstgedachte hare Maje.
# 4411: fteyt, en daer het verder van noden mochte we.
# 4412: fen B d op het nadruckelijckste soude hebben voor
# 4413: te dragen, maer oock der Supplianten Gede.
# 4414: pureerden , soo veel immers mogelijck, met
# 4415: racdt en dacdt assisteren, om eyndelijck tot een
# 4416: 8 E ki e. nst 7 effe ect in dese sware 1 olii citatie t el
# 4417: nen geraecken. Waerop gedelibereert zynde
# 4418: is goedtgevonden ende verstaen , dat aen de Suy.
# 4419: plfanten gegeven sal werden Copie authentic
# 4420: van de voorschreve Reeckeninge, en den eed.
# 4421: daer op gedaen ; ende dat den Heere van Vy.
# 4422: bergen ‚ haer H loogh M ogende extraordinarie
# 4423: Envoy € aen het Hof van har e Maj- esleyt de Ko-
# 4424: ninginne van Groot Brittannien „sal werden aen.
# 4425: gefchreven, aen de Supplianten , sulcke, ende
# 4426: daer het van de meeste vrucht sal konnen wesen,
# 4427: de behulpfame handt te bieden, en daer om’
# 4428: trent soodanige devoiren aen te wenden, en te.
# 4429: presentatie te doen e als hy sal oordeelen ear ie
# 4430:
#
# 4431: (47
# 4432: Den 10. Januari,
# 4433: val
# 4434: )
# 4435: bekomen van de betalinge van der Supplian-
# 4436: ten achterwesen j van het meeste effec allen
# 4437: zyn.
# 4438: Is ter Vergaderinge gelesen de Requeste van
# 4439: Anthony Alvares Machado ‚ Provediteur Ce.
# 4440: neracl, houdende, dat hy Suppliant geno,
# 4441: faeckt was Proces te suftineren voor de Raede
# 4442: van State, als gerequireerde in cas communicatie
# 4443: cer entre, open jegens Jacob van Rietschoten
# 4444: Schipper, requirant in hiet voorschteve cas ve,
# 4445:
#
# 4446: procedeert, dat naer dat die was voldongen, en
# 4447: in stact van wyse gebracht, den gemelden Raede
# 4448: van State by hare Sententie, in dato den voer.
# 4449: tienden Junii 1704, hem Suppliant hadden ve
# 4450: condemieert den voornoemden van Ries eo.
# 4451: ten, wegens het arrest op sijn Schip gedaen,
# 4452: kost en scha deloos te houden ende qindemmeren
# 4453: aen de selve op te leggen en te betalen de ve’
# 4454: sehene leghdagen, vledert den vyftienden
# 4455: gust 1 703 9 ‚en w y ders te besorg en 4 ac hety
# 4456: schreve Schip ten eersten uyt het voorschteye a,
# 4457: rest onuslagen wierde ‚ met condemnatie van
# 4458: kosten; dat den Suppliant met die Sententie ten
# 4459: hooghsten zijnde gegraveert, en hy sigh ve.
# 4460: beeldende dat van de Sententie van dex Raed
# 4461: van State, maer alleen open stonde het middel
# 4462: van Revisie, en niet van Appel, aen hact
# 4463: Hoogh Mogende hy Suppliant sich op den deie
# 4464: en twintighiten Juli 1704. hadde geaddresseere
# 4465: aen den gemelde Raedt van State, en versoght
# 4466: Mandement van Revisie, dat op de voorscht ye
# 4467: Requeste tot noch toe geen dispositie zynde ge
# 4468: volght, immiddess den voornoemden Ries eh,
# 4469: ten sigh hadde geaddresseert aen den Raedt van
# 4470: State, en versocht en geobtineert brieven van
# 4471: attache aen den Hove van Hollandt, uyt krat,
# 4472: te van dewelke hy Suppliant tot voldoeninge
# 4473: van den inhoude van de voorschreve genten,
# 4474: was geëxecuteert, en Proces in cas van eyfelinge,
# 4475: lieispendent was hangende voor den Ho 50 7
# 4476: Hollande, sonder dat nochtans by den voor.
# 4477: noemden Rietschoten cautie was gestele ee
# 4478: foeckende , doordien geconsidereert moeste
# 4479:
#
# 4480: onseecker niet konde blyven, ofte namentlijck
# 4481: hy Mandement van revisie soude obeineren, en
# 4482: aen de andere syde niet behoorde te werden pe.
# 4483: se xe uee el È immer a sonder dat cautie was y
# 4484: stelt 5 te min ‚ om dat den voornoemden R 7
# 4485: schoten was een Man, daer van in tijde en wy.
# 4486: len niets oude konnen werden geconsequeert,
# 4487: dat haer Hoogh Mogende geliefden te declare-
# 4488: ten of den Suppliant bevoeght was de voor.
# 4489: schreve Sententie te komen in appel aen haer
# 4490: Hoogh Mogende 5 gelijck in voorgaende tyden
# 4491: was gepractiseert, dan of hem alleen, naer het
# 4492: exempel van de Sententie van de Raden ter Ad-
# 4493: miraliteyt open stondt het middel van revisie,
# 4494: en dat haer Hoogh Mogende in het laetste ge.
# 4495: val oelicfden die voorsieninge te doen, dat het
# 4496: vooschreve versochte Mandement in cas van
# 4497: revisie aen den Suppsiant mochten werden ver-
# 4498: leent, en in cas haer Hoogh Mogende daer om-
# 4499: trent de saecke niet in staet vonden om op dat
# 4500: hier vooren Declaratoir aenstonts finalijck te
# 4501: disponeren, dat dan in soodanigen geval moch-
# 4502: te werden verstaen dat met de voorschreve pro-
# 4503: ceduyren voor den Hove van Hollandt tot soo
# 4504: lange soude moeten werden gesupercedeert, tot
# 4505: dat haer Hooeh Mogende op dese Requeste fi-
# 4506: f
# 4507: nalijck souden hebben gedisponeert. Waer on
# 4508: oedelibereert zynde, isgoetgevonden ende ver
# 4509: staen, dat Copye van de voorschreve Requefte
# 4510: gestelt sal werden in handen van de Heeren van
# 4511: Gent, ende andere haer Hoogh Mogende Ge-
# 4512: deputeerden tot de saecken van de Griffe, om
# 4513: te visiteren, examineren, en van alles alhier ter
# 4514: 7
# 4515: nos
# 4516:
#
# 4517: Vergaderinge rapport te doen.
# 4518: Zijnde ter Vergaderinge getoont Copie van
# 4519: een Wisselbrief door den Heer van Almelo,
# 4520: haer Hooeh Mogende extraordinaris Envoyé aen
# 4521: verscheyde Hoven in Duytslandt gepasseert , er
# 4522: somme van hondert pistolen, te Betalen door
# 4523: haer Hoogh Mogende, aen Louis Comminoc,
# 4524: ofte desselfs ordre hebbende: is naer voorgaen-
# 4525: de deliberatie goedtgevonden ende verstaen,
# 4526: mits desen te versoecken den Raedt van State,
# 4527: de noodige voorsieninge te doen, dat de voor-
# 4528: schreve Wisselbrief door den Onfanger Gene-
# 4529: racl geaccepteert ende betaeldt mogen wei
# 4530: LisM
# 4531: den.
# 4532: Ontfangen een Missive van den Generael-
# 4533: Major Ticharner, geschreven tot Bergen op
# 4534: Zoom den achtsten deser ; versoeckende noch-
# 4535: mael haer Hoogh Mogende permissie om sigh
# 4536: in sijne gesontheyt te herstellen , sulcks aldaer
# 4537: onmogelijck zynde, immers soo haer Hoogh
# 4538: Mogende hem niet eenige gunste gunden, ten
# 4539: minsten als de koortse heeft; versoeckende dat
# 4540: haer Hoogh Mogende yemande derwaerts gelie.
# 4541: ven te senden ‚ om het commandement voor
# 4542: eenigen tijdt waer te nemen. Waer op gede.
# 4543: libereert, en gehoort zynde het rappogt van de
# 4544: Heeren Ham, ende andete haer Hoogh Mogen-
# 4545: de Gedeputeerden tot de Militaire saecken ,
# 4546: over den inhoude van de voorschreve. Missive
# 4547: met eenige Heeren Gecommitteerden uyt den
# 4548: Raedt van State in Conferentie geweest zynde,
# 4549: Is goedteevonden ende verstaen , dat aen ge-
# 4550: te
# 4551: melden Generael- Major Tschatner sal werden
# 4552: gerescri peert dat haer Hoogh Mogende dienstigh
# 4553: achten dat hy voor eerst noch te Bergen op.
# 4554: Zoom blyft, ten. ware het met sijne gesontheyt
# 4555: erger wierde, als wanneer haer Hoogh Mogen-
# 4556: de op sijn versoeck nader sullen, disponneren,
# 4557: dogh dat den Major-Generael Coljers sal werden
# 4558: gelast, soo. als de selve gelast wert mits desen,
# 4559: sich ten spoedighsten na Bergen op Zoom te be-
# 4560: geven 5. om den gemelden Generael- Major
# 4561: Tcharner aldaer in het commandement te assi-
# 4562: steren, en wanneer de selve door sieckte wert
# 4563: beleth het voorschreve commandement ten dien-
# 4564: ste van den Lande waer te nemen.
# 4565: Is gehoort het rapport van de Heeren Ham,
# 4566: en andere haer Hoogh Mogende Gedeputeerden
# 4567: tot de Militaire saecken , ebbende , in gevolge
# 4568: ende tot voldoeninge van der selver Resolutie
# 4569: Commissoriael van den negen en twintighsten
# 4570: der voorlede maendt , met ende nevens eenige
# 4571: Heeren Gecommitteerden uyt den Raedt van
# 4572: State, nader overleght hoedanigh bequaemst
# 4573: gevonden sa4 konnen werden de Recrutes die
# 4574: aen de Regimenten in Portugael noch manke-
# 4575: ren, te weten, seven hondert Man voor de In-
# 4576: fanterye . ende dertigh voor de Dragonders.
# 4577: Waer op gedelibereerdt zynde, is oedtgevon-
# 4578: den ende verstaen , dat om de voorschreve Re-
# 4579: crutes te vinden, genomen sal werden een Man
# 4580: van yeder Compagnie van de eygen Militie van
# 4581: den Staet, ende soo veel doensijck sal zijn Pet-
# 4582: soonen die ongetrouwt ende vrywilsigh zyn om
# 4583: derwaerts te gaen ‚ en dat aen de Compagnien
# 4584: voor yeder Man met hare Klederen , Monture
# 4585: ende Geweer, gegeven sal werden dertigh rijcks-
# 4586: daelders, ende werdt den Raedt van State ver-
# 4587: socht en geauthoriseert om de noodige ordre te
# 4588: stellen dat. de voorschreve reerutes op bequame
# 4589: Plaetsen by een versamelt mogen werden, om
# 4590: vervolgens met de Schepen van Oorlogh die in
# 4591: het vroege voorjaer na Portugael sullen moeten
# 4592: gaen, derwaerts getransporteert te werden, dat
# 4593: om het geene voorschreve is te konnen effectue-
# 4594: ren, de Heeren Staten van de respective Pro-
# 4595: vincien By Missive sullen werden versocht om
# 4596: te suyvereh hare quotes in de Petitien tot de on-
# 4597: kosten profuerende . uyt de Tracaten met Por-
# 4598: tugael, ende in de Petitien tot de recruteringe 9
# 4599: in deen en d’ander consenterende ‚ soo veel
# 4600: nogh niet geconsenteert hebben . en dat de
# 4601: hooghgemelde Heeren Staten, die van Hollands
# 4602: uytgesondert  insgelijcks sullen werden versoght
# 4603: te consenteren in de Petitie tot de extraordina-
# 4604: ris Equipagie over desen are ‚ en alle om daer
# 4605: toe ten spoedighsten een goede somme van pen-
# 4606: ningen te berde brengen , en dat aen de hoogh-
# 4607: gemelde Heeren Staten nochmael sal werden ge-
# 4608: representeert dat het werck in Portugael niet
# 4609: staende vehouden sal konnen werden, nochte
# 4610: daer uyt te verwachten zyn de voordeelen die
# 4611: daer mede zyn beooght, ten sy de handt daer
# 4612: aen krachtigh werdt gehouden ES dogh dat sulks
# 4613: gedaen werdende, onder Godes segen 2 hoope
# 4614: magh werden geschept dat de efforten aldaer te
# 4615: doen ‚ van beter succes ‚ en meerder gevolgen
# 4616: fallen wesen, als tot nogh toe niet geweest zyn 5
# 4617: dogh dat alle Resolutien en pogingen te ver-
# 4618: geefs zyn, in gevalle de respective Provincien.
# 4619: niet komen te furneren de middelen daer toe.
# 4620: nodigh, en sonder de welcke het werck niet uyt
# 4621: te voeren, is, dat insonderheyt vereyst wert dae
# 4622: de Schepen van Ooslogh na die Quartieren ge-
# 4623: destineert, volgens de geprojecteerde extraar-
# 4624: dinaris E quipagie i ade maendt van Februari,
# 4625: en hoe eerder soo beter derwaerts mogen ver.
# 4626: trecken , onder het welcke de Reerutes paer
# 4627: Portugacl gedestineert i alwaer de C- ampagne
# 4628: seer vroegh begint , niet derwaerts gebracht
# 4629: sullen konnen werden ende sonder dewelke
# 4630: men pericul sal loopen van de Vyanden ij die
# 4631: volgens alle advisen met de uytterste viye aen
# 4632: hare B quip age arbeyden om eerst in Zee te we.
# 4633: sen ‚ gep’ re vel nieert te werden 1 ende de vrught
# 4634: van alle de onkosten aen de expeditie na P oren.
# 4635: gacl aengewend, verlooren sal gaen, dogh dat
# 4636: geen verwaghtinge kan werden opgevat, dat de
# 4637: Equfpage na Portugael ende de Middelandssche
# 4638: Zee gedestineert ‚ in gereetheydt kan werden
# 4639: gebraght soo lange de Provincie inhouden hare
# 4640: Consenten tot de extraordinaris Equipage voor
# 4641: desen jare, waer van dese een gedeelte is, en soo
# 4642: lange de Collegien ter Admitaliteyt door regle
# 4643: fuenissementen niet werden bequaem gemaeckt,
# 4644: om de selve te konnen doen en voltrecken, ende
# 4645: dat, derhalven het gantsche effect van de expeditie
# 4646: in Portugael van de hier voorge melde consenten
# 4647: en furnisiementen dependerende, haer Hoogh
# 4648: Mogende verwaghten dat meer hoogh-gemelde
# 4649: Heeren Staten yeder voor soo veel haer aen.
# 4650: gaet daer omtrent de nodige voorsieninge sullen
# 4651: doen.
# 4652: 2
# 4653: novo
# 4654: OOV -
# 4655: Dominica den 1 1. Fanuarij 1705.
# 4656: Nihil ahum est.
# 4657: ob
# 4658: overl
# 4659: ne n
# 4660: ned ni 9
# 4661: on o0b
# 4662: IM 96 1
# 4663: Luna den 12. Januari 1 705.
# 4664: P R ZE SID E,
# 4665: 7
# 4666: ba
# 4667: ob
# 4668: De Heer Becker
# 4669: P R ESE NTI B U 8,
# 4670: De Heeren van Gent, van Essen, Ham.
# 4671: V ande Honert, Heemskerck, Groeninx, van
# 4672: Hoey, Raedi-Pensionaris Heynsius.
# 4673: Een extraordinaris Gedeputeerde uyt de Provincie
# 4674: van Zeelandt.
# 4675: Renswoude , Ve elthuysen.
# 4676: Du our,
# 4677: il
# 4678: P
# 4679: Wichers, Gockinga.
# 4680: bn
# 4681: In
# 4682: nn
# 4683:
#
# 4684: AE Resolutien eergisteren genomen, zijn

# %%
resolution_segments = [(97,126),(127,147),(2669,2685),(2813,2825),(3068,3093)]

id_suffix = 1
resolution_annotations = []
for rs in resolution_segments:
    res_annot = {'label':'resolutions','begin_index':rs[0],'end_index':rs[1],\
                 'id':'NL-HaNA_1.01.02_3760_resolution-'+str(id_suffix)}
    resolution_annotations.append(res_annot)
    id_suffix += 1

resolution_annotations
# Out:
# [{'label': 'resolutions',
#   'begin_index': 97,
#   'end_index': 126,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-1'},
#  {'label': 'resolutions',
#   'begin_index': 127,
#   'end_index': 147,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-2'},
#  {'label': 'resolutions',
#   'begin_index': 2669,
#   'end_index': 2685,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-3'},
#  {'label': 'resolutions',
#   'begin_index': 2813,
#   'end_index': 2825,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-4'},
#  {'label': 'resolutions',
#   'begin_index': 3068,
#   'end_index': 3093,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-5'}]

# %%
all_annotations.extend(resolution_annotations)

# %%
def annotations_at_index(index,label=None):
    annots_at_index = [ann_info for ann_info in all_annotations if ann_info['begin_index'] <= index <= ann_info['end_index']]  
    return annots_at_index

# %%
annotations_at_index(2675)
# Out:
# [{'label': 'lines',
#   'image_coords': {'left': 1390,
#    'right': 2278,
#    'top': 955,
#    'bottom': 1015,
#    'height': 60,
#    'width': 888},
#   'begin_index': 2675,
#   'id': 'NL-HaNA_1.01.02_3760_0022-page-42-col-1-tr-0-line-12',
#   'end_index': 2675},
#  {'label': 'textregions',
#   'image_coords': {'left': 1380,
#    'right': 2294,
#    'top': 372,
#    'bottom': 3290,
#    'height': 2918,
#    'width': 914},
#   'begin_index': 2663,
#   'id': 'NL-HaNA_1.01.02_3760_0022-page-42-col-1-tr-0',
#   'end_index': 2724},
#  {'label': 'columns',
#   'image_coords': {'left': 1380,
#    'right': 2294,
#    'top': 372,
#    'bottom': 3290,
#    'height': 2918,
#    'width': 914},
#   'begin_index': 2663,
#   'id': 'NL-HaNA_1.01.02_3760_0022-page-42-col-1',
#   'end_index': 2724},
#  {'label': 'sessions',
#   'image_coords': None,
#   'begin_index': 2568,
#   'id': 'meeting-1705-01-07-session-1',
#   'end_index': 3093},
#  {'label': 'scanpage',
#   'iiif_url': 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg',
#   'begin_index': 2599,
#   'end_index': 2850,
#   'scan_num': 22},
#  {'label': 'pages',
#   'id': 'NL-HaNA_1.01.02_3760_0022-page-42',
#   'begin_index': 2599,
#   'end_index': 2850,
#   'indexesByContainment': True},
#  {'label': 'pages',
#   'id': 'NL-HaNA_1.01.02_3760_0022-page-43',
#   'begin_index': 2599,
#   'end_index': 2850,
#   'indexesByContainment': True},
#  {'label': 'resolutions',
#   'begin_index': 2669,
#   'end_index': 2685,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-3'}]

# %% [markdown]
# Zoek alle annotaties die overlappen met een interval. Dat interval kan ontleent worden aan begin_index en end_index van een resolutie.

# %%
# return generator for annotations with a specific label
def get_annotations_of_type(type,annotations):
    return (a for a in annotations if a['label'] == type)

# %%
for a in get_annotations_of_type('resolutions', all_annotations):
    print(a)
# Out:
# {'label': 'resolutions', 'begin_index': 97, 'end_index': 126, 'id': 'NL-HaNA_1.01.02_3760_resolution-1'}
# {'label': 'resolutions', 'begin_index': 127, 'end_index': 147, 'id': 'NL-HaNA_1.01.02_3760_resolution-2'}
# {'label': 'resolutions', 'begin_index': 2669, 'end_index': 2685, 'id': 'NL-HaNA_1.01.02_3760_resolution-3'}
# {'label': 'resolutions', 'begin_index': 2813, 'end_index': 2825, 'id': 'NL-HaNA_1.01.02_3760_resolution-4'}
# {'label': 'resolutions', 'begin_index': 3068, 'end_index': 3093, 'id': 'NL-HaNA_1.01.02_3760_resolution-5'}

# %%
def get_annotations_overlapping_with(begin,end,annotations):
    return (a for a in annotations if (a['begin_index'] >= begin and a['begin_index'] < end) or\
           (a['end_index'] > begin and a['end_index'] <= end) or\
           (a['begin_index'] <= begin and a['end_index'] >= end))

# %%
for a in get_annotations_overlapping_with(2813,2825,all_annotations):
    print(a)
# Out:
# {'label': 'lines', 'image_coords': {'left': 3575, 'right': 4413, 'top': 1561, 'bottom': 1657, 'height': 96, 'width': 838}, 'begin_index': 2813, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-15', 'end_index': 2813}
# {'label': 'lines', 'image_coords': {'left': 3522, 'right': 4413, 'top': 1609, 'bottom': 1702, 'height': 93, 'width': 891}, 'begin_index': 2814, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-16', 'end_index': 2814}
# {'label': 'lines', 'image_coords': {'left': 3517, 'right': 4413, 'top': 1655, 'bottom': 1749, 'height': 94, 'width': 896}, 'begin_index': 2815, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-17', 'end_index': 2815}
# {'label': 'lines', 'image_coords': {'left': 3515, 'right': 4414, 'top': 1703, 'bottom': 1799, 'height': 96, 'width': 899}, 'begin_index': 2816, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-18', 'end_index': 2816}
# {'label': 'lines', 'image_coords': {'left': 3518, 'right': 4406, 'top': 1753, 'bottom': 1848, 'height': 95, 'width': 888}, 'begin_index': 2817, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-19', 'end_index': 2817}
# {'label': 'lines', 'image_coords': {'left': 3519, 'right': 4407, 'top': 1802, 'bottom': 1894, 'height': 92, 'width': 888}, 'begin_index': 2818, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-20', 'end_index': 2818}
# {'label': 'lines', 'image_coords': {'left': 3515, 'right': 4403, 'top': 1849, 'bottom': 1944, 'height': 95, 'width': 888}, 'begin_index': 2819, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-21', 'end_index': 2819}
# {'label': 'lines', 'image_coords': {'left': 3516, 'right': 4404, 'top': 1897, 'bottom': 1990, 'height': 93, 'width': 888}, 'begin_index': 2820, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-22', 'end_index': 2820}
# {'label': 'lines', 'image_coords': {'left': 3515, 'right': 4402, 'top': 1947, 'bottom': 2037, 'height': 90, 'width': 887}, 'begin_index': 2821, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-23', 'end_index': 2821}
# {'label': 'lines', 'image_coords': {'left': 3512, 'right': 4395, 'top': 1996, 'bottom': 2087, 'height': 91, 'width': 883}, 'begin_index': 2822, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-24', 'end_index': 2822}
# {'label': 'lines', 'image_coords': {'left': 3512, 'right': 4390, 'top': 2045, 'bottom': 2135, 'height': 90, 'width': 878}, 'begin_index': 2823, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-25', 'end_index': 2823}
# {'label': 'lines', 'image_coords': {'left': 3510, 'right': 4389, 'top': 2091, 'bottom': 2186, 'height': 95, 'width': 879}, 'begin_index': 2824, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-26', 'end_index': 2824}
# {'label': 'lines', 'image_coords': {'left': 3505, 'right': 4160, 'top': 2140, 'bottom': 2219, 'height': 79, 'width': 655}, 'begin_index': 2825, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2-line-27', 'end_index': 2825}
# {'label': 'textregions', 'image_coords': {'left': 3446, 'right': 4448, 'top': 834, 'bottom': 3392, 'height': 2558, 'width': 1002}, 'begin_index': 2798, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1-tr-2', 'end_index': 2850}
# {'label': 'columns', 'image_coords': {'left': 3446, 'right': 4457, 'top': 396, 'bottom': 3440, 'height': 3044, 'width': 1011}, 'begin_index': 2785, 'id': 'NL-HaNA_1.01.02_3760_0022-page-43-col-1', 'end_index': 2850}
# {'label': 'sessions', 'image_coords': None, 'begin_index': 2568, 'id': 'meeting-1705-01-07-session-1', 'end_index': 3093}
# {'label': 'scanpage', 'iiif_url': 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg', 'begin_index': 2599, 'end_index': 2850, 'scan_num': 22}
# {'label': 'pages', 'id': 'NL-HaNA_1.01.02_3760_0022-page-42', 'begin_index': 2599, 'end_index': 2850, 'indexesByContainment': True}
# {'label': 'pages', 'id': 'NL-HaNA_1.01.02_3760_0022-page-43', 'begin_index': 2599, 'end_index': 2850, 'indexesByContainment': True}
# {'label': 'resolutions', 'begin_index': 2813, 'end_index': 2825, 'id': 'NL-HaNA_1.01.02_3760_resolution-4'}

# %% [markdown]
# Combineer beide: alle annotaties van een bepaald type, binnen een interval

# %%
# nested generators (is that allowed?)
def get_annotations_of_type_overlapping(type,begin,end,annotations):
    return get_annotations_of_type(type,(get_annotations_overlapping_with(begin,end,annotations)))

# %%
for a in get_annotations_of_type_overlapping('resolutions',2599,2850,all_annotations):
    print(a)
# Out:
# {'label': 'resolutions', 'begin_index': 2669, 'end_index': 2685, 'id': 'NL-HaNA_1.01.02_3760_resolution-3'}
# {'label': 'resolutions', 'begin_index': 2813, 'end_index': 2825, 'id': 'NL-HaNA_1.01.02_3760_resolution-4'}

# %%
def get_textlines_between(begin,end,annotations): 
    textlines = []
    for line_annot in get_annotations_of_type_overlapping('lines',begin,end,annotations):
        textlines.append((line_annot['begin_index'],all_textlines[line_annot['begin_index']]))
    return textlines

# %%
# get text for (text segment of) resolution
for a in get_textlines_between(2813,2825,all_annotations):
    print(a)
# Out:
# (2813, 'Is ter Vergaderinge gelesen de Requeste van')
# (2814, 'Arnoldus Boomhouwer , Auditeur tot Roer')
# (2815, 'monde, versoeckende, om redenen in de voor.')
# (2816, 'schreve Requeste geësprimeert, dat haer Hoogh')
# (2817, 'Mogende geliefden hem Suppliant te begunse,')
# (2818, 'gen met de Fourier- ofte Biljet meesters pact')
# (2819, 'binnen de Stadt Rroermonde, ende aen hen dae,')
# (2820, 'van te verleenen Commissie in forma, Waer ey')
# (2821, 'gedelibereert aynde is goetgevonden ende yer.')
# (2822, 'staen, dat Copye van de voorschreve Request')
# (2823, 'gesonden sal werden aen de Magistraet van koe')
# (2824, 'inonde » om der selver b erie ih t daer op en ie')
# (2825, 'Hoogh Mogende te laten toekomen.')

# %% [markdown]
# Vraag nu de tekst op voor de kolom waar deze resolutie deel van uitmaakt

# %%
# resolutiegrenzen 2813 en 2825 waren eerder al opgevraagd middels 'get_annotations_of_type'
# vraag eerst columns op, die overlappen met die grenzen
begin = 2813
end = 2825
column_annots = get_annotations_of_type_overlapping('columns',begin,end,all_annotations)

# voor ieder column, print column_id, print column text
for col_annot in column_annots:
    print(f"column id: {col_annot['id']}")
    print(f"{col_annot['begin_index']}   {col_annot['end_index']}\n")
    
    for a in get_textlines_between(col_annot['begin_index'],col_annot['end_index'],all_annotations):
        print(a)
# Out:
# column id: NL-HaNA_1.01.02_3760_0022-page-43-col-1
# 2785   2850
#
# (2785, '(29')
# (2786, 'ai')
# (2787, 'Den 7. Januarth,')
# (2788, 'H')
# (2789, 'Gul-')
# (2790, '1')
# (2791, 'het besolsieitere nde bet iinge Y oe')
# (2792, 'ges Waer op gedelibel ee zynde is goetge.')
# (2793, 'vonden ende verstaen , mite desen te onsen.')
# (2794, 'teren in het voorschreve versoeck, ende wend.')
# (2795, 'dienvolgende aen den Suppliant gesccordee')
# (2796, 'permissie en verlof voor den tydt van wee maen.')
# (2797, 'den ì')
# (2798, 'ts er Vergaderinge gelesen de Requeste van')
# (2799, 'Frangois d le Serra, Lieut enant Collon l van a')
# (2800, 'Regiment van den Colsonel Henry de Caris, ver.')
# (2801, '\n')
# (2802, 'qucste geësprimeert, dat haer Hoogh Mogen.')
# (2803, 'de geliefden a en hem Sapp lane te permis ven')
# (2804, '\n')
# (2805, 'Collonel op approbatie ende aggreatie van haa,')
# (2806, 'Hoogh Mogende aen een ander bequzem Of')
# (2807, '\n')
# (2808, 'gedelibereert ynde is goetgevonden ende ye')
# (2809, 'sen , dat Copye van de voorschreve Requesie')
# (2810, 'gefonden sl werden aen den gemelden Collon')
# (2811, 'Caris ‚ om sijn bericht daer op aen haer Hogg,')
# (2812, 'Mogende te laten toekomen,')
# (2813, 'Is ter Vergaderinge gelesen de Requeste van')
# (2814, 'Arnoldus Boomhouwer , Auditeur tot Roer')
# (2815, 'monde, versoeckende, om redenen in de voor.')
# (2816, 'schreve Requeste geësprimeert, dat haer Hoogh')
# (2817, 'Mogende geliefden hem Suppliant te begunse,')
# (2818, 'gen met de Fourier- ofte Biljet meesters pact')
# (2819, 'binnen de Stadt Rroermonde, ende aen hen dae,')
# (2820, 'van te verleenen Commissie in forma, Waer ey')
# (2821, 'gedelibereert aynde is goetgevonden ende yer.')
# (2822, 'staen, dat Copye van de voorschreve Request')
# (2823, 'gesonden sal werden aen de Magistraet van koe')
# (2824, 'inonde » om der selver b erie ih t daer op en ie')
# (2825, 'Hoogh Mogende te laten toekomen.')
# (2826, 'Is ter Vergaderinge gelesen een Memorie o,')
# (2827, 'de naem van den Marquis diie we, verso end,')
# (2828, 'by vernieuwinge en andersunes verscheyde pay')
# (2829, 'porten gratis om op ’s Vyandes bodem te mogen')
# (2830, 'reysen. Waer op gedelibercert ynde is goe,')
# (2831, 'vonden en verstaen ‚ dat Pasporten grat, sue,')
# (2832, 'werden gedepescheert voor den ris. van Ra.')
# (2833, 'benpeé, Groot Jagermeester , voor den Goy,')
# (2834, 'van Bergeyck, Superintendane Generacl van de')
# (2835, '\n')
# (2836, 'se ie d ans an de Fina ntie ‚ voor den Mar ie 1')
# (2837, 'ee - In vendane van Brabant en Me helen, ee')
# (2838, 'voor Manuel Tesi, Commisris van de Viy,')
# (2839, 'alle voor den tydt van een jaer,')
# (2840, 'On tfangen een Missive van')
# (2841, '\n')
# (2842, 'Eynatten van Nieuwerburgh , Heer van Culpen,')
# (2843, 'geschreven tot Nieuwerbugh den sestienden')
# (2844, 'cember laetstleden, ende daer nevens wee Byl.')
# (2845, 'gen houdende, in gevolge en tot voldoening')
# (2846, 'van haer Hoogh Mogende Resolutie van den,')
# (2847, 'en wincighsten November aetstleden, des ele.')
# (2848, 'belangh op de Requcste ten selven dage aen hae,')
# (2849, 'Hoogh Mogende gepesenteert ‚ by ofte van we')
# (2850, 'gen Patroclus Edsema, Voorleser der Kercka tat')

# %% [markdown]
# Volgende stap: definieren van named entities. Voorlopig alleen door te verwijzen naar de index van de line(s) waar deze entities op voorkomen

# %%
entity_segments = [(2814,2814,'per','Arnoldus Boomhouwer'),(2832,2833,'per','van Rabenpeé'),\
                   (2819,2819,'loc','Roermond')]

id_suffix = 1
entity_annotations = []
for es in entity_segments:
    ent_annot = {'label':'entities','begin_index':es[0],'end_index':es[1],\
                 'id':'NL-HaNA_1.01.02_3760_entity-'+str(id_suffix),\
                 'entity_type': es[2],'entity_text':es[3]}
    entity_annotations.append(ent_annot)
    id_suffix += 1

entity_annotations
# Out:
# [{'label': 'entities',
#   'begin_index': 2814,
#   'end_index': 2814,
#   'id': 'NL-HaNA_1.01.02_3760_entity-1',
#   'entity_type': 'per',
#   'entity_text': 'Arnoldus Boomhouwer'},
#  {'label': 'entities',
#   'begin_index': 2832,
#   'end_index': 2833,
#   'id': 'NL-HaNA_1.01.02_3760_entity-2',
#   'entity_type': 'per',
#   'entity_text': 'van Rabenpeé'},
#  {'label': 'entities',
#   'begin_index': 2819,
#   'end_index': 2819,
#   'id': 'NL-HaNA_1.01.02_3760_entity-3',
#   'entity_type': 'loc',
#   'entity_text': 'Roermond'}]

# %%
all_annotations.extend(entity_annotations)

# %%
for a in get_annotations_of_type('entities', all_annotations):
    print(a)
# Out:
# {'label': 'entities', 'begin_index': 2814, 'end_index': 2814, 'id': 'NL-HaNA_1.01.02_3760_entity-1', 'entity_type': 'per', 'entity_text': 'Arnoldus Boomhouwer'}
# {'label': 'entities', 'begin_index': 2832, 'end_index': 2833, 'id': 'NL-HaNA_1.01.02_3760_entity-2', 'entity_type': 'per', 'entity_text': 'van Rabenpeé'}
# {'label': 'entities', 'begin_index': 2819, 'end_index': 2819, 'id': 'NL-HaNA_1.01.02_3760_entity-3', 'entity_type': 'loc', 'entity_text': 'Roermond'}

# %%
# get text for (text segment of) entity
for a in get_textlines_between(2832,2833,all_annotations):
    print(a)
# Out:
# (2832, 'werden gedepescheert voor den ris. van Ra.')
# (2833, 'benpeé, Groot Jagermeester , voor den Goy,')

# %%
# get text for (text segment of) entity
for a in get_textlines_between(2819,2819,all_annotations):
    print(a)
# Out:
# (2819, 'binnen de Stadt Rroermonde, ende aen hen dae,')

# %%
# get all entities for a specific session

# first get session that contains our example resolution from 2813 to 2825
for a in get_annotations_of_type_overlapping('sessions',2599,2850,all_annotations):
    print(a)
# Out:
# {'label': 'sessions', 'image_coords': None, 'begin_index': 2568, 'id': 'meeting-1705-01-07-session-1', 'end_index': 3093}

# %%
# then, get overlapping entities
for a in get_annotations_of_type_overlapping('entities',2568,3093,all_annotations):
    print(a)
# Out:
# {'label': 'entities', 'begin_index': 2814, 'end_index': 2814, 'id': 'NL-HaNA_1.01.02_3760_entity-1', 'entity_type': 'per', 'entity_text': 'Arnoldus Boomhouwer'}
# {'label': 'entities', 'begin_index': 2832, 'end_index': 2833, 'id': 'NL-HaNA_1.01.02_3760_entity-2', 'entity_type': 'per', 'entity_text': 'van Rabenpeé'}
# {'label': 'entities', 'begin_index': 2819, 'end_index': 2819, 'id': 'NL-HaNA_1.01.02_3760_entity-3', 'entity_type': 'loc', 'entity_text': 'Roermond'}

# %% [markdown]
# Experiment: voeg een 'image_range' element toe voor iedere resolutie

# %%
resolution_annotations
# Out:
# [{'label': 'resolutions',
#   'begin_index': 97,
#   'end_index': 126,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-1'},
#  {'label': 'resolutions',
#   'begin_index': 127,
#   'end_index': 147,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-2'},
#  {'label': 'resolutions',
#   'begin_index': 2669,
#   'end_index': 2685,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-3'},
#  {'label': 'resolutions',
#   'begin_index': 2813,
#   'end_index': 2825,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-4'},
#  {'label': 'resolutions',
#   'begin_index': 3068,
#   'end_index': 3093,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-5'}]

# %%
# voor iedere resolutie, bepaal image_range en voeg deze toe

def get_bounding_box_for(annotations): 
    ann_list = list(annotations) # because a generator can only be used once
    
    min_left = min([ann['image_coords']['left'] for ann in ann_list if 'image_coords' in ann])
    max_right = max([ann['image_coords']['right'] for ann in ann_list if 'image_coords' in ann])
    min_top = min([ann['image_coords']['top'] for ann in ann_list if 'image_coords' in ann])
    max_bottom = max([ann['image_coords']['bottom'] for ann in ann_list if 'image_coords' in ann])
    height = max_bottom - min_top
    width = max_right - min_left

    return {'left': min_left, 'right': max_right, 'top': min_top, 'bottom': max_bottom, 'height': height, 'width': width}

for r in resolution_annotations:
    r['image_range'] = []
    
    res_begin=r['begin_index']
    res_end=r['end_index']
    print(f"\nbegin of resolution: {res_begin}, end of resolution: {res_end}")
    
    # loop over scans die overlappen met de resolutie
    for a in get_annotations_of_type_overlapping('scanpage',res_begin,res_end,all_annotations):
        bounding_boxes = []
        image_url = a['iiif_url']
        print(image_url)
        
        scan_begin=a['begin_index']
        scan_end=a['end_index']
        
        # loop over alle kolommen op de betreffende scan. Per kolom, bereken bounding box voor 
        # overlappende resolutieregels
        for clm in get_annotations_of_type_overlapping('columns',scan_begin,scan_end,all_annotations):
            clm_begin=clm['begin_index']
            clm_end=clm['end_index']
            
            # bepaal overlap_begin en overlap_end indexes voor kolom
            overlap_begin=max(res_begin, clm_begin)
            overlap_end=min(res_end, clm_end)
            
#            print(f"{clm['id']}  {clm_begin}  {clm_end} overlap_begin: {overlap_begin} overlap_end: {overlap_end}")
            
            # bepaal hieruit de bounding box coords voor deze kolom
            if overlap_end-overlap_begin >= 0: # resolution and column are overlapping
                bounding_box=get_bounding_box_for(get_annotations_of_type_overlapping('lines',\
                                                        overlap_begin,overlap_end,all_annotations))
                bounding_boxes.append(bounding_box)
        
        r['image_range'].append((image_url, bounding_boxes))
        print(r['image_range'])
# Out:
# begin of resolution: 97, end of resolution: 126
# https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/full/,3114/0/default.jpg
# [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/full/,3114/0/default.jpg', [{'left': 405, 'right': 1310, 'top': 1036, 'bottom': 2451, 'height': 1415, 'width': 905}])]
#
# begin of resolution: 127, end of resolution: 147
# https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/full/,3114/0/default.jpg
# [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/full/,3114/0/default.jpg', [{'left': 420, 'right': 1317, 'top': 2436, 'bottom': 3273, 'height': 837, 'width': 897}, {'left': 1361, 'right': 2264, 'top': 349, 'bottom': 557, 'height': 208, 'width': 903}])]
#
# begin of resolution: 2669, end of resolution: 2685
# https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg
# [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg', [{'left': 1388, 'right': 2291, 'top': 666, 'bottom': 1462, 'height': 796, 'width': 903}])]
#
# begin of resolution: 2813, end of resolution: 2825
# https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg
# [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg', [{'left': 3505, 'right': 4414, 'top': 1561, 'bottom': 2219, 'height': 658, 'width': 909}])]
#
# begin of resolution: 3068, end of resolution: 3093
# https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0023.jpg/full/,3111/0/default.jpg
# [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0023.jpg/full/,3111/0/default.jpg', [{'left': 3483, 'right': 4408, 'top': 2145, 'bottom': 3326, 'height': 1181, 'width': 925}])]
# https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0024.jpg/full/,312/0/default.jpg
# [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0023.jpg/full/,3111/0/default.jpg', [{'left': 3483, 'right': 4408, 'top': 2145, 'bottom': 3326, 'height': 1181, 'width': 925}]), ('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0024.jpg/full/,312/0/default.jpg', [{'left': 372, 'right': 1252, 'top': 370, 'bottom': 482, 'height': 112, 'width': 880}])]

# %% [markdown]
# Tussenconclusie: het is mogelijk voor een resolutie alle omsluitende rectangles af te leiden, zelfs als de resolutietekst over meerdere kolommen en/of meerdere scans doorloopt. In principe zijn uit deze image_ranges IIIF image urls af te leiden voor de resolutieonderdelen op de scans, of de hele scans zijn op te halen, en de resolutiedelen daarop zijn te omkaderen.

# %% [markdown]
# Omdat het leuk is: genereer nog even een list van IIIF image urls per resolutie (en zet ze dan in je browser even naast elkaar.

# %%
resolution_annotations
# Out:
# [{'label': 'resolutions',
#   'begin_index': 97,
#   'end_index': 126,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-1',
#   'image_range': [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/full/,3114/0/default.jpg',
#     [{'left': 405,
#       'right': 1310,
#       'top': 1036,
#       'bottom': 2451,
#       'height': 1415,
#       'width': 905}])]},
#  {'label': 'resolutions',
#   'begin_index': 127,
#   'end_index': 147,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-2',
#   'image_range': [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/full/,3114/0/default.jpg',
#     [{'left': 420,
#       'right': 1317,
#       'top': 2436,
#       'bottom': 3273,
#       'height': 837,
#       'width': 897},
#      {'left': 1361,
#       'right': 2264,
#       'top': 349,
#       'bottom': 557,
#       'height': 208,
#       'width': 903}])]},
#  {'label': 'resolutions',
#   'begin_index': 2669,
#   'end_index': 2685,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-3',
#   'image_range': [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg',
#     [{'left': 1388,
#       'right': 2291,
#       'top': 666,
#       'bottom': 1462,
#       'height': 796,
#       'width': 903}])]},
#  {'label': 'resolutions',
#   'begin_index': 2813,
#   'end_index': 2825,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-4',
#   'image_range': [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg',
#     [{'left': 3505,
#       'right': 4414,
#       'top': 1561,
#       'bottom': 2219,
#       'height': 658,
#       'width': 909}])]},
#  {'label': 'resolutions',
#   'begin_index': 3068,
#   'end_index': 3093,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-5',
#   'image_range': [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0023.jpg/full/,3111/0/default.jpg',
#     [{'left': 3483,
#       'right': 4408,
#       'top': 2145,
#       'bottom': 3326,
#       'height': 1181,
#       'width': 925}]),
#    ('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0024.jpg/full/,312/0/default.jpg',
#     [{'left': 372,
#       'right': 1252,
#       'top': 370,
#       'bottom': 482,
#       'height': 112,
#       'width': 880}])]}]

# %%
for res in resolution_annotations:
    region_links = []
    for image_url, regions in res['image_range']:
        for coords in regions:
            # construct iiif_url from image_url and coords
            coord_str = f"{coords['left']},{coords['top']},{coords['width']},{coords['height']}"
            region_url = re.sub(r'(full)/(,\d+)', rf'{coord_str}/\1', image_url)
            region_links.append(region_url)
    res['region_links'] = region_links

# %%
resolution_annotations
# Out:
# [{'label': 'resolutions',
#   'begin_index': 97,
#   'end_index': 126,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-1',
#   'image_range': [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/full/,3114/0/default.jpg',
#     [{'left': 405,
#       'right': 1310,
#       'top': 1036,
#       'bottom': 2451,
#       'height': 1415,
#       'width': 905}])],
#   'region_links': ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/405,1036,905,1415/full/0/default.jpg']},
#  {'label': 'resolutions',
#   'begin_index': 127,
#   'end_index': 147,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-2',
#   'image_range': [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/full/,3114/0/default.jpg',
#     [{'left': 420,
#       'right': 1317,
#       'top': 2436,
#       'bottom': 3273,
#       'height': 837,
#       'width': 897},
#      {'left': 1361,
#       'right': 2264,
#       'top': 349,
#       'bottom': 557,
#       'height': 208,
#       'width': 903}])],
#   'region_links': ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/420,2436,897,837/full/0/default.jpg',
#    'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/1361,349,903,208/full/0/default.jpg']},
#  {'label': 'resolutions',
#   'begin_index': 2669,
#   'end_index': 2685,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-3',
#   'image_range': [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg',
#     [{'left': 1388,
#       'right': 2291,
#       'top': 666,
#       'bottom': 1462,
#       'height': 796,
#       'width': 903}])],
#   'region_links': ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/1388,666,903,796/full/0/default.jpg']},
#  {'label': 'resolutions',
#   'begin_index': 2813,
#   'end_index': 2825,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-4',
#   'image_range': [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg',
#     [{'left': 3505,
#       'right': 4414,
#       'top': 1561,
#       'bottom': 2219,
#       'height': 658,
#       'width': 909}])],
#   'region_links': ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/3505,1561,909,658/full/0/default.jpg']},
#  {'label': 'resolutions',
#   'begin_index': 3068,
#   'end_index': 3093,
#   'id': 'NL-HaNA_1.01.02_3760_resolution-5',
#   'image_range': [('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0023.jpg/full/,3111/0/default.jpg',
#     [{'left': 3483,
#       'right': 4408,
#       'top': 2145,
#       'bottom': 3326,
#       'height': 1181,
#       'width': 925}]),
#    ('https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0024.jpg/full/,312/0/default.jpg',
#     [{'left': 372,
#       'right': 1252,
#       'top': 370,
#       'bottom': 482,
#       'height': 112,
#       'width': 880}])],
#   'region_links': ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0023.jpg/3483,2145,925,1181/full/0/default.jpg',
#    'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0024.jpg/372,370,880,112/full/0/default.jpg']}]

# %%
for a in get_annotations_of_type('resolutions', all_annotations):
    print(a['region_links'])
# Out:
# ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/405,1036,905,1415/full/0/default.jpg']
# ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/420,2436,897,837/full/0/default.jpg', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/1361,349,903,208/full/0/default.jpg']
# ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/1388,666,903,796/full/0/default.jpg']
# ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/3505,1561,909,658/full/0/default.jpg']
# ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0023.jpg/3483,2145,925,1181/full/0/default.jpg', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0024.jpg/372,370,880,112/full/0/default.jpg']

# %%
def get_annotation_by_id(id, annotations):
    return next(ann for ann in annotations if 'id' in ann.keys() and ann['id'] == id)

# %%
for a in get_annotations_of_type_overlapping('resolutions',130,130,all_annotations):
    print(a['region_links'])
# Out:
# ['https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/420,2436,897,837/full/0/default.jpg', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/1361,349,903,208/full/0/default.jpg']

# %%
for a in get_textlines_between(127,147,all_annotations):
    print(a)
# Out:
# (127, '0, de Requeste van Paulus de Noter ‚ Schip-')
# (128, 'per, woonende tot Brussel, is na voorgdende de-')
# (129, 'liberatie goetgevofiden en verstaer, dat ten be-')
# (130, 'hoeve van den Suppliant een Pasport sal werden')
# (131, 'oedepescheert, om met sijn Schip direct en son-')
# (132, 'der overschepinge van Brussel uyt dese Landen te')
# (133, 'mogen afhalen 1000 sacken wit gerafineert Zout,')
# (134, 'ende de selve na Brussel te mogen uytvoeren,')
# (135, 'mits betalende ’sLandts gerechtieheyt, mitsga-')
# (136, 'ders de Spaensche rechten van het PortSt. Maria')
# (137, 'aen den Ontfanger Flinck. Endesal Exeract van')
# (138, 'dese haer Hoogh Mogende Resolutie gesonden')
# (139, 'werden aen het Cellegie ter A dmiralieeye in Zee-')
# (140, 'lande, en het selve aengeschreven soodanige or-')
# (141, 'dre te stellen , en die voorsseninge te doen dat')
# (142, 'de voorschreve quantiteyt Zout onverhindert en')
# (143, 'sonder eenige molestatie op der elver Comptoi-')
# (144, 'ren mogen passeren. De Heeren Gedeputeera')
# (145, 'den van de Provincie van Zeelande hebben de')
# (146, 'voorschreve Reqneste overgenomen, en de con-')
# (147, 'clusse gecontradiceert.')

# %%
for a in get_annotations_of_type('resolutions', all_annotations):
    print(json.dumps(a, sort_keys=False, indent=2))
# Out:
# {
#   "label": "resolutions",
#   "begin_index": 97,
#   "end_index": 126,
#   "id": "NL-HaNA_1.01.02_3760_resolution-1",
#   "image_range": [
#     [
#       "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/full/,3114/0/default.jpg",
#       [
#         {
#           "left": 405,
#           "right": 1310,
#           "top": 1036,
#           "bottom": 2451,
#           "height": 1415,
#           "width": 905
#         }
#       ]
#     ]
#   ],
#   "region_links": [
#     "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/405,1036,905,1415/full/0/default.jpg"
#   ]
# }
# {
#   "label": "resolutions",
#   "begin_index": 127,
#   "end_index": 147,
#   "id": "NL-HaNA_1.01.02_3760_resolution-2",
#   "image_range": [
#     [
#       "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/full/,3114/0/default.jpg",
#       [
#         {
#           "left": 420,
#           "right": 1317,
#           "top": 2436,
#           "bottom": 3273,
#           "height": 837,
#           "width": 897
#         },
#         {
#           "left": 1361,
#           "right": 2264,
#           "top": 349,
#           "bottom": 557,
#           "height": 208,
#           "width": 903
#         }
#       ]
#     ]
#   ],
#   "region_links": [
#     "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/420,2436,897,837/full/0/default.jpg",
#     "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0009.jpg/1361,349,903,208/full/0/default.jpg"
#   ]
# }
# {
#   "label": "resolutions",
#   "begin_index": 2669,
#   "end_index": 2685,
#   "id": "NL-HaNA_1.01.02_3760_resolution-3",
#   "image_range": [
#     [
#       "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg",
#       [
#         {
#           "left": 1388,
#           "right": 2291,
#           "top": 666,
#           "bottom": 1462,
#           "height": 796,
#           "width": 903
#         }
#       ]
#     ]
#   ],
#   "region_links": [
#     "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/1388,666,903,796/full/0/default.jpg"
#   ]
# }
# {
#   "label": "resolutions",
#   "begin_index": 2813,
#   "end_index": 2825,
#   "id": "NL-HaNA_1.01.02_3760_resolution-4",
#   "image_range": [
#     [
#       "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/full/,3130/0/default.jpg",
#       [
#         {
#           "left": 3505,
#           "right": 4414,
#           "top": 1561,
#           "bottom": 2219,
#           "height": 658,
#           "width": 909
#         }
#       ]
#     ]
#   ],
#   "region_links": [
#     "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0022.jpg/3505,1561,909,658/full/0/default.jpg"
#   ]
# }
# {
#   "label": "resolutions",
#   "begin_index": 3068,
#   "end_index": 3093,
#   "id": "NL-HaNA_1.01.02_3760_resolution-5",
#   "image_range": [
#     [
#       "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0023.jpg/full/,3111/0/default.jpg",
#       [
#         {
#           "left": 3483,
#           "right": 4408,
#           "top": 2145,
#           "bottom": 3326,
#           "height": 1181,
#           "width": 925
#         }
#       ]
#     ],
#     [
#       "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0024.jpg/full/,312/0/default.jpg",
#       [
#         {
#           "left": 372,
#           "right": 1252,
#           "top": 370,
#           "bottom": 482,
#           "height": 112,
#           "width": 880
#         }
#       ]
#     ]
#   ],
#   "region_links": [
#     "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0023.jpg/3483,2145,925,1181/full/0/default.jpg",
#     "https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3760/NL-HaNA_1.01.02_3760_0024.jpg/372,370,880,112/full/0/default.jpg"
#   ]
# }

# %%
all_textlines[-10:]
# Out:
# ['Renswoude , Ve elthuysen.',
#  'Du our,',
#  'il',
#  'P',
#  'Wichers, Gockinga.',
#  'bn',
#  'In',
#  'nn',
#  '\n',
#  'AE Resolutien eergisteren genomen, zijn']

# %%
# write all_textlines to a file
with open('../data/all_textlines.txt', 'w') as filehandle:
    json.dump(all_textlines, filehandle)
