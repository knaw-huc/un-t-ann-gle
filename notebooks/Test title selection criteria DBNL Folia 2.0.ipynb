# %% [markdown]
# In dit notebook probeer ik met lxml over alle nieuwe DBNL files te itereren. Per file zoek ik alle div's die een attribuut 'metadata' hebben en een attribuut 'class="value"'. Daarna groepeer ik de resultaten over de waarden van 'value'. Doel: 1. testen van deze conditie als splitsingscriterium 2. overzicht van mogelijke waarden van 'class', mogelijk moet ik op grond van sommige waarden wel splitsen, op grond van andere niet.

# %%
import lxml
from lxml import etree

path = '_gid001183701_01.nederlab.folia.xml'

# %%
tree = etree.parse(path)

# %%
root = tree.getroot()

# %% [markdown]
# onderstaande call werkt zowel voor tree als voor root:

# %%
tree.xpath('//*[@class]/@class', namespaces = {"xmlns": "http://ilk.uvt.nl/folia"})
# Out:
# ['bodymatter',
#  'chapter',
#  'pagebreak',
#  'h3',
#  'nld',
#  'PUNCTUATION',
#  'LET()',
#  '[',
#  'WORD',
#  'N(soort,ev,basis,onz,stan)',
#  'soort',
#  'ev',
#  'basis',
#  'onz',
#  'stan',
#  'woord',
#  'WORD',
#  'BW()',
#  'vooraf',
#  'PUNCTUATION',
#  'LET()',
#  ']',
#  'p',
#  'i',
#  'nld',
#  'WORD',
#  'ADJ(vrij,basis,zonder)',
#  'vrij',
#  'basis',
#  'zonder',
#  'gedachtig',
#  'WORD',
#  'VZ(init)',
#  'init',
#  'aan',
#  'WORD',
#  'LID(bep,stan,rest)',
#  'bep',
#  'stan',
#  'rest',
#  'de',
#  'WORD',
#  'N(soort,ev,basis,zijd,stan)',
#  'soort',
#  'ev',
#  'basis',
#  'zijd',
#  'stan',
#  'uitspraak',
#  'WORD',
#  'VZ(init)',
#  'init',
#  'van',
#  'WORD',
#  'LID(bep,dial)',
#  'bep',
#  'dial',
#  'de',
#  'den',
#  'WORD',
#  'SPEC(deeleigen)',
#  'deeleigen',
#  'Wetgever',
#  'WORD',
#  'VZ(init)',
#  'init',
#  'op',
#  'WORD',
#  'LID(bep,dial)',
#  'bep',
#  'dial',
#  'de',
#  'den',
#  'WORD',
#  'SPEC(deeleigen)',
#  'deeleigen',
# ...

# %%
matching_divs = tree.xpath('//*[@metadata and @class]', namespaces = {"xmlns": "http://ilk.uvt.nl/folia"})

# %%
len(matching_divs)
# Out:
# 174

# %% [markdown]
# maak een overzicht van unieke waarden voor 'class'

# %%
occurring_classes = tree.xpath('//*[@metadata and @class]/@class', namespaces = {"xmlns": "http://ilk.uvt.nl/folia"})

# %%
occurring_classes
# Out:
# ['chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
#  'chapter',
# ...

# %% [markdown]
# deze lijst bevat de volgende unieke waarden:

# %%
set_of_class_values = set(occurring_classes)

# %%
set_of_class_values
# Out:
# {'chapter', 'section'}

# %% [markdown]
# Volgende stap: 1. check het geval met 'section', wat is dat? 2. doe dezelfde inventarisatie voor een grote subset van DBNL docs.
# ad 1: lijkt gewoon meegenomen te moeten worden, section wrs onderdeel van het vocabulaire waarop moet worden gefilterd. Het betreft hier id eindigend op _0122, zoek het oude folia bestand er nog even bij, ter verificatie.

# %% [markdown]
# Ad 2: loop over alle DBNL folia's > 1800

# %%
dbnl_folder_path = "/Users/hennie/Documents/TEAM TEXT/experimenten/dbnl folia 2.0 experimentjes/nieuwe/folia2.0-files/batch_post1800_regular"

# %%
import os

#for filename in os.listdir(dbnl_folder_path)[:1000]:
#    set_of_class_values.update(tree.xpath('//*[@metadata and @class]/@class', namespaces = {"xmlns": "http://ilk.uvt.nl/folia"}))
    
#set_of_class_values
metadata_cnt = 0
num_processed = 0
for filename in os.listdir(dbnl_folder_path):
    metadata_cnt += len(tree.xpath('//*[@metadata]', namespaces = {"xmlns": "http://ilk.uvt.nl/folia"}))
    num_processed += 1
    if num_processed %100 == 0:
        print(num_processed)

print(f"metadata attribute occurs {metadata_cnt} times")
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
